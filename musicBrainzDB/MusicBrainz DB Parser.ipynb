# %%
###########################################################################
## Basic
###########################################################################
# %load_ext autoreload
# %autoreload
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
 

###########################################################################
## Warnings
###########################################################################
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>

# %% [markdown]
# # Basic Functions

# %%
from fileIO import fileIO
from fsUtils import fileUtil, dirUtil
from pandas import read_csv, DataFrame, Series
from fsUtils import setDir, setFile
from timeUtils import timestat
from numpy import nan
from pandas import to_datetime, NaT, isna, concat

from glob import glob
from fileIO import csvIO, pickleIO


def loadData(ifile):
    mbdata = csvIO().get(ifile, delimiter="\t", header=None, error_bad_lines=False)
    #mbdata = read_csv(ifile, delimiter="\t", header=None)
    mbdata = mbdata.replace('\\N', nan)
    return mbdata


def getData(files, colnames):
    data = {fileUtil(ifile).basename: loadData(ifile) for ifile in files}
    print("Keys: {0}".format(data.keys()))
    data = {key: val[list(colnames[key].keys())].rename(columns=colnames[key]) for key,val in data.items() if key in colnames} if colnames is not None else data
    print("Keys: {0}".format(data.keys()))
    return data


def setIndex(data):
    for key,df in data.items():
        colname = df.columns[0]
        df.index = df[colname]
        df.drop([colname], axis=1, inplace=True)
    return data


def createDate(year, month, day):
    if all([isinstance(x,str) for x in [year,month,day]]):
        return to_datetime('{0}-{1}-{2}'.format(year, month, day), format='%Y-%m-%d', errors='ignore')
    elif all([isinstance(x,str) for x in [year,month]]):
        return to_datetime('{0}-{1}'.format(year, month), format='%Y-%m', errors='ignore')
    elif all([isinstance(x,str) for x in [year]]):
        return to_datetime('{0}'.format(year), format='%Y', errors='ignore')
    return NaT


def convertToDatetime(year, month, day):
    year  = year.apply(lambda x: int(x) if (not isna(x) and x.isdigit()) else -1)
    month = month.apply(lambda x: int(x) if (not isna(x) and x.isdigit()) else -1)
    day   = day.apply(lambda x: int(x) if (not isna(x) and x.isdigit()) else -1)
    tmp   = DataFrame(year).join(month).join(day)
    tmp.columns = ["year", "month", "day"]
    return to_datetime(tmp, errors='coerce')


basedir = "./"
basedir = "/Volumes/Seagate/DB"

aIDs={"ArianaGrande": 823336, "BuddyHolly": 10937, "Rupaul": 34318, "U2": 197, "DMB": 502, "Bono": 35575, "Mozart": 11285, "JohnMayer": 33563}

# %%
# !ln -s '/Volumes/Seagate/DB/mbdump'

# %% [markdown]
# # DB Data

# %%
lengthData = open("flength.csv").readlines()
lengthData = [x.replace("\n", "").strip().split() for x in lengthData]
lengthData = Series({item[1].split("/")[1]: int(item[0]) for item in lengthData if len(item[1].split("/")) > 1})
lengthData

# %%
list(lengthData.index)

# %%
#lengthData['release_label']
lengthData[(lengthData <= 6)]

# %% [markdown]
# # Lookup Dictionary

# %%
colnames = {}
colnames['gender'] = {0: "GenderID", 1: "GenderName"} #, 3: "NA3", "GenderDescr"}

ts = timestat("Loading Gender Data")
files = [ifile for ifile in glob("mbdump/gender*")]
genderData = getData(files, colnames)
genderData = setIndex(genderData)
ts.stop()

dGenderName = genderData['gender']['GenderName'].to_dict()
del genderData
# Out:
# Current Time is Sat Dec 11, 2021 22:17 for Loading Gender Data
# Keys: dict_keys(['gender'])
# Keys: dict_keys(['gender'])
# Process [Loading Gender Data] Took 0.0 Seconds

# %%
colnames = {}
colnames["area_type"] = {0: "AreaTypeID", 1: "AreaTypeName", 3: "AlsoAreaTypeID", 4: "AreaTypeDescr", 5: "AreaTypeGID"}
colnames["area"]      = {0: "AreaID", 1: "AreaGID", 2: "AreaName", 3: "AreaTypeID"}
#colnames["area_gid_redirect"] = {0: "AreaGIDUUID", 1: "AreaGID"}
#colnames["area_alias_type"] = {0: "AreaAliasTypeID", 1: "AreaAliasTypeName", 5: "AreaAliasTypeUUID"}
#colnames["area_alias"] = {0: "AreaAliasID", 1: "NA1", 2: "AreaAlias", 3: "AreaLang", 6: "AliasTypeID", 7: "AreaSortName"}

ts = timestat("Loading Area Data")
files = glob("mbdump/area*")
areaData = getData(files, colnames)
areaData = setIndex(areaData)
ts.stop()

dAreaName = areaData['area']['AreaName'].to_dict()
del areaData
# Out:
# Current Time is Sat Dec 11, 2021 22:17 for Loading Area Data
# Keys: dict_keys(['area', 'area_alias', 'area_alias_type', 'area_gid_redirect', 'area_type'])
# Keys: dict_keys(['area', 'area_type'])
# Process [Loading Area Data] Took 0.7 Seconds

# %%
colnames = {}
colnames['isrc'] = {0: "ISRCID", 1: "RecordingID", 2: "ISRC"}
colnames['iswc'] = {0: "ISWCID", 1: "WorkID", 2: "ISWC"}
colnames['iso_3166_1'] = {0: "ISO31661ID", 1: "ISO31661"}
colnames['iso_3166_2'] = {0: "ISO31662ID", 1: "ISO31662"}
colnames['iso_3166_3'] = {0: "ISO31663ID", 1: "ISO31663"}

ts = timestat("Loading i* Code Data")
files = glob("mbdump/is*")
icodeData = getData(files, colnames)
icodeData = setIndex(icodeData)
ts.stop()

iSWCData = icodeData['iswc']["ISWC"].copy(deep=True)
iSWCData.index = icodeData['iswc']['WorkID']
iSWCData = iSWCData.drop_duplicates()
del icodeData
# Out:
# Current Time is Sat Dec 11, 2021 22:17 for Loading i* Code Data
# Keys: dict_keys(['iso_3166_1', 'iso_3166_2', 'iso_3166_3', 'isrc', 'iswc'])
# Keys: dict_keys(['iso_3166_1', 'iso_3166_2', 'iso_3166_3', 'isrc', 'iswc'])
# Process [Loading i* Code Data] Took 2.7 Seconds

# %%
colnames = {}
colnames["language"] = {0: "LanguageID", 1: "LanguageShort1", 2: "LanguageShort2", 3: "LanguageShort3", 4: "LanguageName", 5: "NA5", 6: "LanguageShort"}

ts = timestat("Loading URL Data")
files = glob("mbdump/language*")
languageData = getData(files, colnames)
languageData = setIndex(languageData)
ts.stop()

dLanguageName = languageData['language']['LanguageName'].to_dict()
del languageData
# Out:
# Current Time is Sat Dec 11, 2021 22:17 for Loading URL Data
# Keys: dict_keys(['language'])
# Keys: dict_keys(['language'])
# Process [Loading URL Data] Took 0.0 Seconds

# %%
colnames = {}
colnames["script"] = {0: "ScriptID", 1: "ScriptName", 2: "NA2", 3: "ScriptDescr", 4: "NA4"}

ts = timestat("Loading URL Data")
files = glob("mbdump/script")
scriptData = getData(files, colnames)
scriptData = setIndex(scriptData)
ts.stop()

dScriptName = scriptData['script']['ScriptName'].to_dict()
del scriptData
# Out:
# Current Time is Sat Dec 11, 2021 22:17 for Loading URL Data
# Keys: dict_keys(['script'])
# Keys: dict_keys(['script'])
# Process [Loading URL Data] Took 0.0 Seconds

# %%
colnames = {}
colnames["label_alias"] = {0: "LabelAliasID", 1: "LabelID", 2: "LabelAliasName", 7: "LabelAliasName2"}
colnames["label_alias_type"] = {0: "LabelAliasTypeID", 1: "LabelAliasTypeName", 5: "LabelAliasGID"}
colnames["label_ipi"] = {0: "LabelIPIID", 1: "LabelIPI"}
colnames["label_isni"] = {0: "LabelISNIID", 1: "LabelISNI"}
colnames["label_type"] = {0: "LabelTypeID", 1: "LabelTypeName", 5: "LabelTypeGID"}
colnames["label"] = {0: "LabelID", 1: "LabelGID", 2: "LabelName"}

ts = timestat("Loading Label Data")
files = glob("mbdump/label*")
labelData = getData(files, colnames)
labelData = setIndex(labelData)
ts.stop()

dLabelName = labelData['label']['LabelName'].to_dict()
del labelData
# Out:
# Current Time is Sat Dec 11, 2021 22:17 for Loading Label Data
# Keys: dict_keys(['label', 'label_alias', 'label_alias_type', 'label_gid_redirect', 'label_ipi', 'label_isni', 'label_type'])
# Keys: dict_keys(['label', 'label_alias', 'label_alias_type', 'label_ipi', 'label_isni', 'label_type'])
# Process [Loading Label Data] Took 0.9 Seconds

# %% [markdown]
# # Gender

# %%
colnames = {}
colnames['gender'] = {0: "GenderID", 1: "GenderName"} #, 3: "NA3", "GenderDescr"}

ts = timestat("Loading Gender Data")
files = [ifile for ifile in glob("mbdump/gender*")]
genderData = getData(files, colnames)
genderData = setIndex(genderData)
ts.stop()

# %% [markdown]
# # Lookup

# %%
colnames = {}
colnames["l_label_release"] = {0: "Index", 1: "NA1", 2: "NA2", 3: "ReleaseID"}

ts = timestat("Loading Area Data")
files = glob("mbdump/l_label_release")
lookupData = {fileInfo(ifile).basename: loadData(ifile) for ifile in files}
lookupData = {key: val[list(colnames[key].keys())].rename(columns=colnames[key]) for key,val in lookupData.items()} if colnames is not None else lookupData
print("Keys: {0}".format(lookupData.keys()))
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 22:17 for Loading Area Data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j1/syf62l4j46q052mwy0366byh0000gn/T/ipykernel_3071/2511908938.py in <module>
#       4 ts = timestat("Loading Area Data")
#       5 files = glob("mbdump/l_label_release")
# ----> 6 lookupData = {fileInfo(ifile).basename: loadData(ifile) for ifile in files}
#       7 lookupData = {key: val[list(colnames[key].keys())].rename(columns=colnames[key]) for key,val in lookupData.items()} if colnames is not None else lookupData
#       8 print("Keys: {0}".format(lookupData.keys()))
#
# /var/folders/j1/syf62l4j46q052mwy0366byh0000gn/T/ipykernel_3071/2511908938.py in <dictcomp>(.0)
#       4 ts = timestat("Loading Area Data")
#       5 files = glob("mbdump/l_label_release")
# ----> 6 lookupData = {fileInfo(ifile).basename: loadData(ifile) for ifile in files}
#       7 lookupData = {key: val[list(colnames[key].keys())].rename(columns=colnames[key]) for key,val in lookupData.items()} if colnames is not None else lookupData
#       8 print("Keys: {0}".format(lookupData.keys()))
#
# NameError: name 'fileInfo' is not defined

# %%
lookupData['l_label_release'][lookupData['l_label_release']['ReleaseID'].isin(releaseIDs)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j1/syf62l4j46q052mwy0366byh0000gn/T/ipykernel_3071/3384347301.py in <module>
# ----> 1 lookupData['l_label_release'][lookupData['l_label_release']['ReleaseID'].isin(releaseIDs)]
#
# KeyError: 'l_label_release'

# %%
lookupData['l_label_release'].max()

# %% [markdown]
# # Area

# %%
colnames = {}
colnames["area_type"] = {0: "AreaTypeID", 1: "AreaTypeName", 3: "AlsoAreaTypeID", 4: "AreaTypeDescr", 5: "AreaTypeGID"}
colnames["area"]      = {0: "AreaID", 1: "AreaGID", 2: "AreaName", 3: "AreaTypeID"}
#colnames["area_gid_redirect"] = {0: "AreaGIDUUID", 1: "AreaGID"}
#colnames["area_alias_type"] = {0: "AreaAliasTypeID", 1: "AreaAliasTypeName", 5: "AreaAliasTypeUUID"}
#colnames["area_alias"] = {0: "AreaAliasID", 1: "NA1", 2: "AreaAlias", 3: "AreaLang", 6: "AliasTypeID", 7: "AreaSortName"}

ts = timestat("Loading Area Data")
files = glob("mbdump/area*")
areaData = getData(files, colnames)
areaData = setIndex(areaData)
ts.stop()

# %% [markdown]
# # Event

# %%
colnames = {}
colnames["event_type"] = {0: "EventTypeID", 1: "EventTypeName", 4: "EventTypeDescr"}
colnames["event_alias_type"] = {0: "EventAliasTypeID", 1: "EventAliasTypeName", 5: "EventAliasTypeGID"}
colnames["event_alias"] = {0: "EventAliasID", 1: "EventID", 2: "EventAliasName", 3: "EventAliasLang", 7: "EventAliasName2"}
colnames["event"] = {0: "EventID", 1: "EventGID", 2: "EventName", 
                     3: "EventStartYear", 4: "EventStartMonth", 5: "EventStartDay", 6: "EventEndYear", 7: "EventEndMonth", 8: "EventEndDay"}

ts = timestat("Loading Event Data")
files = glob("mbdump/event*")
eventData = {fileInfo(ifile).basename: loadData(ifile) for ifile in files}
print("Keys: {0}".format(eventData.keys()))
eventData = {key: val[list(colnames[key].keys())].rename(columns=colnames[key]) for key,val in eventData.items() if key in colnames} if colnames is not None else eventData
print("Keys: {0}".format(eventData.keys()))
ts.stop()

# %%
eventData['event']

# %% [markdown]
# # ICode

# %%
colnames = {}
colnames['isrc'] = {0: "ISRCID", 1: "RecordingID", 2: "ISRC"}
colnames['iswc'] = {0: "ISWCID", 1: "WorkID", 2: "ISWC"}
colnames['iso_3166_1'] = {0: "ISO31661ID", 1: "ISO31661"}
colnames['iso_3166_2'] = {0: "ISO31662ID", 1: "ISO31662"}
colnames['iso_3166_3'] = {0: "ISO31663ID", 1: "ISO31663"}

ts = timestat("Loading i* Code Data")
files = glob("mbdump/is*")
icodeData = getData(files, colnames)
icodeData = setIndex(icodeData)
ts.stop()

iSWCData = icodeData['iswc']["ISWC"].copy(deep=True)
iSWCData.index = icodeData['iswc']['WorkID']
iSWCData = iSWCData.drop_duplicates()
del icodeData

# %% [markdown]
# # Medium

# %%
colnames = {}
colnames["medium_format"] = {0: "MediumFormatID", 1: "MediumName", 2: "MediumGroupID", 3: "NA3", 4: "MediumIntroYear", 5: "MediumDescr", 6: "MediumGID"}
#colnames["medium_cdtoc"]  = {0: "NA0", 1: "NA1", 2: "NA2", 3: "NA3"}
colnames["medium"] = {0: "ReleaseID_1", 1: "ReleaseID", 2: "SideNum", 3: "MediumFormatID", 4: "NA4", 5: "NA5", 7: "NumTracks"}

ts = timestat("Loading Medium Data")
files = glob("mbdump/medium*")
mediumData = {fileInfo(ifile).basename: loadData(ifile) for ifile in files}
print("Keys: {0}".format(mediumData.keys()))
mediumData = {key: val[list(colnames[key].keys())].rename(columns=colnames[key]) for key,val in mediumData.items() if key in colnames} if colnames is not None else mediumData
print("Keys: {0}".format(mediumData.keys()))
ts.stop()

# %%
mediumData['medium_format'].nunique()

# %%
mediumData['medium'].nunique()

# %%
## 12" Vinyl ; ReleaseID=1310220
#mediumData['medium'][mediumData['medium'].eq(1310220).any(1)]
# MediumID  ReleaseID  Sides?  Format?   ?
# 1310220   1274390    1       33        4
# 1351220   1310220    1       31        11      <- Matches https://musicbrainz.org/release/6b5f33a8-fc5e-4c1e-b379-c659ce20a1c8


## Digital Media : ReleaseID=1792210
#mediumData['medium'][mediumData['medium'].eq(1792210).any(1)]
# MediumID  ReleaseID  Sides?  Format?   ?
# 1792210   1694923    1      12	NaN	0	2015-11-30 00:32:22.335038+00	13
# 1904010   1792210    1      12	NaN	0	2016-06-20 18:41:01.106192+00	11   Both Match


# 2x12" Vinyl ; ReleaseID=1680415

#mediumData['medium'][mediumData['medium'].eq(1680415).any(1)]
# MediumID  ReleaseID  Sides?  Format?   ?
# 1680415	1598741	1	1	NaN	0	2015-04-27 04:37:49.277705+00	11
# 1775088	1680415	1	31	NaN	0	2015-10-31 12:02:35.843886+00	5
# 1775089	1680415	2	31	NaN	0	2015-10-31 12:02:35.843886+00	6

# 1792210   1694923    1      12	NaN	0	2015-11-30 00:32:22.335038+00	13
# 1904010   1792210    1      12	NaN	0	2016-06-20 18:41:01.106192+00	11   Both Match

# Pixies Velouria CD w/ 4 Tracks
# 3099, 1162482, 3097, 2259927

## CD
# mediumData['medium'][mediumData['medium'].eq(3099).any(1)]
# 3099	3099	1	1	NaN	0	2011-05-16 14:57:06.530063+00	4

## CD (Status=Promotional)
# mediumData['medium'][mediumData['medium'].eq(1162482).any(1)]
# 1162482	1146184	1	12	NaN	0	2012-04-14 05:35:56.931961+00	1
# 1181517	1162482	1	1	NaN	0	2012-05-30 00:53:24.512335+00	4

## CD
# mediumData['medium'][mediumData['medium'].eq(3097).any(1)]
# 3097	3097	1	1	NaN	0	2012-10-18 19:49:17.567219+00	4

## 12" Vinyl
# mediumData['medium'][mediumData['medium'].eq(2259927).any(1)]
# 2259927	2099781	1	12	NaN	0	2018-01-11 08:03:13.107915+00	5
# 2441117	2259927	1	31	NaN	0	2018-09-28 23:20:29.279923+00	4  <-- This matches Web

# %%
mediumData['medium'].nunique()

# %%
mediumData['medium'].shape

# %%
mediumData['medium_cdtoc'][mediumData['medium_cdtoc'].eq(1598741).any(1)]

# %%
mediumData['medium_format'][mediumData['medium_format'].eq(38).any(1)]

# %%
mediumData['medium_format'][mediumData['medium_format'].eq('38').any(1)]

# %%
mediumData['medium_format'][mediumData['medium_format'].eq(63).any(1)]

# %%
mediumData['medium_format'][mediumData['medium_format'].eq(64).any(1)]

# %% [markdown]
# # Language

# %%
colnames = {}
colnames["language"] = {0: "LanguageID", 1: "LanguageShort1", 2: "LanguageShort2", 3: "LanguageShort3", 4: "LanguageName", 5: "NA5", 6: "LanguageShort"}

ts = timestat("Loading URL Data")
files = glob("mbdump/language*")
languageData = getData(files, colnames)
languageData = setIndex(languageData)
ts.stop()

# %% [markdown]
# # Script

# %%
colnames = {}
colnames["script"] = {0: "ScriptID", 1: "ScriptName", 2: "NA2", 3: "ScriptDescr", 4: "NA4"}

ts = timestat("Loading URL Data")
files = glob("mbdump/script")
scriptData = getData(files, colnames)
scriptData = setIndex(scriptData)
ts.stop()

# %% [markdown]
# # URL

# %%
colnames = {}
colnames["url"] = {0: "URLID", 1: "URLGID", 2: "URLName"}
#colnames["url_gid_redirect"] = {0: "URLGIDUUID", 1: "URLGIDID"}

ts = timestat("Loading URL Data")
files = glob("mbdump/url*")
urlData = getData(files, colnames)
urlData = setIndex(urlData)
ts.stop()

# %% [markdown]
# # Work

# %%
colnames = {}
colnames["work_type"] = {0: "WorkTypeID", 1: "WorkTypeName", 3: "WorkTypeRanking", 4: "WorkTypeDescr", 5: "WorkTypeGID"}
#colnames["work_alias"] = {0: "WorkAliasID", 1: "WorkID", 2: "WorkName", 3: "WorkLang", 7: "WorkName2"}
#colnames["work_alias_type"] = {0: "WorkAliasTypeID", 1: "WorkAliasTypeName", 5: "WorkAliasTypeGID"}
colnames['work_attribute_type_allowed_value'] = {0: 'WorkAttributeTypeValueID', 1: "WorkAttributeTypeID", 2: "WorkAttributeTypeValue", 6: "WorkAttributeTypeValueGID"}
colnames["work_attribute_type"] = {0: "WorkAttributeTypeID", 1: "WorkAttributeTypeName", 6: "WorkAttributeTypeDescr"}
colnames["work_attribute"] = {0: "WorkAttributeID", 1: "WorkID", 2: "WorkAttributeTypeID", 3: "WorkAttributeTypeValueID", 4: "WorkAttributeCode"}
colnames["work_language"] = {0: "WorkID", 1: "LanguageID"}
colnames["work"] = {0: "WorkID", 1: "WorkGID", 2: "WorkName", 3: "WorkTypeID"} #, 4: "WorkDescr"}

ts = timestat("Loading Work Data")
files = glob("mbdump/work*")
workData = getData(files, colnames)
workData = setIndex(workData)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 21:18 for Loading Work Data
# Keys: dict_keys(['work', 'work_alias', 'work_alias_type', 'work_attribute', 'work_attribute_type', 'work_attribute_type_allowed_value', 'work_gid_redirect', 'work_language', 'work_type'])
# Keys: dict_keys(['work', 'work_attribute', 'work_attribute_type', 'work_attribute_type_allowed_value', 'work_language', 'work_type'])
# Process [Loading Work Data] Took 5.8 Seconds

# %% [markdown]
# ## Append Data And Create Master Work DataFrame

# %%
ts = timestat("Joining Release Language Name")
workData['work_language']["Language"] = workData['work_language']['LanguageID'].apply(lambda x: dLanguageName.get(x) if not isna(x) else None)
workData['work_language'].drop(["LanguageID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Work Attribute Type")
dWorkAttributeTypeName = workData['work_attribute_type']["WorkAttributeTypeName"].to_dict()
workData['work_attribute_type_allowed_value']["WorkAttributeType"] = workData['work_attribute_type_allowed_value']['WorkAttributeTypeID'].apply(lambda x: dWorkAttributeTypeName.get(x) if not isna(x) else None)
workData['work_attribute_type_allowed_value'].drop(["WorkAttributeTypeID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Work Attribute Type")
dWorkAttributeTypeName = workData['work_attribute_type']["WorkAttributeTypeName"].to_dict()
workData['work_attribute']["WorkAttributeType"] = workData['work_attribute']['WorkAttributeTypeID'].apply(lambda x: dWorkAttributeTypeName.get(x) if not isna(x) else None)
workData['work_attribute'].drop(["WorkAttributeTypeID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Work Type")
dWorkTypeName = workData['work_type']["WorkTypeName"].to_dict()
workData['work']["WorkTypeName"] = workData['work']['WorkTypeID'].apply(lambda x: dWorkTypeName.get(int(x)) if not isna(x) else None)
workData['work'].drop(["WorkTypeID"], axis=1, inplace=True)
ts.stop()

###
# Ignore Work Attributes
###

ts = timestat("Dropping Last Columns")
workData['work'].drop(["WorkGID"], axis=1, inplace=True)
ts.stop()

savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("WorkDataFrame"))
ts = timestat("Saving Master Release DataFrame To {0}".format(savename))
pickleIO().save(idata=workData['work'], ifile=savename)
# Out:
# Current Time is Sat Dec 11, 2021 21:18 for Joining Release Language Name
# Process [Joining Release Language Name] Took 0.5 Seconds
# Current Time is Sat Dec 11, 2021 21:18 for Joining Work Attribute Type
# Process [Joining Work Attribute Type] Took 0.0 Seconds
# Current Time is Sat Dec 11, 2021 21:18 for Joining Work Attribute Type
# Process [Joining Work Attribute Type] Took 0.3 Seconds
# Current Time is Sat Dec 11, 2021 21:18 for Joining Work Type
# Process [Joining Work Type] Took 0.9 Seconds
# Current Time is Sat Dec 11, 2021 21:19 for Dropping Last Columns
# Process [Dropping Last Columns] Took 0.1 Seconds
# Current Time is Sat Dec 11, 2021 21:19 for Saving Master Release DataFrame To /Volumes/Seagate/DB/MusicBrainzData/WorkDataFrame.p

# %% [markdown]
# # Label

# %%
colnames = {}
colnames["label_alias"] = {0: "LabelAliasID", 1: "LabelID", 2: "LabelAliasName", 7: "LabelAliasName2"}
colnames["label_alias_type"] = {0: "LabelAliasTypeID", 1: "LabelAliasTypeName", 5: "LabelAliasGID"}
colnames["label_ipi"] = {0: "LabelIPIID", 1: "LabelIPI"}
colnames["label_isni"] = {0: "LabelISNIID", 1: "LabelISNI"}
colnames["label_type"] = {0: "LabelTypeID", 1: "LabelTypeName", 5: "LabelTypeGID"}
colnames["label"] = {0: "LabelID", 1: "LabelGID", 2: "LabelName"}

ts = timestat("Loading Label Data")
files = glob("mbdump/label*")
labelData = getData(files, colnames)
labelData = setIndex(labelData)
ts.stop()

# %% [markdown]
# # Recording

# %%
colnames = {}
#colnames["recording_alias_type"] = {0: "RecordingAliasTypeID", 1: "RecordingAliasTypeName"}
#colnames["recording_alias"] = {0: "RecordingAliasID", 1: "RecordingID", 2: "RecordingAliasName", 3: "RecordingAliasLang", 7: "recordingAliasName2"}
colnames["recording"] = {0: "RecordingID", 1: "RecordingGID", 2: "RecordingName", 3: "ArtistID", 4: "TimeLength"} #, 5: "RecordingDescr"}

ts = timestat("Loading Recording Data")
files = [ifile for ifile in glob("mbdump/recording*")]
recordingData = getData(files, colnames)
recordingData = setIndex(recordingData)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 21:52 for Loading Recording Data
# b'Skipping line 2180777: expected 9 fields, saw 12\n'
# b'Skipping line 5112821: expected 9 fields, saw 12\n'
# b'Skipping line 11110739: expected 9 fields, saw 12\nSkipping line 11110746: expected 9 fields, saw 12\n'
# b'Skipping line 12675230: expected 9 fields, saw 12\n'
# b'Skipping line 22142824: expected 9 fields, saw 12\n'
# /var/folders/j1/syf62l4j46q052mwy0366byh0000gn/T/ipykernel_3071/2566599573.py:14: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   mbdata = csvIO().get(ifile, delimiter="\t", header=None, error_bad_lines=False)
# Keys: dict_keys(['recording', 'recording_alias', 'recording_alias_type', 'recording_gid_redirect'])
# Keys: dict_keys(['recording'])
# Process [Loading Recording Data] Took 1.4 Minutes

# %% [markdown]
# ## Append Data And Create Master Recording DataFrame

# %%
ts = timestat("Dropping Last Columns")
recordingData['recording'].drop(["RecordingGID"], axis=1, inplace=True)
ts.stop()

savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("RecordingDataFrame"))
ts = timestat("Saving Master Recording DataFrame To {0} (~1.1 min)".format(savename))
from fileIO import pickleIO
pickleIO().save(idata=recordingData['recording'], ifile=savename)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 21:54 for Dropping Last Columns
# Process [Dropping Last Columns] Took 1.5 Seconds
# Current Time is Sat Dec 11, 2021 21:54 for Saving Master Recording DataFrame To /Volumes/Seagate/DB/MusicBrainzData/RecordingDataFrame.p (~1.1 min)
# Process [Saving Master Recording DataFrame To /Volumes/Seagate/DB/MusicBrainzData/RecordingDataFrame.p (~1.1 min)] Took 44.1 Seconds

# %% [markdown]
# # Track

# %%
colnames = {}
colnames["track"] = {0: "TrackID", 1: "TrackGID", 2: "RecordingID", 3: "NA3", 4: "TrackNum", 5: "TrackNumName", 6: "TrackName", 7: "ArtistID", 8: "TimeLength"}

# Release
# 2373946	7c5d14b4-cf40-4eb1-89e6-d448125d94f3	1987-12-12: Hampton Coliseum, Hampton, VA, USA	197	2128729	3	\N	120	28	\N		0	-1	2019-03-15 09:46:50.446876+00
            
# Release Group
# 2128729	f979a1c6-b6c2-4aad-b5b6-709c6c216752	1987-12-12: Hampton Coliseum, Hampton, VA, USA	197	1		0	2019-03-15 09:46:45.458509+00

# Recording
# 24365864	6a355a78-06c0-4e06-a15e-05d6e533255e	Sunday Bloody Sunday	197	366000		0	2019-03-15 12:29:22.049215+00	f

# Track
# 27710495	fc969b10-fdba-4b0c-82d9-aa6a7179e41f	24365864	2571008	7	7	Sunday Bloody Sunday	197	366000	0	2019-03-15 12:29:22.049215+00	f
ts = timestat("Loading Recording Data")
files = glob("mbdump/track")
trackData = {fileInfo(ifile).basename: loadData(ifile) for ifile in files}
print("Keys: {0}".format(trackData.keys()))
trackData = {key: val[list(colnames[key].keys())].rename(columns=colnames[key]) for key,val in trackData.items() if key in colnames} if colnames is not None else trackData
print("Keys: {0}".format(trackData.keys()))
ts.stop()

# %% [markdown]
# # Release

# %%
colnames = {}
#colnames["release_alias_type"] = {0: "ReleaseAliasTypeID", 1: "ReleaseAliasTypeName"}
#colnames["release_alias"] = {0: "ReleaseAliasID", 1: "ReleaseID", 2: "ReleaseAliasName", 3: "ReleaseAliasLang", 7: "ReleaseAliasName2"}
colnames["release_status"] = {0: "ReleaseStatusID", 1: "ReleaseStatusName", 3: "NA3", 3: "ReleaseStatusDescr", 4: "ReleaseStatusGID"}
colnames["release_packaging"] = {0: "ReleasePackagingID", 1: "ReleasePackagingName", 3: "NA3", 4: "ReleasePackagingDescr", 5: "ReleaseStatusGID"}
colnames["release_label"] = {0: "Index", 1: "ReleaseID", 2: "LabelID", 3: "CatalogNumber"}
colnames["release_country"] = {0: "ReleaseID", 1: "ReleaseCountryID", 2: "ReleaseCountryYear", 3: "ReleaseCountryMonth", 4: "ReleaseCountryDay"}
colnames["release_unknown_country"] = {0: "ReleaseID", 1: "ReleaseCountryYear", 2: "ReleaseCountryMonth", 3: "ReleaseCountryDay"}
colnames["release"] = {0: "ReleaseID", 1: "ReleaseGID", 2: "ReleaseName", 3: "ArtistID", 4: "ReleaseGroupID", 5: "ReleaseStatusID", 
                       6: "ReleasePackagingID", 7: "LanguageID", 8: "ScriptID", 9: "ReleaseBarcode", 10: "ReleaseComment", 11: "NA11", 12: "NA12"}

ts = timestat("Loading Release Data")
files = [ifile for ifile in glob("mbdump/release*") if "group" not in ifile]
releaseData = getData(files, colnames)
releaseData = setIndex(releaseData)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 22:17 for Loading Release Data
# Keys: dict_keys(['release', 'release_alias', 'release_alias_type', 'release_country', 'release_gid_redirect', 'release_label', 'release_packaging', 'release_status', 'release_unknown_country'])
# Keys: dict_keys(['release', 'release_country', 'release_label', 'release_packaging', 'release_status', 'release_unknown_country'])
# Process [Loading Release Data] Took 20.9 Seconds

# %% [markdown]
# ## Append Data And Create Master Release DataFrame

# %%
tsRelease = timestat("Appending Release Data")

ts = timestat("Creating Release Country DateTime For {0} Releases".format(releaseData['release_country'].shape[0]))
tmp = releaseData['release_country'][["ReleaseCountryYear", "ReleaseCountryMonth", "ReleaseCountryDay"]]
tmp.columns = ["year", "month", "day"]
releaseData['release_country']['ReleaseDate'] = to_datetime(tmp, errors='ignore')
releaseData['release_country'].drop(["ReleaseCountryYear", "ReleaseCountryMonth", "ReleaseCountryDay"], axis=1, inplace=True)
ts.stop()

ts = timestat("Creating Release Unknown Country DateTime For {0} Releases".format(releaseData['release_unknown_country'].shape[0]))
tmp = releaseData['release_unknown_country'][["ReleaseCountryYear", "ReleaseCountryMonth", "ReleaseCountryDay"]]
tmp.columns = ["year", "month", "day"]
releaseData['release_unknown_country']['ReleaseDate'] = to_datetime(tmp, errors='ignore')
releaseData['release_unknown_country'].drop(["ReleaseCountryYear", "ReleaseCountryMonth", "ReleaseCountryDay"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Country Area")
dAreaName = areaData['area']['AreaName'].to_dict()
releaseData['release_country']["Country"] = releaseData['release_country']['ReleaseCountryID'].apply(lambda x: dAreaName.get(x) if not isna(x) else None)
releaseData['release_country'].drop(["ReleaseCountryID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Release Packaging Name")
dReleasePackagingName = releaseData['release_packaging']['ReleasePackagingName'].to_dict()
releaseData['release']["Packaging"] = releaseData['release']['ReleasePackagingID'].apply(lambda x: dReleasePackagingName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
releaseData['release'].drop(["ReleasePackagingID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Release Status Name")
dReleaseStatusName = releaseData['release_status']['ReleaseStatusName'].to_dict()
releaseData['release']["Status"] = releaseData['release']['ReleaseStatusID'].apply(lambda x: dReleaseStatusName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
releaseData['release'].drop(["ReleaseStatusID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Release Language Name")
dLanguageName = languageData['language']['LanguageName'].to_dict()
releaseData['release']["Language"] = releaseData['release']['LanguageID'].apply(lambda x: dLanguageName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
releaseData['release'].drop(["LanguageID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Release Script Name")
dScriptName = scriptData['script']['ScriptName'].to_dict()
releaseData['release']["Script"] = releaseData['release']['ScriptID'].apply(lambda x: dScriptName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
releaseData['release'].drop(["ScriptID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Country/Release Date")
tmp = concat([releaseData['release_country'], releaseData['release_unknown_country']]).reset_index()
releaseIDDate = tmp.sort_values(by="ReleaseDate").drop_duplicates(subset="ReleaseID")
releaseIDDate.index = releaseIDDate['ReleaseID']
releaseIDDate.drop(["ReleaseID"], axis=1, inplace=True)
releaseData['release'] = releaseData['release'].join(releaseIDDate)
ts.stop()

ts = timestat("Joining Label Data")
dLabelName = labelData['label']['LabelName'].to_dict()
releaseData['release_label']["Label"] = releaseData['release_label']['LabelID'].apply(lambda x: dLabelName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
releaseLabel = releaseData['release_label'].drop_duplicates(subset="ReleaseID")[["ReleaseID", "Label"]].copy(deep=True)
releaseLabel["Label"].index = releaseLabel["ReleaseID"]
releaseData['release'].join(releaseLabel)
ts.stop()

ts = timestat("Dropping Last Columns")
releaseData['release'].drop(["ReleaseComment", "ReleaseBarcode", "NA11", "NA12"], axis=1, inplace=True)
ts.stop()


savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("ReleaseDataFrame"))
ts = timestat("Saving Master Release DataFrame To {0}".format(savename))
pickleIO().save(idata=releaseData['release'], ifile=savename)
fsize = fileInfo(savename).fsize
print("Master Release DataFrame is {0}{1}".format(fsize[0], fsize[1]))
ts.stop()


tsRelease.stop()
# Out:
# Current Time is Sat Dec 11, 2021 22:18 for Appending Release Data
# Current Time is Sat Dec 11, 2021 22:18 for Creating Release Country DateTime For 6845429 Releases
# Process [Creating Release Country DateTime For 6845429 Releases] Took 21.2 Seconds
# Current Time is Sat Dec 11, 2021 22:18 for Creating Release Unknown Country DateTime For 205613 Releases
# Process [Creating Release Unknown Country DateTime For 205613 Releases] Took 0.5 Seconds
# Current Time is Sat Dec 11, 2021 22:18 for Joining Country Area
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j1/syf62l4j46q052mwy0366byh0000gn/T/ipykernel_3071/2473433413.py in <module>
#      16
#      17 ts = timestat("Joining Country Area")
# ---> 18 dAreaName = areaData['area']['AreaName'].to_dict()
#      19 releaseData['release_country']["Country"] = releaseData['release_country']['ReleaseCountryID'].apply(lambda x: dAreaName.get(x) if not isna(x) else None)
#      20 releaseData['release_country'].drop(["ReleaseCountryID"], axis=1, inplace=True)
#
# NameError: name 'areaData' is not defined

# %% [markdown]
# # Release-Group

# %%
colnames = {}
#colnames["release_group_alias_type"] = {0: "ReleaseGroupAliasTypeID", 1: "ReleaseGroupAliasTypeName"}
#colnames["release_group_alias"] = {0: "ReleaseGroupAliasID", 1: "NA1", 2: "ReleaseGroupAliasName", 3: "ReleaseGroupAliasLang", 7: "ReleaseGroupAliasName2"}
colnames["release_group_primary_type"] = {0: "ReleaseGroupPrimaryTypeID", 1: "ReleaseGroupPrimaryTypeName", 3: "NA3"}
colnames["release_group_secondary_type"] = {0: "ReleaseGroupSecondaryTypeID", 1: "ReleaseGroupSecondaryTypeName"}
colnames["release_group"] = {0: "ReleaseGroupID", 1: "ReleaseGroupGID", 2: "ReleaseGroupName", 3: "ArtistID", 4: "ReleaseGroupPrimaryTypeID", 5: "ReleaseGroupComment", 6: "NA6"}
colnames["release_group_secondary_type_join"] = {0: "ReleaseGroupID", 1: "ReleaseGroupSecondaryTypeID"}

ts = timestat("Loading Release Data")
files = [ifile for ifile in glob("mbdump/release*") if "group" in ifile]
releaseGroupData = getData(files, colnames)
releaseGroupData = setIndex(releaseGroupData)
ts.stop()

# %% [markdown]
# ## Append Data And Create Master ReleaseGroup DataFrame

# %%
tsReleaseGroup = timestat("Appending ReleaseGroup Data")

ts = timestat("Joining Secondary Type Names")
dReleaseGroupSecondaryTypeName = releaseGroupData['release_group_secondary_type']['ReleaseGroupSecondaryTypeName'].to_dict()
releaseGroupData['release_group_secondary_type_join']['ReleaseGroupSecondaryType'] = releaseGroupData['release_group_secondary_type_join']['ReleaseGroupSecondaryTypeID'].apply(lambda x: dReleaseGroupSecondaryTypeName.get(x) if not isna(x) else None)
releaseGroupData['release_group_secondary_type_join'].drop(["ReleaseGroupSecondaryTypeID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Primary Type Names")
dReleaseGroupPrimaryTypeName = releaseGroupData['release_group_primary_type']['ReleaseGroupPrimaryTypeName'].to_dict()
releaseGroupData['release_group']['ReleaseGroupPrimaryType'] = releaseGroupData['release_group']['ReleaseGroupPrimaryTypeID'].apply(lambda x: dReleaseGroupPrimaryTypeName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
releaseGroupData['release_group'].drop(["ReleaseGroupPrimaryTypeID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Release Group And Secondary Type Join Data")
releaseGroupData['release_group'] = releaseGroupData['release_group'].join(releaseGroupData['release_group_secondary_type_join'])
ts.stop()

ts = timestat("Dropping Last Columns")
releaseGroupData['release_group'].drop(["NA6", "ReleaseGroupComment"], axis=1, inplace=True)
ts.stop()


savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("ReleaseGroupDataFrame"))
ts = timestat("Saving Master ReleaseGroup DataFrame To {0} (~20 sec)".format(savename))
from fileIO import pickleIO
pickleIO().save(idata=releaseGroupData['release_group'], ifile=savename)
fsize = fileInfo(savename).fsize
print("Master ReleaseGroup DataFrame is {0}{1}".format(fsize[0], fsize[1]))
ts.stop()


tsReleaseGroup.stop()

del releaseGroupData

# %% [markdown]
# # Artist

# %%
colnames = {}
colnames["artist_credit"] = {0: "ArtistCreditID", 1: "ArtistCreditName", 2: "ArtistCreditNum", 3: "NA3"}
colnames["artist_type"] = {0: "ArtistTypeID", 1: "ArtistTypeName", 2: "NA2", 3: "NA3", 4: "ArtistTypeDescr", 5: "ArtistTypeGID"}
colnames["artist_isni"] = {0: "ArtistID", 1: "ISNICode"}
colnames["artist_alias_type"] = {0: "ArtistAliasTypeID", 1: "ArtistAliasTypeName", 5: "ArtistAliasTypeGID"}
colnames["artist_alias"] = {0: "ArtistAliasID", 1: "ArtistID", 2: "ArtistAliasName", 3: "ArtistAliasLang", 7: "ArtistAliasSortName"}
colnames["artist"] = {0: "ArtistID", 1: "ArtistGID", 2: "ArtistName", 3: "ArtistSortName",
                      4: "FormedYear", 5: "FormedMonth", 6: "FormedDay", 
                      7: "DisbandedYear", 8: "DisbandedMonth", 9: "DisbandedDay", 
                      10: "ArtistTypeID", 11: "CountryAreaID", 12: "GenderID", 13: "ArtistDescr", 14: "NA14", 17: "FoundedInAreaID", 18: "DisbandedInAreaID"}

ts = timestat("Loading Artist Data")
files = [ifile for ifile in glob("mbdump/artist*") if ifile not in ["mbdump/artist_credit_name"]]
artistData = getData(files, colnames)
artistData = setIndex(artistData)
ts.stop()

# %% [markdown]
# ## Append Data And Create Master Artist DataFrame

# %%
tsArtist = timestat("Appending Artist Data")

ts = timestat("Creating Formed/Disbanded DateTime For {0} Artists (~7 sec)".format(artistData['artist'].shape[0]))
artistData['artist']['Formed']    = convertToDatetime(artistData['artist']["FormedYear"], artistData['artist']["FormedMonth"], artistData['artist']["FormedDay"])
artistData['artist']['Disbanded'] = convertToDatetime(artistData['artist']["DisbandedYear"], artistData['artist']["DisbandedMonth"], artistData['artist']["DisbandedDay"])
artistData['artist'].drop(["FormedYear", "FormedMonth", "FormedDay", "DisbandedYear", "DisbandedMonth", "DisbandedDay"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Artist Type")
dArtistTypeName = artistData['artist_type']["ArtistTypeName"].to_dict()
artistData['artist']["ArtistType"] = artistData['artist']['ArtistTypeID'].apply(lambda x: dArtistTypeName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
artistData['artist'].drop(["ArtistTypeID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Gender Type")
artistData['artist']['Gender'] = artistData['artist']['GenderID'].apply(lambda x: dGenderName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
artistData['artist'].drop(["GenderID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining Area Type")
artistData['artist']["Country"]     = artistData['artist']['CountryAreaID'].apply(lambda x: dAreaName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
artistData['artist']["FormedIn"]    = artistData['artist']['FoundedInAreaID'].apply(lambda x: dAreaName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
artistData['artist']["DisbandedIn"] = artistData['artist']['DisbandedInAreaID'].apply(lambda x: dAreaName.get(int(x)) if (not isna(x) and x.isdigit()) else None)
artistData['artist'].drop(["CountryAreaID", "FoundedInAreaID", "DisbandedInAreaID"], axis=1, inplace=True)
ts.stop()

ts = timestat("Joining ISNI")
artistData['artist'] = artistData['artist'].join(artistData['artist_isni'])
ts.stop()

ts = timestat("Collecting and Joining Artist Aliases (~40 sec)")
artistAliases = DataFrame(Series({artistID: df["ArtistAliasName"].to_list() for artistID,df in artistData['artist_alias'].groupby("ArtistID")}))
artistAliases.columns = ["Aliases"]
artistData['artist'] = artistData['artist'].join(artistAliases)
ts.stop()


ts = timestat("Dropping Last Columns")
artistData['artist'].drop(["ArtistDescr", "NA14"], axis=1, inplace=True)
ts.stop()


savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("ArtistDataFrame"))
ts = timestat("Saving Master Artist DataFrame To {0} (~20 sec)".format(savename))
from fileIO import pickleIO
pickleIO().save(idata=artistData['artist'], ifile=savename)
#fsize = fileInfo(savename).fsize
#print("Master Artist DataFrame is {0}{1}".format(fsize[0], fsize[1]))
ts.stop()

tsArtist.stop()
#del artistData

# %%
artistData['artist'].head()

# %% [markdown]
# ## Artist <=> Work

# %%
colnames = {}
colnames["l_artist_work"] = {0: "LookupID", 1: "WorkGroupID", 2: "ArtistID", 3: "WorkID", 6: "NA6", 7: "NA7"}

ts = timestat("Loading Artist <=> Work Data")
files = [ifile for ifile in glob("mbdump/l_artist_work")]
lookupData = getData(files, colnames)
lookupData = setIndex(lookupData)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 21:36 for Loading Artist <=> Work Data
# Keys: dict_keys(['l_artist_work'])
# Keys: dict_keys(['l_artist_work'])
# Process [Loading Artist <=> Work Data] Took 2.5 Seconds

# %%
ts = timestat("Merging Artist <=> Work Lookup")
wData = workData['work'].reset_index()
lData = lookupData['l_artist_work'].reset_index()
mergedWorkData = merge(wData,lData,on='WorkID')
ts.stop()

ts = timestat("Dropping Last Columns")
mergedWorkData.drop(["WorkID", "LookupID", "NA6", "NA7"], axis=1, inplace=True)
ts.stop()

ts = timestat("Grouping By ArtistID (~31 sec)")
artistWorks = Series({artistID: list(zip(artistIDWorks["WorkGroupID"], artistIDWorks["WorkTypeName"], artistIDWorks["WorkName"])) for artistID,artistIDWorks in mergedWorkData.groupby(["ArtistID"])})
ts.stop()

savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("ArtistWorkDataFrame"))
ts = timestat("Saving Master Artist Work DataFrame To {0} (~6 sec)".format(savename))
from fileIO import pickleIO
pickleIO().save(idata=artistWorks, ifile=savename)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 21:36 for Merging Artist <=> Work Lookup
# Process [Merging Artist <=> Work Lookup] Took 0.9 Seconds
# Current Time is Sat Dec 11, 2021 21:36 for Dropping Last Columns
# Process [Dropping Last Columns] Took 0.3 Seconds
# Current Time is Sat Dec 11, 2021 21:36 for Grouping By ArtistID (~31 sec)
# Process [Grouping By ArtistID (~31 sec)] Took 31.2 Seconds
# Current Time is Sat Dec 11, 2021 21:37 for Saving Master Artist Work DataFrame To /Volumes/Seagate/DB/MusicBrainzData/ArtistWorkDataFrame.p (~26 sec)
# Process [Saving Master Artist Work DataFrame To /Volumes/Seagate/DB/MusicBrainzData/ArtistWorkDataFrame.p (~26 sec)] Took 6.2 Seconds

# %% [markdown]
# ## Artist <=> Recording

# %%
colnames = {}
colnames["l_artist_recording"] = {0: "LookupID", 1: "RecordingGroupID", 2: "ArtistID", 3: "RecordingID", 6: "NA6", 7: "NA7"}

ts = timestat("Loading Artist <=> Recording Data")
files = [ifile for ifile in glob("mbdump/l_artist_recording")]
lookupData = getData(files, colnames)
lookupData = setIndex(lookupData)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 21:50 for Loading Artist <=> Recording Data
# Keys: dict_keys(['l_artist_recording'])
# Keys: dict_keys(['l_artist_recording'])
# Process [Loading Artist <=> Recording Data] Took 29.2 Seconds

# %%
ts = timestat("Merging Artist <=> Recording Lookup (~16 sec)")
rData = recordingData['recording'].reset_index().drop(["ArtistID"], axis=1)
lData = lookupData['l_artist_recording'].reset_index()
mergedRecordingData = merge(rData,lData,on='RecordingID')
ts.stop()

ts = timestat("Dropping Last Columns")
mergedRecordingData.drop(["RecordingID", "RecordingGroupID", "LookupID", "NA6", "NA7"], axis=1, inplace=True)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 22:05 for Merging Artist <=> Recording Lookup (~16 sec)
# Process [Merging Artist <=> Recording Lookup (~16 sec)] Took 13.1 Seconds
# Current Time is Sat Dec 11, 2021 22:05 for Dropping Last Columns
# Process [Dropping Last Columns] Took 1.7 Seconds

# %%
ts = timestat("Grouping By ArtistID (~31 sec)")
artistRecordings = Series({artistID: list(zip(artistIDRecordings["RecordingName"], artistIDRecordings["TimeLength"])) for artistID,artistIDRecordings in mergedRecordingData.groupby(["ArtistID"])})
ts.stop()

savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("ArtistRecordingDataFrame"))
ts = timestat("Saving Master Artist Recording DataFrame To {0} (~54 sec)".format(savename))
from fileIO import pickleIO
pickleIO().save(idata=artistRecordings, ifile=savename)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 22:07 for Grouping By ArtistID (~31 sec)
# Process [Grouping By ArtistID (~31 sec)] Took 58.1 Seconds
# Current Time is Sat Dec 11, 2021 22:08 for Saving Master Artist Recording DataFrame To /Volumes/Seagate/DB/MusicBrainzData/ArtistRecordingDataFrame.p (~6 sec)
# Process [Saving Master Artist Recording DataFrame To /Volumes/Seagate/DB/MusicBrainzData/ArtistRecordingDataFrame.p (~6 sec)] Took 54.1 Seconds

# %% [markdown]
# ## Artist <=> Release

# %%
colnames = {}
colnames["l_artist_release"] = {0: "LookupID", 1: "ReleaseGroupID", 2: "ArtistID", 3: "ReleaseID", 6: "NA6", 7: "NA7"}

ts = timestat("Loading Artist <=> Release Data")
files = [ifile for ifile in glob("mbdump/l_artist_release")]
lookupData = getData(files, colnames)
lookupData = setIndex(lookupData)
ts.stop()
# Out:
# Current Time is Sat Dec 11, 2021 22:14 for Loading Artist <=> Release Data
# Keys: dict_keys(['l_artist_release'])
# Keys: dict_keys(['l_artist_release'])
# Process [Loading Artist <=> Release Data] Took 0.9 Seconds

# %%
from fileIO import fileIO
savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("ReleaseDataFrame"))
releaseData = fileIO().get(savename)

# %%
#lookupData['l_artist_release']
#releaseData
# Out:
#                                      ReleaseGID  \
# ReleaseID
# 9          425cf29a-1490-43ab-abfa-7b17a2cec351
# 10         a96e1d03-e685-3627-8cba-f5b96be7158f
# 12         9660928f-7cd8-4fef-852d-5599dc4ad3ec
# 26         dd245091-b21e-48a3-b59a-f9b8ed8a0469
# 49         bc9afecd-685e-482c-9412-27f2d267b1dd
# ...                                         ...
# 1293174    c5f1344a-00a6-4e92-94b6-457f0c3935b9
# 3206280    1ea28fc2-37f4-48ca-a1ce-33f1c5764be5
# 3206281    2f923f68-d213-4f30-8a18-6b4796f39c61
# 3206282    37d5c7c4-96fd-4245-9830-cf16a5bd3cbb
# 1047773    3fed2bc5-2a94-47da-a1b6-28e0eec30de2
#
#                                 ReleaseName  ArtistID  ReleaseGroupID  \
# ReleaseID
# 9                         A Sorta Fairytale        60          896742
# 10                        A Sorta Fairytale        60          896742
# 12                   Silent All These Years        60          104189
# 26                                   Demons     20211           94299
# 49                               Out Spaced     20211           94125
# ...                                     ...       ...             ...
# 1293174                                Hope      3002          197236
# 3206280    Book I: The End of Ancient Lands   3116008         2783720
# 3206281    Book I: The End of Ancient Lands   3116008         2783720
# 3206282    Book I: The End of Ancient Lands   3116008         2783720
# 1047773                       Peter Gabriel      1343          133050
#
#                  Packaging    Status              Language Script ReleaseDate  \
# ReleaseID
# 9                     None  Official               English   Latn  2002-10-14
# 10                    None  Official               English   Latn  2002-10-14
# 12                    None  Official               English   Latn         NaT
# 26                    None  Official               English   Latn  1998-04-01
# 49                    None  Official  [Multiple languages]   Latn  1998-11-23
# ...                    ...       ...                   ...    ...         ...
# 1293174    Super Jewel Box  Official               English   Latn  2008-05-21
# 3206280               None  Official                  None   None         NaT
# 3206281               None  Official                  None   None         NaT
# 3206282               None  Official                  None   None         NaT
# 1047773         Jewel Case  Official               English   Latn  2003-04-29
#
#                   Country
# ReleaseID
# 9                 Germany
# 10         United Kingdom
# 12                Germany
# 26                  Japan
# 49         United Kingdom
# ...                   ...
# 1293174     United States
# 3206280               NaN
# 3206281               NaN
# 3206282               NaN
# 1047773            Europe
#
# [3002066 rows x 10 columns]

# %% [markdown]
# ## Artist <=> URL

# %%
colnames = {}
colnames["l_artist_url"] = {0: "LookupID", 1: "URLGroupID", 2: "ArtistID", 3: "URLID", 6: "NA6", 7: "NA7"}

ts = timestat("Loading Artist <=> URL Data")
files = [ifile for ifile in glob("mbdump/l_artist_url")]
lookupData = getData(files, colnames)
lookupData = setIndex(lookupData)
ts.stop()

# %%
ts = timestat("Joining URLs")
lookupData['l_artist_url']["URL"] = lookupData['l_artist_url']['URLID'].apply(lambda x: urlData['url']["URLName"].get(x))
ts.stop()

urlType={'26038': 'Discogs',
 '26039': 'Myspace',
 '26040': 'IMDB',
 '26041': 'Wikipedia',
 '26042': 'Artist',
 '26048': 'LastFMMisc',
 '26052': 'Apple',
 '26055': 'YouTube',
 '26056': 'Facebook',
 '26062': 'GeniusMisc',
 '26068': 'VGMDB',
 '26316': 'DeezerSpotify',
 '28613': 'AllMusic',
 '30134': 'Soundcloud',
 '41329': 'Video',
 '49052': 'RateYourMusicMisc',
 '94979': 'SecondhandSongs',
 '106477': 'VIAG',
 '117675': 'Wikidata',
 '139284': 'Bandcamp',
 '195003': 'IMSLP',
 '199852': 'Songkick',
 '204138': 'Setlist.fm',
 '215573': 'Last.fm',
 '240791': 'BandsInTown',
 '624633': 'AppleTidalNapster',
 '697028': 'PureVolume',
 '732275': 'CDBaby',
 '748510': 'GooglePlus',
 '753046': 'GooglePlay',
 '771457': 'BBC'}

def getURLGroupName(url):
    if "discogs." in url:
        return "Discogs"
    elif "myspace." in url:
        return "Myspace"
    elif "imdb." in url:
        return "IMDB"
    elif "youtube." in url:
        return "YouTube"
    elif "allmusic." in url:
        return "AllMusic"
    elif "last.fm" in url:
        return "LastFM"
    elif "soundcloud." in url:
        return "Soundcloud"
    elif "directlyrics." in url:
        return "DirectLyrics"
    elif "facebook." in url:
        return "Facebook"
    elif "tumblr." in url:
        return "Tumblr"
    elif "viaf." in url:
        return "VIAF"
    elif "wikidata." in url:
        return "Wikidata"
    elif "rateyourmusic." in url:
        return "RateYourMusic"
    elif "muzikum." in url:
        return "Muzikum"
    elif "spotify." in url:
        return "Spotify"
    elif "archive." in url:
        return "Archive"
    elif "play.google." in url:
        return "GooglePlay"
    elif "genius." in url:
        return "Genius"
    elif "musicmoz." in url:
        return "Musicmoz"
    elif "imvdb." in url:
        return "IMVBD"
    elif "musik-sammler." in url:
        return "MusikSammler"
    elif "whosampled." in url:
        return "WhoSampled"
    elif "setlist." in url:
        return "SetListFM"
    elif "secondhandsongs." in url:
        return "SecondhandSongs"
    elif "apple." in url:
        return "Apple"
    elif "deezer." in url:
        return "Deezer"
    elif "twitter." in url:
        return "Twitter"
    elif "songkick." in url:
        return "Songkick"
    elif "instagram." in url:
        return "Instagram"
    elif "tidal." in url:
        return "Tidal"
    elif "bbc." in url:
        return "BBC"
    elif "musixmatch." in url:
        return "MusixMatch"
    elif "napster." in url:
        return "Napster"
    elif "junodownload." in url:
        return "JunoDownload"
    elif "beatport." in url:
        return "Beatport"
    elif "bandsintown." in url:
        return "BandsInTown"
    elif "bandcamp." in url:
        return "BandCamp"
    else:
        return "Misc"

def getURLType(urlGroupID):
    urlGroupName = urlType.get(str(urlGroupID),"Misc")
    return urlGroupName

ts = timestat("Getting URL Group Name")
lookupData['l_artist_url']['URLGroupName'] = lookupData['l_artist_url']['URL'].apply(getURLGroupName)
ts.stop()

ts = timestat("Dropping Last Columns")
lookupData['l_artist_url'].drop(["NA6", "NA7"], axis=1, inplace=True)
ts.stop()

ts = timestat("Grouping By ArtistID (~2 min)")
artistURLs = Series({artistID: list(zip(artistIDURLs["URLGroupName"], artistIDURLs["URL"])) for artistID,artistIDURLs in lookupData['l_artist_url'].groupby(["ArtistID"])})
ts.stop()

savedir = setDir(basedir, "MusicBrainzData")
savename = setFile(savedir, "{0}.p".format("ArtistURLDataFrame"))
ts = timestat("Saving Master Artist URL DataFrame To {0} (~11 sec)".format(savename))
from fileIO import pickleIO
pickleIO().save(idata=artistURLs, ifile=savename)
ts.stop()

# %% [markdown]
# # Master Artist Summary Data

# %%
masterArtistRecordingData[2229589]
# Out:
# [('漸漸', '278000'), ('RUN', '251000'), ('龍舌蘭', '285000'), ('我們萬歲', '236000')]

# %%
str("龍舌蘭")
# Out:
# '龍舌蘭'

# %%
masterArtistData[masterArtistData["ArtistGID"] == "c4596d2d-de50-4388-aca3-f9abb313918d"]
# Out:
#                                     ArtistGID ArtistName ArtistSortName  \
# 2229589  c4596d2d-de50-4388-aca3-f9abb313918d         米巍        Mi, Wei
#
#         Formed Disbanded ArtistType Gender Country FormedIn DisbandedIn  \
# 2229589    NaT       NaT     Person   None   China     None        None
#
#         ISNICode Aliases                               MyArtistID
# 2229589      NaN     NaN  251108434349887660386335524263902329399

# %%
from fsUtils import dirUtil

savedir = dirUtil(basedir).join("MusicBrainzData")
io = fileIO()
ts = timestat("Loading Master Data (~3 sec)")
masterArtistData          = io.get(setFile(savedir, "{0}.p".format("ArtistDataFrame")))
masterReleaseGroupData    = io.get(setFile(savedir, "{0}.p".format("ReleaseGroupDataFrame")))
masterArtistRecordingData = io.get(setFile(savedir, "{0}.p".format("ArtistRecordingDataFrame")))
masterArtistWorkData      = io.get(setFile(savedir, "{0}.p".format("ArtistWorkDataFrame")))
masterArtistURLData       = io.get(setFile(savedir, "{0}.p".format("ArtistURLDataFrame")))
ts.stop()
# Out:
# Current Time is Mon Dec 13, 2021 12:27 for Loading Master Data (~35 sec)
# Process [Loading Master Data (~35 sec)] Took 29.8 Seconds

# %%
Nmod = 100

# %%
from dbArtistsID import artistIDMusicBrainz
mbID = artistIDMusicBrainz()
ts = timestat("Setting My ArtistID From MusicBrainz GID (~12 sec)")
masterArtistData["MyArtistID"] = masterArtistData['ArtistGID'].apply(mbID.getArtistID)
ts.stop()
# Out:
# Current Time is Mon Dec 13, 2021 12:32 for Setting My ArtistID From MusicBrainz GID
# Process [Setting My ArtistID From MusicBrainz GID] Took 12.2 Seconds

# %%
def createReleaseGroupKey(x):
    key = None
    primary   = x['ReleaseGroupPrimaryType']
    secondary = x['ReleaseGroupSecondaryType']
    if isinstance(primary, str) and isinstance(secondary, str):
        key = " + ".join([primary, secondary])
    elif isinstance(primary, str):
        key = primary
    elif isinstance(secondary, str):
        key = secondary
    else:
        key = "Unknown"
    return key
    
ts = timestat("Setting ReleaseGroup Key (~1/2 min)")
masterReleaseGroupData["ReleaseGroupKey"] = masterReleaseGroupData.apply(createReleaseGroupKey, axis=1)
ts.stop()
# Out:
# Current Time is Mon Dec 13, 2021 12:33 for Setting ReleaseGroup Key (~1 min)
# Process [Setting ReleaseGroup Key (~1 min)] Took 23.2 Seconds

# %%
from artistDBBase import artistDBBase, artistDBDataClass
from artistDBBase import artistDBNameClass, artistDBMetaClass, artistDBIDClass, artistDBURLClass, artistDBPageClass
from artistDBBase import artistDBProfileClass, artistDBMediaClass, artistDBMediaAlbumClass
from artistDBBase import artistDBMediaDataClass, artistDBMediaCountsClass, artistDBFileInfoClass
from artistDBBase import artistDBTextClass, artistDBLinkClass
from strUtils import fixName
from dbUtils import utilsDiscogs
from hashlib import md5

def getMediaCounts(media):
    amcc = artistDBMediaCountsClass()

    credittype = "Releases"
    if amcc.counts.get(credittype) == None:
        amcc.counts[credittype] = {}
    for creditsubtype in media.media.keys():
        amcc.counts[credittype][creditsubtype] = int(len(media.media[creditsubtype]))

    return amcc

savedir = setDir(basedir, "MusicBrainzMetadata")
tsAll = timestat("Creating DB Data")
Nmod = 100
for n,modVal in enumerate(range(Nmod)):
    ts = timestat("Creating ModData Subset")
    artistModData = masterArtistData[masterArtistData["MyArtistID"].apply(lambda x: int(x)%Nmod) == modVal]
    releaseGroupModData = masterReleaseGroupData[masterReleaseGroupData["ArtistID"].isin(artistModData.index)]
    ts.stop()

    modValData = {}
    N = artistModData.shape[0]
    tsMod = timestat("Creating DB Data From {0} Artists For ModVal={1}".format(N,modVal))
    for i,(artistID,artistData) in enumerate(artistModData.iterrows()):
        artistName  = str(artistData["ArtistName"])
        artistGID   = artistData['ArtistGID']
        artistURL   = "https://musicbrainz.org/artist/{0}".format(artistGID)
        myID        = artistData["MyArtistID"]
        #if artistGID != "070d193a-845c-479f-980e-bef15710653e":
        #    continue
        #if myID != '251108434349887660386335524263902329399':
        #    continue

        generalData = {}
        generalData["SortName"]   = artistData["ArtistSortName"]
        generalData["Aliases"]    = artistData["Aliases"]
        generalData["Gender"]     = artistData["Gender"]
        generalData["County"]     = artistData["Country"]
        generalData["Formed"]     = artistData["Formed"]
        generalData["Disbanded"]  = artistData["Disbanded"]
        generalData["ArtistType"] = artistData["ArtistType"]
        generalData["ISNI"]       = artistData["ISNICode"]
        generalData = {k: v for k,v in generalData.items() if v is not None}
        generalData = generalData if len(generalData) > 0 else None

        
        ########################################################################
        # Get URLs
        ########################################################################
        externalData = {}
        artistURLs = masterArtistURLData.get(artistID, [])
        for (urlType,url) in artistURLs:
            adblink      = artistDBLinkClass(None)
            adblink.href = url
            adblink.err  = None
            if externalData.get(urlType) is None:
                externalData[urlType] = []
            externalData[urlType].append(adblink)
        externalData = externalData if len(externalData) > 0 else None
        
            
        
        ########################################################################
        # Get Release Groups
        ########################################################################
        artistReleaseGroupData = releaseGroupModData[releaseGroupModData["ArtistID"] == artistID]
        mediaData = {}
        for mediaName,mediaNameData in artistReleaseGroupData.groupby("ReleaseGroupKey"):
            mediaData[mediaName] = []
            for code, releaseGroupInfo in mediaNameData.iterrows():
                album        = releaseGroupInfo['ReleaseGroupName']
                albumURL     = "https://musicbrainz.org/releasegroup/{0}".format(releaseGroupInfo['ReleaseGroupGID'])
                albumArtists = [artistName]
            
                amdc = artistDBMediaDataClass(album=album, url=albumURL, artist=albumArtists, code=code, year=None)
                mediaData[mediaName].append(amdc)
                
            
        ########################################################################
        # Get Works
        ########################################################################
        artistWorks = masterArtistWorkData.get(artistID)  
        if artistWorks:
            for workID,workType,workName in artistWorks:
                mediaName = "OtherWork" if workType is None else workType
                if mediaData.get(mediaName) is None:
                    mediaData[mediaName] = []
                m = md5()
                codes = {}
                m.update(str(workID).encode('utf-8'))
                m.update(str(mediaName).encode('utf-8'))
                m.update(str(workName).encode('utf-8'))
                hashval = m.hexdigest()
                code    = str(int(hashval, 16) % int(1e6))
                if codes.get(code) is not None:
                    continue
                codes[code] = True

                amdc = artistDBMediaDataClass(album=str(workName), url=None, artist=None, code=code, year=None)
                mediaData[mediaName].append(amdc)
                
            
        ########################################################################
        # Get Recordings
        ########################################################################
        artistRecordings = masterArtistRecordingData.get(artistID)        
        artistRecordings = Series(artistRecordings).drop_duplicates()
        if len(artistRecordings) > 0:
            mediaName = "Recordings"
            if mediaData.get(mediaName) is None:
                mediaData[mediaName] = []
            codes = {}
            for idx,(recName,recTime) in artistRecordings.iteritems():
                m = md5()
                m.update(str(recName).encode('utf-8'))
                m.update(str(recTime).encode('utf-8'))
                hashval = m.hexdigest()
                code    = str(int(hashval, 16) % int(1e6))
                if codes.get(code) is not None:
                    continue
                codes[code] = True
                
                amdc = artistDBMediaDataClass(album=str(recName), url=None, artist=None, code=code, year=None)
                mediaData[mediaName].append(amdc)

        
        artist      = artistDBNameClass(name=artistName, err=None)
        meta        = artistDBMetaClass(title=None, url=artistURL)
        url         = artistDBURLClass(url=artistURL)
        ID          = artistDBIDClass(ID=myID)
        pages       = artistDBPageClass(ppp=1, tot=1, redo=False, more=False)
        profile     = artistDBProfileClass(general=generalData, external=externalData)
        media       = artistDBMediaClass()
        media.media = mediaData
        mediaCounts = getMediaCounts(media)
        info        = artistDBFileInfoClass(info=None)
        
        modValData[myID] = artistDBDataClass(artist=artist, meta=meta, url=url, ID=ID, pages=pages, profile=profile, mediaCounts=mediaCounts, media=media, info=info)
        if (i+1) % 7500 == 0 or (i+1) == 2500:
            tsMod.update(n=i+1, N=N)
    tsMod.stop()
            
    outdir = setDir(basedir, "MusicBrainzDBData")
    io.save(idata=Series(modValData), ifile=setFile(outdir, "{0}-{1}.p".format(modVal, "DB")))
    tsAll.update(n=n, N=Nmod)
    print("\n")
tsAll.stop()
# Out:
# Current Time is Wed Dec 15, 2021 12:13 for Creating DB Data
# Current Time is Wed Dec 15, 2021 12:13 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:13 for Creating DB Data From 18813 Artists For ModVal=0
# 2500/18813 : Process [Creating DB Data From 18813 Artists For ModVal=0] Has Run For 3.6 Seconds.  ETA is 23.5 Seconds
# 7500/18813 : Process [Creating DB Data From 18813 Artists For ModVal=0] Has Run For 9.7 Seconds.  ETA is 14.6 Seconds
# 15000/18813 : Process [Creating DB Data From 18813 Artists For ModVal=0] Has Run For 17.8 Seconds.  ETA is 4.5 Seconds
# Process [Creating DB Data From 18813 Artists For ModVal=0] Took 21.8 Seconds
# 0/100      : Process [Creating DB Data] Has Run For 25.6 Seconds.  ETA is ? Seconds
#
#
# Current Time is Wed Dec 15, 2021 12:14 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:14 for Creating DB Data From 18789 Artists For ModVal=1
# 2500/18789 : Process [Creating DB Data From 18789 Artists For ModVal=1] Has Run For 3.6 Seconds.  ETA is 23.5 Seconds
# 7500/18789 : Process [Creating DB Data From 18789 Artists For ModVal=1] Has Run For 9.0 Seconds.  ETA is 13.5 Seconds
# 15000/18789 : Process [Creating DB Data From 18789 Artists For ModVal=1] Has Run For 17.6 Seconds.  ETA is 4.4 Seconds
# Process [Creating DB Data From 18789 Artists For ModVal=1] Took 21.6 Seconds
# 1/100      : Process [Creating DB Data] Has Run For 51.2 Seconds.  ETA is 5068.8 Seconds
#
#
# Current Time is Wed Dec 15, 2021 12:14 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.2 Seconds
# Current Time is Wed Dec 15, 2021 12:14 for Creating DB Data From 18675 Artists For ModVal=2
# 2500/18675 : Process [Creating DB Data From 18675 Artists For ModVal=2] Has Run For 3.6 Seconds.  ETA is 23.3 Seconds
# 7500/18675 : Process [Creating DB Data From 18675 Artists For ModVal=2] Has Run For 9.1 Seconds.  ETA is 13.6 Seconds
# 15000/18675 : Process [Creating DB Data From 18675 Artists For ModVal=2] Has Run For 17.6 Seconds.  ETA is 4.3 Seconds
# Process [Creating DB Data From 18675 Artists For ModVal=2] Took 21.3 Seconds
# 2/100      : Process [Creating DB Data] Has Run For 1.3 Minutes.  ETA is 63.7 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:14 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:14 for Creating DB Data From 18937 Artists For ModVal=3
# 2500/18937 : Process [Creating DB Data From 18937 Artists For ModVal=3] Has Run For 3.8 Seconds.  ETA is 25.0 Seconds
# 7500/18937 : Process [Creating DB Data From 18937 Artists For ModVal=3] Has Run For 9.5 Seconds.  ETA is 14.5 Seconds
# 15000/18937 : Process [Creating DB Data From 18937 Artists For ModVal=3] Has Run For 17.2 Seconds.  ETA is 4.5 Seconds
# Process [Creating DB Data From 18937 Artists For ModVal=3] Took 21.2 Seconds
# 3/100      : Process [Creating DB Data] Has Run For 1.7 Minutes.  ETA is 55.0 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:15 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:15 for Creating DB Data From 19004 Artists For ModVal=4
# 2500/19004 : Process [Creating DB Data From 19004 Artists For ModVal=4] Has Run For 4.3 Seconds.  ETA is 28.4 Seconds
# 7500/19004 : Process [Creating DB Data From 19004 Artists For ModVal=4] Has Run For 10.0 Seconds.  ETA is 15.3 Seconds
# 15000/19004 : Process [Creating DB Data From 19004 Artists For ModVal=4] Has Run For 18.1 Seconds.  ETA is 4.8 Seconds
# Process [Creating DB Data From 19004 Artists For ModVal=4] Took 22.1 Seconds
# 4/100      : Process [Creating DB Data] Has Run For 2.1 Minutes.  ETA is 50.4 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:15 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:15 for Creating DB Data From 18861 Artists For ModVal=5
# 2500/18861 : Process [Creating DB Data From 18861 Artists For ModVal=5] Has Run For 4.4 Seconds.  ETA is 28.8 Seconds
# 7500/18861 : Process [Creating DB Data From 18861 Artists For ModVal=5] Has Run For 10.0 Seconds.  ETA is 15.1 Seconds
# 15000/18861 : Process [Creating DB Data From 18861 Artists For ModVal=5] Has Run For 18.3 Seconds.  ETA is 4.7 Seconds
# Process [Creating DB Data From 18861 Artists For ModVal=5] Took 22.2 Seconds
# 5/100      : Process [Creating DB Data] Has Run For 2.6 Minutes.  ETA is 49.4 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:16 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:16 for Creating DB Data From 18681 Artists For ModVal=6
# 2500/18681 : Process [Creating DB Data From 18681 Artists For ModVal=6] Has Run For 4.3 Seconds.  ETA is 27.8 Seconds
# 7500/18681 : Process [Creating DB Data From 18681 Artists For ModVal=6] Has Run For 9.7 Seconds.  ETA is 14.5 Seconds
# 15000/18681 : Process [Creating DB Data From 18681 Artists For ModVal=6] Has Run For 17.7 Seconds.  ETA is 4.3 Seconds
# Process [Creating DB Data From 18681 Artists For ModVal=6] Took 21.7 Seconds
# 6/100      : Process [Creating DB Data] Has Run For 3.0 Minutes.  ETA is 47.0 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:16 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:16 for Creating DB Data From 18917 Artists For ModVal=7
# 2500/18917 : Process [Creating DB Data From 18917 Artists For ModVal=7] Has Run For 4.4 Seconds.  ETA is 28.9 Seconds
# 7500/18917 : Process [Creating DB Data From 18917 Artists For ModVal=7] Has Run For 10.0 Seconds.  ETA is 15.2 Seconds
# 15000/18917 : Process [Creating DB Data From 18917 Artists For ModVal=7] Has Run For 18.1 Seconds.  ETA is 4.7 Seconds
# Process [Creating DB Data From 18917 Artists For ModVal=7] Took 22.6 Seconds
# 7/100      : Process [Creating DB Data] Has Run For 3.4 Minutes.  ETA is 45.2 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:17 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:17 for Creating DB Data From 18663 Artists For ModVal=8
# 2500/18663 : Process [Creating DB Data From 18663 Artists For ModVal=8] Has Run For 3.9 Seconds.  ETA is 25.2 Seconds
# 7500/18663 : Process [Creating DB Data From 18663 Artists For ModVal=8] Has Run For 10.1 Seconds.  ETA is 15.0 Seconds
# 15000/18663 : Process [Creating DB Data From 18663 Artists For ModVal=8] Has Run For 17.8 Seconds.  ETA is 4.3 Seconds
# Process [Creating DB Data From 18663 Artists For ModVal=8] Took 21.4 Seconds
# 8/100      : Process [Creating DB Data] Has Run For 3.9 Minutes.  ETA is 44.8 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:17 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:17 for Creating DB Data From 18882 Artists For ModVal=9
# 2500/18882 : Process [Creating DB Data From 18882 Artists For ModVal=9] Has Run For 3.7 Seconds.  ETA is 24.2 Seconds
# 7500/18882 : Process [Creating DB Data From 18882 Artists For ModVal=9] Has Run For 10.2 Seconds.  ETA is 15.5 Seconds
# 15000/18882 : Process [Creating DB Data From 18882 Artists For ModVal=9] Has Run For 17.9 Seconds.  ETA is 4.6 Seconds
# Process [Creating DB Data From 18882 Artists For ModVal=9] Took 21.7 Seconds
# 9/100      : Process [Creating DB Data] Has Run For 4.3 Minutes.  ETA is 43.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:17 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:17 for Creating DB Data From 18798 Artists For ModVal=10
# 2500/18798 : Process [Creating DB Data From 18798 Artists For ModVal=10] Has Run For 3.7 Seconds.  ETA is 24.1 Seconds
# 7500/18798 : Process [Creating DB Data From 18798 Artists For ModVal=10] Has Run For 9.2 Seconds.  ETA is 13.9 Seconds
# 15000/18798 : Process [Creating DB Data From 18798 Artists For ModVal=10] Has Run For 18.0 Seconds.  ETA is 4.6 Seconds
# Process [Creating DB Data From 18798 Artists For ModVal=10] Took 21.7 Seconds
# 10/100     : Process [Creating DB Data] Has Run For 4.7 Minutes.  ETA is 42.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:18 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:18 for Creating DB Data From 18920 Artists For ModVal=11
# 2500/18920 : Process [Creating DB Data From 18920 Artists For ModVal=11] Has Run For 3.7 Seconds.  ETA is 24.3 Seconds
# 7500/18920 : Process [Creating DB Data From 18920 Artists For ModVal=11] Has Run For 9.1 Seconds.  ETA is 13.9 Seconds
# 15000/18920 : Process [Creating DB Data From 18920 Artists For ModVal=11] Has Run For 17.9 Seconds.  ETA is 4.7 Seconds
# Process [Creating DB Data From 18920 Artists For ModVal=11] Took 22.0 Seconds
# 11/100     : Process [Creating DB Data] Has Run For 5.1 Minutes.  ETA is 41.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:18 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:18 for Creating DB Data From 18954 Artists For ModVal=12
# 2500/18954 : Process [Creating DB Data From 18954 Artists For ModVal=12] Has Run For 3.6 Seconds.  ETA is 23.7 Seconds
# 7500/18954 : Process [Creating DB Data From 18954 Artists For ModVal=12] Has Run For 9.3 Seconds.  ETA is 14.2 Seconds
# 15000/18954 : Process [Creating DB Data From 18954 Artists For ModVal=12] Has Run For 17.8 Seconds.  ETA is 4.7 Seconds
# Process [Creating DB Data From 18954 Artists For ModVal=12] Took 23.2 Seconds
# 12/100     : Process [Creating DB Data] Has Run For 5.6 Minutes.  ETA is 41.1 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:19 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:19 for Creating DB Data From 18807 Artists For ModVal=13
# 2500/18807 : Process [Creating DB Data From 18807 Artists For ModVal=13] Has Run For 5.7 Seconds.  ETA is 37.2 Seconds
# 7500/18807 : Process [Creating DB Data From 18807 Artists For ModVal=13] Has Run For 11.1 Seconds.  ETA is 16.7 Seconds
# 15000/18807 : Process [Creating DB Data From 18807 Artists For ModVal=13] Has Run For 18.4 Seconds.  ETA is 4.7 Seconds
# Process [Creating DB Data From 18807 Artists For ModVal=13] Took 22.0 Seconds
# 13/100     : Process [Creating DB Data] Has Run For 6.0 Minutes.  ETA is 40.2 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:19 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:19 for Creating DB Data From 19029 Artists For ModVal=14
# 2500/19029 : Process [Creating DB Data From 19029 Artists For ModVal=14] Has Run For 4.4 Seconds.  ETA is 29.1 Seconds
# 7500/19029 : Process [Creating DB Data From 19029 Artists For ModVal=14] Has Run For 13.3 Seconds.  ETA is 20.4 Seconds
# 15000/19029 : Process [Creating DB Data From 19029 Artists For ModVal=14] Has Run For 24.8 Seconds.  ETA is 6.7 Seconds
# Process [Creating DB Data From 19029 Artists For ModVal=14] Took 30.5 Seconds
# 14/100     : Process [Creating DB Data] Has Run For 6.6 Minutes.  ETA is 40.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:20 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.2 Seconds
# Current Time is Wed Dec 15, 2021 12:20 for Creating DB Data From 18675 Artists For ModVal=15
# 2500/18675 : Process [Creating DB Data From 18675 Artists For ModVal=15] Has Run For 5.8 Seconds.  ETA is 37.5 Seconds
# 7500/18675 : Process [Creating DB Data From 18675 Artists For ModVal=15] Has Run For 11.0 Seconds.  ETA is 16.4 Seconds
# 15000/18675 : Process [Creating DB Data From 18675 Artists For ModVal=15] Has Run For 18.3 Seconds.  ETA is 4.5 Seconds
# Process [Creating DB Data From 18675 Artists For ModVal=15] Took 21.8 Seconds
# 15/100     : Process [Creating DB Data] Has Run For 7.1 Minutes.  ETA is 40.2 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:20 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:20 for Creating DB Data From 18727 Artists For ModVal=16
# 2500/18727 : Process [Creating DB Data From 18727 Artists For ModVal=16] Has Run For 4.5 Seconds.  ETA is 29.2 Seconds
# 7500/18727 : Process [Creating DB Data From 18727 Artists For ModVal=16] Has Run For 14.1 Seconds.  ETA is 21.1 Seconds
# 15000/18727 : Process [Creating DB Data From 18727 Artists For ModVal=16] Has Run For 23.5 Seconds.  ETA is 5.8 Seconds
# Process [Creating DB Data From 18727 Artists For ModVal=16] Took 27.0 Seconds
# 16/100     : Process [Creating DB Data] Has Run For 7.6 Minutes.  ETA is 39.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:21 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:21 for Creating DB Data From 18859 Artists For ModVal=17
# 2500/18859 : Process [Creating DB Data From 18859 Artists For ModVal=17] Has Run For 3.5 Seconds.  ETA is 22.9 Seconds
# 7500/18859 : Process [Creating DB Data From 18859 Artists For ModVal=17] Has Run For 9.9 Seconds.  ETA is 15.0 Seconds
# 15000/18859 : Process [Creating DB Data From 18859 Artists For ModVal=17] Has Run For 19.2 Seconds.  ETA is 4.9 Seconds
# Process [Creating DB Data From 18859 Artists For ModVal=17] Took 23.4 Seconds
# 17/100     : Process [Creating DB Data] Has Run For 8.0 Minutes.  ETA is 39.1 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:21 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.5 Seconds
# Current Time is Wed Dec 15, 2021 12:21 for Creating DB Data From 18791 Artists For ModVal=18
# 2500/18791 : Process [Creating DB Data From 18791 Artists For ModVal=18] Has Run For 5.0 Seconds.  ETA is 32.6 Seconds
# 7500/18791 : Process [Creating DB Data From 18791 Artists For ModVal=18] Has Run For 11.3 Seconds.  ETA is 17.0 Seconds
# 15000/18791 : Process [Creating DB Data From 18791 Artists For ModVal=18] Has Run For 20.2 Seconds.  ETA is 5.1 Seconds
# Process [Creating DB Data From 18791 Artists For ModVal=18] Took 25.9 Seconds
# 18/100     : Process [Creating DB Data] Has Run For 8.5 Minutes.  ETA is 38.7 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:22 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.5 Seconds
# Current Time is Wed Dec 15, 2021 12:22 for Creating DB Data From 18866 Artists For ModVal=19
# 2500/18866 : Process [Creating DB Data From 18866 Artists For ModVal=19] Has Run For 4.3 Seconds.  ETA is 28.1 Seconds
# 7500/18866 : Process [Creating DB Data From 18866 Artists For ModVal=19] Has Run For 9.4 Seconds.  ETA is 14.2 Seconds
# 15000/18866 : Process [Creating DB Data From 18866 Artists For ModVal=19] Has Run For 17.4 Seconds.  ETA is 4.5 Seconds
# Process [Creating DB Data From 18866 Artists For ModVal=19] Took 21.1 Seconds
# 19/100     : Process [Creating DB Data] Has Run For 9.0 Minutes.  ETA is 38.4 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:22 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:22 for Creating DB Data From 18929 Artists For ModVal=20
# 2500/18929 : Process [Creating DB Data From 18929 Artists For ModVal=20] Has Run For 3.6 Seconds.  ETA is 23.7 Seconds
# 7500/18929 : Process [Creating DB Data From 18929 Artists For ModVal=20] Has Run For 9.0 Seconds.  ETA is 13.7 Seconds
# 15000/18929 : Process [Creating DB Data From 18929 Artists For ModVal=20] Has Run For 18.6 Seconds.  ETA is 4.9 Seconds
# Process [Creating DB Data From 18929 Artists For ModVal=20] Took 22.6 Seconds
# 20/100     : Process [Creating DB Data] Has Run For 9.4 Minutes.  ETA is 37.6 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:23 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:23 for Creating DB Data From 19049 Artists For ModVal=21
# 2500/19049 : Process [Creating DB Data From 19049 Artists For ModVal=21] Has Run For 3.7 Seconds.  ETA is 24.5 Seconds
# 7500/19049 : Process [Creating DB Data From 19049 Artists For ModVal=21] Has Run For 9.6 Seconds.  ETA is 14.8 Seconds
# 15000/19049 : Process [Creating DB Data From 19049 Artists For ModVal=21] Has Run For 20.4 Seconds.  ETA is 5.5 Seconds
# Process [Creating DB Data From 19049 Artists For ModVal=21] Took 25.0 Seconds
# 21/100     : Process [Creating DB Data] Has Run For 9.9 Minutes.  ETA is 37.2 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:23 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:23 for Creating DB Data From 18856 Artists For ModVal=22
# 2500/18856 : Process [Creating DB Data From 18856 Artists For ModVal=22] Has Run For 4.1 Seconds.  ETA is 26.8 Seconds
# 7500/18856 : Process [Creating DB Data From 18856 Artists For ModVal=22] Has Run For 9.2 Seconds.  ETA is 13.9 Seconds
# 15000/18856 : Process [Creating DB Data From 18856 Artists For ModVal=22] Has Run For 17.1 Seconds.  ETA is 4.4 Seconds
# Process [Creating DB Data From 18856 Artists For ModVal=22] Took 20.7 Seconds
# 22/100     : Process [Creating DB Data] Has Run For 10.3 Minutes.  ETA is 36.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:23 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:23 for Creating DB Data From 18833 Artists For ModVal=23
# 2500/18833 : Process [Creating DB Data From 18833 Artists For ModVal=23] Has Run For 4.8 Seconds.  ETA is 31.4 Seconds
# 7500/18833 : Process [Creating DB Data From 18833 Artists For ModVal=23] Has Run For 11.2 Seconds.  ETA is 16.9 Seconds
# 15000/18833 : Process [Creating DB Data From 18833 Artists For ModVal=23] Has Run For 19.2 Seconds.  ETA is 4.9 Seconds
# Process [Creating DB Data From 18833 Artists For ModVal=23] Took 24.1 Seconds
# 23/100     : Process [Creating DB Data] Has Run For 10.8 Minutes.  ETA is 36.2 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:24 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.3 Seconds
# Current Time is Wed Dec 15, 2021 12:24 for Creating DB Data From 18771 Artists For ModVal=24
# 2500/18771 : Process [Creating DB Data From 18771 Artists For ModVal=24] Has Run For 5.4 Seconds.  ETA is 35.1 Seconds
# 7500/18771 : Process [Creating DB Data From 18771 Artists For ModVal=24] Has Run For 12.4 Seconds.  ETA is 18.6 Seconds
# 15000/18771 : Process [Creating DB Data From 18771 Artists For ModVal=24] Has Run For 20.6 Seconds.  ETA is 5.2 Seconds
# Process [Creating DB Data From 18771 Artists For ModVal=24] Took 24.1 Seconds
# 24/100     : Process [Creating DB Data] Has Run For 11.2 Minutes.  ETA is 35.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:24 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:24 for Creating DB Data From 18856 Artists For ModVal=25
# 2500/18856 : Process [Creating DB Data From 18856 Artists For ModVal=25] Has Run For 3.7 Seconds.  ETA is 24.2 Seconds
# 7500/18856 : Process [Creating DB Data From 18856 Artists For ModVal=25] Has Run For 11.5 Seconds.  ETA is 17.4 Seconds
# 15000/18856 : Process [Creating DB Data From 18856 Artists For ModVal=25] Has Run For 19.2 Seconds.  ETA is 4.9 Seconds
# Process [Creating DB Data From 18856 Artists For ModVal=25] Took 22.8 Seconds
# 25/100     : Process [Creating DB Data] Has Run For 11.7 Minutes.  ETA is 35.1 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:25 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:25 for Creating DB Data From 18824 Artists For ModVal=26
# 2500/18824 : Process [Creating DB Data From 18824 Artists For ModVal=26] Has Run For 5.8 Seconds.  ETA is 37.9 Seconds
# 7500/18824 : Process [Creating DB Data From 18824 Artists For ModVal=26] Has Run For 15.6 Seconds.  ETA is 23.6 Seconds
# 15000/18824 : Process [Creating DB Data From 18824 Artists For ModVal=26] Has Run For 23.2 Seconds.  ETA is 5.9 Seconds
# Process [Creating DB Data From 18824 Artists For ModVal=26] Took 28.1 Seconds
# 26/100     : Process [Creating DB Data] Has Run For 12.2 Minutes.  ETA is 34.7 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:25 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:25 for Creating DB Data From 18809 Artists For ModVal=27
# 2500/18809 : Process [Creating DB Data From 18809 Artists For ModVal=27] Has Run For 3.6 Seconds.  ETA is 23.5 Seconds
# 7500/18809 : Process [Creating DB Data From 18809 Artists For ModVal=27] Has Run For 11.4 Seconds.  ETA is 17.2 Seconds
# 15000/18809 : Process [Creating DB Data From 18809 Artists For ModVal=27] Has Run For 20.1 Seconds.  ETA is 5.1 Seconds
# Process [Creating DB Data From 18809 Artists For ModVal=27] Took 24.2 Seconds
# 27/100     : Process [Creating DB Data] Has Run For 12.7 Minutes.  ETA is 34.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:26 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:26 for Creating DB Data From 18586 Artists For ModVal=28
# 2500/18586 : Process [Creating DB Data From 18586 Artists For ModVal=28] Has Run For 4.2 Seconds.  ETA is 27.0 Seconds
# 7500/18586 : Process [Creating DB Data From 18586 Artists For ModVal=28] Has Run For 10.4 Seconds.  ETA is 15.4 Seconds
# 15000/18586 : Process [Creating DB Data From 18586 Artists For ModVal=28] Has Run For 19.2 Seconds.  ETA is 4.6 Seconds
# Process [Creating DB Data From 18586 Artists For ModVal=28] Took 24.2 Seconds
# 28/100     : Process [Creating DB Data] Has Run For 13.2 Minutes.  ETA is 33.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:26 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:26 for Creating DB Data From 18919 Artists For ModVal=29
# 2500/18919 : Process [Creating DB Data From 18919 Artists For ModVal=29] Has Run For 3.4 Seconds.  ETA is 22.3 Seconds
# 7500/18919 : Process [Creating DB Data From 18919 Artists For ModVal=29] Has Run For 8.5 Seconds.  ETA is 12.9 Seconds
# 15000/18919 : Process [Creating DB Data From 18919 Artists For ModVal=29] Has Run For 17.7 Seconds.  ETA is 4.6 Seconds
# Process [Creating DB Data From 18919 Artists For ModVal=29] Took 22.8 Seconds
# 29/100     : Process [Creating DB Data] Has Run For 13.7 Minutes.  ETA is 33.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:27 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.6 Seconds
# Current Time is Wed Dec 15, 2021 12:27 for Creating DB Data From 18819 Artists For ModVal=30
# 2500/18819 : Process [Creating DB Data From 18819 Artists For ModVal=30] Has Run For 3.7 Seconds.  ETA is 24.2 Seconds
# 7500/18819 : Process [Creating DB Data From 18819 Artists For ModVal=30] Has Run For 8.8 Seconds.  ETA is 13.3 Seconds
# 15000/18819 : Process [Creating DB Data From 18819 Artists For ModVal=30] Has Run For 16.1 Seconds.  ETA is 4.1 Seconds
# Process [Creating DB Data From 18819 Artists For ModVal=30] Took 19.7 Seconds
# 30/100     : Process [Creating DB Data] Has Run For 14.1 Minutes.  ETA is 32.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:27 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:27 for Creating DB Data From 18808 Artists For ModVal=31
# 2500/18808 : Process [Creating DB Data From 18808 Artists For ModVal=31] Has Run For 4.1 Seconds.  ETA is 26.7 Seconds
# 7500/18808 : Process [Creating DB Data From 18808 Artists For ModVal=31] Has Run For 9.2 Seconds.  ETA is 13.9 Seconds
# 15000/18808 : Process [Creating DB Data From 18808 Artists For ModVal=31] Has Run For 16.5 Seconds.  ETA is 4.2 Seconds
# Process [Creating DB Data From 18808 Artists For ModVal=31] Took 20.1 Seconds
# 31/100     : Process [Creating DB Data] Has Run For 14.5 Minutes.  ETA is 32.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:28 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.4 Seconds
# Current Time is Wed Dec 15, 2021 12:28 for Creating DB Data From 18655 Artists For ModVal=32
# 2500/18655 : Process [Creating DB Data From 18655 Artists For ModVal=32] Has Run For 4.5 Seconds.  ETA is 29.1 Seconds
# 7500/18655 : Process [Creating DB Data From 18655 Artists For ModVal=32] Has Run For 11.9 Seconds.  ETA is 17.7 Seconds
# 15000/18655 : Process [Creating DB Data From 18655 Artists For ModVal=32] Has Run For 20.4 Seconds.  ETA is 5.0 Seconds
# Process [Creating DB Data From 18655 Artists For ModVal=32] Took 24.1 Seconds
# 32/100     : Process [Creating DB Data] Has Run For 14.9 Minutes.  ETA is 31.7 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:28 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.5 Seconds
# Current Time is Wed Dec 15, 2021 12:28 for Creating DB Data From 18914 Artists For ModVal=33
# 2500/18914 : Process [Creating DB Data From 18914 Artists For ModVal=33] Has Run For 4.1 Seconds.  ETA is 26.9 Seconds
# 7500/18914 : Process [Creating DB Data From 18914 Artists For ModVal=33] Has Run For 10.5 Seconds.  ETA is 16.0 Seconds
# 15000/18914 : Process [Creating DB Data From 18914 Artists For ModVal=33] Has Run For 21.0 Seconds.  ETA is 5.5 Seconds
# Process [Creating DB Data From 18914 Artists For ModVal=33] Took 26.7 Seconds
# 33/100     : Process [Creating DB Data] Has Run For 15.5 Minutes.  ETA is 31.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:29 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:29 for Creating DB Data From 18971 Artists For ModVal=34
# 2500/18971 : Process [Creating DB Data From 18971 Artists For ModVal=34] Has Run For 4.7 Seconds.  ETA is 31.0 Seconds
# 7500/18971 : Process [Creating DB Data From 18971 Artists For ModVal=34] Has Run For 10.2 Seconds.  ETA is 15.6 Seconds
# 15000/18971 : Process [Creating DB Data From 18971 Artists For ModVal=34] Has Run For 18.3 Seconds.  ETA is 4.8 Seconds
# Process [Creating DB Data From 18971 Artists For ModVal=34] Took 22.2 Seconds
# 34/100     : Process [Creating DB Data] Has Run For 15.9 Minutes.  ETA is 30.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:29 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:29 for Creating DB Data From 18756 Artists For ModVal=35
# 2500/18756 : Process [Creating DB Data From 18756 Artists For ModVal=35] Has Run For 3.4 Seconds.  ETA is 22.1 Seconds
# 7500/18756 : Process [Creating DB Data From 18756 Artists For ModVal=35] Has Run For 10.8 Seconds.  ETA is 16.2 Seconds
# 15000/18756 : Process [Creating DB Data From 18756 Artists For ModVal=35] Has Run For 19.3 Seconds.  ETA is 4.8 Seconds
# Process [Creating DB Data From 18756 Artists For ModVal=35] Took 24.0 Seconds
# 35/100     : Process [Creating DB Data] Has Run For 16.4 Minutes.  ETA is 30.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:30 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:30 for Creating DB Data From 18769 Artists For ModVal=36
# 2500/18769 : Process [Creating DB Data From 18769 Artists For ModVal=36] Has Run For 3.6 Seconds.  ETA is 23.4 Seconds
# 7500/18769 : Process [Creating DB Data From 18769 Artists For ModVal=36] Has Run For 9.1 Seconds.  ETA is 13.7 Seconds
# 15000/18769 : Process [Creating DB Data From 18769 Artists For ModVal=36] Has Run For 18.9 Seconds.  ETA is 4.7 Seconds
# Process [Creating DB Data From 18769 Artists For ModVal=36] Took 23.8 Seconds
# 36/100     : Process [Creating DB Data] Has Run For 16.8 Minutes.  ETA is 29.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:30 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:30 for Creating DB Data From 18630 Artists For ModVal=37
# 2500/18630 : Process [Creating DB Data From 18630 Artists For ModVal=37] Has Run For 4.1 Seconds.  ETA is 26.5 Seconds
# 7500/18630 : Process [Creating DB Data From 18630 Artists For ModVal=37] Has Run For 10.8 Seconds.  ETA is 16.0 Seconds
# 15000/18630 : Process [Creating DB Data From 18630 Artists For ModVal=37] Has Run For 18.2 Seconds.  ETA is 4.4 Seconds
# Process [Creating DB Data From 18630 Artists For ModVal=37] Took 21.6 Seconds
# 37/100     : Process [Creating DB Data] Has Run For 17.3 Minutes.  ETA is 29.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:30 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:30 for Creating DB Data From 18842 Artists For ModVal=38
# 2500/18842 : Process [Creating DB Data From 18842 Artists For ModVal=38] Has Run For 4.2 Seconds.  ETA is 27.5 Seconds
# 7500/18842 : Process [Creating DB Data From 18842 Artists For ModVal=38] Has Run For 10.7 Seconds.  ETA is 16.2 Seconds
# 15000/18842 : Process [Creating DB Data From 18842 Artists For ModVal=38] Has Run For 21.0 Seconds.  ETA is 5.4 Seconds
# Process [Creating DB Data From 18842 Artists For ModVal=38] Took 25.2 Seconds
# 38/100     : Process [Creating DB Data] Has Run For 17.7 Minutes.  ETA is 28.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:31 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:31 for Creating DB Data From 18580 Artists For ModVal=39
# 2500/18580 : Process [Creating DB Data From 18580 Artists For ModVal=39] Has Run For 5.2 Seconds.  ETA is 33.4 Seconds
# 7500/18580 : Process [Creating DB Data From 18580 Artists For ModVal=39] Has Run For 11.3 Seconds.  ETA is 16.7 Seconds
# 15000/18580 : Process [Creating DB Data From 18580 Artists For ModVal=39] Has Run For 18.5 Seconds.  ETA is 4.4 Seconds
# Process [Creating DB Data From 18580 Artists For ModVal=39] Took 23.0 Seconds
# 39/100     : Process [Creating DB Data] Has Run For 18.2 Minutes.  ETA is 28.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:31 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:31 for Creating DB Data From 19006 Artists For ModVal=40
# 2500/19006 : Process [Creating DB Data From 19006 Artists For ModVal=40] Has Run For 4.1 Seconds.  ETA is 27.1 Seconds
# 7500/19006 : Process [Creating DB Data From 19006 Artists For ModVal=40] Has Run For 12.8 Seconds.  ETA is 19.6 Seconds
# 15000/19006 : Process [Creating DB Data From 19006 Artists For ModVal=40] Has Run For 21.1 Seconds.  ETA is 5.6 Seconds
# Process [Creating DB Data From 19006 Artists For ModVal=40] Took 25.7 Seconds
# 40/100     : Process [Creating DB Data] Has Run For 18.7 Minutes.  ETA is 28.1 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:32 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:32 for Creating DB Data From 18928 Artists For ModVal=41
# 2500/18928 : Process [Creating DB Data From 18928 Artists For ModVal=41] Has Run For 3.3 Seconds.  ETA is 21.7 Seconds
# 7500/18928 : Process [Creating DB Data From 18928 Artists For ModVal=41] Has Run For 9.1 Seconds.  ETA is 13.9 Seconds
# 15000/18928 : Process [Creating DB Data From 18928 Artists For ModVal=41] Has Run For 16.4 Seconds.  ETA is 4.3 Seconds
# Process [Creating DB Data From 18928 Artists For ModVal=41] Took 20.1 Seconds
# 41/100     : Process [Creating DB Data] Has Run For 19.1 Minutes.  ETA is 27.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:32 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:32 for Creating DB Data From 18846 Artists For ModVal=42
# 2500/18846 : Process [Creating DB Data From 18846 Artists For ModVal=42] Has Run For 3.6 Seconds.  ETA is 23.5 Seconds
# 7500/18846 : Process [Creating DB Data From 18846 Artists For ModVal=42] Has Run For 9.1 Seconds.  ETA is 13.8 Seconds
# 15000/18846 : Process [Creating DB Data From 18846 Artists For ModVal=42] Has Run For 18.8 Seconds.  ETA is 4.8 Seconds
# Process [Creating DB Data From 18846 Artists For ModVal=42] Took 22.4 Seconds
# 42/100     : Process [Creating DB Data] Has Run For 19.5 Minutes.  ETA is 26.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:33 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:33 for Creating DB Data From 18710 Artists For ModVal=43
# 2500/18710 : Process [Creating DB Data From 18710 Artists For ModVal=43] Has Run For 3.4 Seconds.  ETA is 22.0 Seconds
# 7500/18710 : Process [Creating DB Data From 18710 Artists For ModVal=43] Has Run For 8.8 Seconds.  ETA is 13.2 Seconds
# 15000/18710 : Process [Creating DB Data From 18710 Artists For ModVal=43] Has Run For 18.8 Seconds.  ETA is 4.6 Seconds
# Process [Creating DB Data From 18710 Artists For ModVal=43] Took 24.5 Seconds
# 43/100     : Process [Creating DB Data] Has Run For 20.0 Minutes.  ETA is 26.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:33 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:33 for Creating DB Data From 19113 Artists For ModVal=44
# 2500/19113 : Process [Creating DB Data From 19113 Artists For ModVal=44] Has Run For 3.3 Seconds.  ETA is 21.9 Seconds
# 7500/19113 : Process [Creating DB Data From 19113 Artists For ModVal=44] Has Run For 8.7 Seconds.  ETA is 13.5 Seconds
# 15000/19113 : Process [Creating DB Data From 19113 Artists For ModVal=44] Has Run For 16.2 Seconds.  ETA is 4.4 Seconds
# Process [Creating DB Data From 19113 Artists For ModVal=44] Took 20.4 Seconds
# 44/100     : Process [Creating DB Data] Has Run For 20.4 Minutes.  ETA is 26.0 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:34 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:34 for Creating DB Data From 18919 Artists For ModVal=45
# 2500/18919 : Process [Creating DB Data From 18919 Artists For ModVal=45] Has Run For 6.0 Seconds.  ETA is 39.4 Seconds
# 7500/18919 : Process [Creating DB Data From 18919 Artists For ModVal=45] Has Run For 11.7 Seconds.  ETA is 17.8 Seconds
# 15000/18919 : Process [Creating DB Data From 18919 Artists For ModVal=45] Has Run For 21.2 Seconds.  ETA is 5.5 Seconds
# Process [Creating DB Data From 18919 Artists For ModVal=45] Took 25.0 Seconds
# 45/100     : Process [Creating DB Data] Has Run For 20.9 Minutes.  ETA is 25.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:34 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.2 Seconds
# Current Time is Wed Dec 15, 2021 12:34 for Creating DB Data From 18959 Artists For ModVal=46
# 2500/18959 : Process [Creating DB Data From 18959 Artists For ModVal=46] Has Run For 4.5 Seconds.  ETA is 29.6 Seconds
# 7500/18959 : Process [Creating DB Data From 18959 Artists For ModVal=46] Has Run For 11.9 Seconds.  ETA is 18.2 Seconds
# 15000/18959 : Process [Creating DB Data From 18959 Artists For ModVal=46] Has Run For 22.8 Seconds.  ETA is 6.0 Seconds
# Process [Creating DB Data From 18959 Artists For ModVal=46] Took 26.8 Seconds
# 46/100     : Process [Creating DB Data] Has Run For 21.4 Minutes.  ETA is 25.1 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:35 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:35 for Creating DB Data From 19064 Artists For ModVal=47
# 2500/19064 : Process [Creating DB Data From 19064 Artists For ModVal=47] Has Run For 3.8 Seconds.  ETA is 25.2 Seconds
# 7500/19064 : Process [Creating DB Data From 19064 Artists For ModVal=47] Has Run For 10.4 Seconds.  ETA is 16.0 Seconds
# 15000/19064 : Process [Creating DB Data From 19064 Artists For ModVal=47] Has Run For 20.8 Seconds.  ETA is 5.6 Seconds
# Process [Creating DB Data From 19064 Artists For ModVal=47] Took 27.0 Seconds
# 47/100     : Process [Creating DB Data] Has Run For 21.9 Minutes.  ETA is 24.7 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:35 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.2 Seconds
# Current Time is Wed Dec 15, 2021 12:35 for Creating DB Data From 18676 Artists For ModVal=48
# 2500/18676 : Process [Creating DB Data From 18676 Artists For ModVal=48] Has Run For 5.5 Seconds.  ETA is 35.6 Seconds
# 7500/18676 : Process [Creating DB Data From 18676 Artists For ModVal=48] Has Run For 12.2 Seconds.  ETA is 18.2 Seconds
# 15000/18676 : Process [Creating DB Data From 18676 Artists For ModVal=48] Has Run For 21.6 Seconds.  ETA is 5.3 Seconds
# Process [Creating DB Data From 18676 Artists For ModVal=48] Took 25.1 Seconds
# 48/100     : Process [Creating DB Data] Has Run For 22.4 Minutes.  ETA is 24.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:36 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:36 for Creating DB Data From 18821 Artists For ModVal=49
# 2500/18821 : Process [Creating DB Data From 18821 Artists For ModVal=49] Has Run For 3.8 Seconds.  ETA is 24.8 Seconds
# 7500/18821 : Process [Creating DB Data From 18821 Artists For ModVal=49] Has Run For 10.7 Seconds.  ETA is 16.2 Seconds
# 15000/18821 : Process [Creating DB Data From 18821 Artists For ModVal=49] Has Run For 21.7 Seconds.  ETA is 5.5 Seconds
# Process [Creating DB Data From 18821 Artists For ModVal=49] Took 25.8 Seconds
# 49/100     : Process [Creating DB Data] Has Run For 22.9 Minutes.  ETA is 23.8 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:36 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:36 for Creating DB Data From 18791 Artists For ModVal=50
# 2500/18791 : Process [Creating DB Data From 18791 Artists For ModVal=50] Has Run For 3.8 Seconds.  ETA is 24.8 Seconds
# 7500/18791 : Process [Creating DB Data From 18791 Artists For ModVal=50] Has Run For 9.3 Seconds.  ETA is 14.0 Seconds
# 15000/18791 : Process [Creating DB Data From 18791 Artists For ModVal=50] Has Run For 17.3 Seconds.  ETA is 4.4 Seconds
# Process [Creating DB Data From 18791 Artists For ModVal=50] Took 22.8 Seconds
# 50/100     : Process [Creating DB Data] Has Run For 23.3 Minutes.  ETA is 23.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:37 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.5 Seconds
# Current Time is Wed Dec 15, 2021 12:37 for Creating DB Data From 18973 Artists For ModVal=51
# 2500/18973 : Process [Creating DB Data From 18973 Artists For ModVal=51] Has Run For 4.7 Seconds.  ETA is 31.0 Seconds
# 7500/18973 : Process [Creating DB Data From 18973 Artists For ModVal=51] Has Run For 11.9 Seconds.  ETA is 18.2 Seconds
# 15000/18973 : Process [Creating DB Data From 18973 Artists For ModVal=51] Has Run For 21.3 Seconds.  ETA is 5.6 Seconds
# Process [Creating DB Data From 18973 Artists For ModVal=51] Took 25.2 Seconds
# 51/100     : Process [Creating DB Data] Has Run For 23.8 Minutes.  ETA is 22.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:37 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.2 Seconds
# Current Time is Wed Dec 15, 2021 12:37 for Creating DB Data From 18970 Artists For ModVal=52
# 2500/18970 : Process [Creating DB Data From 18970 Artists For ModVal=52] Has Run For 7.5 Seconds.  ETA is 49.4 Seconds
# 7500/18970 : Process [Creating DB Data From 18970 Artists For ModVal=52] Has Run For 14.9 Seconds.  ETA is 22.8 Seconds
# 15000/18970 : Process [Creating DB Data From 18970 Artists For ModVal=52] Has Run For 23.8 Seconds.  ETA is 6.3 Seconds
# Process [Creating DB Data From 18970 Artists For ModVal=52] Took 28.5 Seconds
# 52/100     : Process [Creating DB Data] Has Run For 24.4 Minutes.  ETA is 22.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:38 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:38 for Creating DB Data From 18759 Artists For ModVal=53
# 2500/18759 : Process [Creating DB Data From 18759 Artists For ModVal=53] Has Run For 5.7 Seconds.  ETA is 37.1 Seconds
# 7500/18759 : Process [Creating DB Data From 18759 Artists For ModVal=53] Has Run For 13.3 Seconds.  ETA is 20.0 Seconds
# 15000/18759 : Process [Creating DB Data From 18759 Artists For ModVal=53] Has Run For 24.0 Seconds.  ETA is 6.0 Seconds
# Process [Creating DB Data From 18759 Artists For ModVal=53] Took 28.8 Seconds
# 53/100     : Process [Creating DB Data] Has Run For 24.9 Minutes.  ETA is 22.1 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:38 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.2 Seconds
# Current Time is Wed Dec 15, 2021 12:38 for Creating DB Data From 18850 Artists For ModVal=54
# 2500/18850 : Process [Creating DB Data From 18850 Artists For ModVal=54] Has Run For 4.3 Seconds.  ETA is 28.1 Seconds
# 7500/18850 : Process [Creating DB Data From 18850 Artists For ModVal=54] Has Run For 11.5 Seconds.  ETA is 17.4 Seconds
# 15000/18850 : Process [Creating DB Data From 18850 Artists For ModVal=54] Has Run For 20.4 Seconds.  ETA is 5.2 Seconds
# Process [Creating DB Data From 18850 Artists For ModVal=54] Took 25.0 Seconds
# 54/100     : Process [Creating DB Data] Has Run For 25.4 Minutes.  ETA is 21.6 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:39 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:39 for Creating DB Data From 18976 Artists For ModVal=55
# 2500/18976 : Process [Creating DB Data From 18976 Artists For ModVal=55] Has Run For 3.9 Seconds.  ETA is 25.7 Seconds
# 7500/18976 : Process [Creating DB Data From 18976 Artists For ModVal=55] Has Run For 11.8 Seconds.  ETA is 18.1 Seconds
# 15000/18976 : Process [Creating DB Data From 18976 Artists For ModVal=55] Has Run For 21.7 Seconds.  ETA is 5.8 Seconds
# Process [Creating DB Data From 18976 Artists For ModVal=55] Took 26.2 Seconds
# 55/100     : Process [Creating DB Data] Has Run For 26.0 Minutes.  ETA is 21.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:39 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.5 Seconds
# Current Time is Wed Dec 15, 2021 12:39 for Creating DB Data From 18923 Artists For ModVal=56
# 2500/18923 : Process [Creating DB Data From 18923 Artists For ModVal=56] Has Run For 3.7 Seconds.  ETA is 24.3 Seconds
# 7500/18923 : Process [Creating DB Data From 18923 Artists For ModVal=56] Has Run For 10.2 Seconds.  ETA is 15.5 Seconds
# 15000/18923 : Process [Creating DB Data From 18923 Artists For ModVal=56] Has Run For 20.5 Seconds.  ETA is 5.4 Seconds
# Process [Creating DB Data From 18923 Artists For ModVal=56] Took 24.6 Seconds
# 56/100     : Process [Creating DB Data] Has Run For 26.5 Minutes.  ETA is 20.8 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:40 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.4 Seconds
# Current Time is Wed Dec 15, 2021 12:40 for Creating DB Data From 18815 Artists For ModVal=57
# 2500/18815 : Process [Creating DB Data From 18815 Artists For ModVal=57] Has Run For 5.2 Seconds.  ETA is 33.9 Seconds
# 7500/18815 : Process [Creating DB Data From 18815 Artists For ModVal=57] Has Run For 11.9 Seconds.  ETA is 18.0 Seconds
# 15000/18815 : Process [Creating DB Data From 18815 Artists For ModVal=57] Has Run For 23.4 Seconds.  ETA is 6.0 Seconds
# Process [Creating DB Data From 18815 Artists For ModVal=57] Took 28.7 Seconds
# 57/100     : Process [Creating DB Data] Has Run For 27.0 Minutes.  ETA is 20.4 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:40 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.2 Seconds
# Current Time is Wed Dec 15, 2021 12:40 for Creating DB Data From 18856 Artists For ModVal=58
# 2500/18856 : Process [Creating DB Data From 18856 Artists For ModVal=58] Has Run For 4.9 Seconds.  ETA is 32.1 Seconds
# 7500/18856 : Process [Creating DB Data From 18856 Artists For ModVal=58] Has Run For 11.9 Seconds.  ETA is 18.0 Seconds
# 15000/18856 : Process [Creating DB Data From 18856 Artists For ModVal=58] Has Run For 21.4 Seconds.  ETA is 5.5 Seconds
# Process [Creating DB Data From 18856 Artists For ModVal=58] Took 26.3 Seconds
# 58/100     : Process [Creating DB Data] Has Run For 27.5 Minutes.  ETA is 19.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:41 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.3 Seconds
# Current Time is Wed Dec 15, 2021 12:41 for Creating DB Data From 18767 Artists For ModVal=59
# 2500/18767 : Process [Creating DB Data From 18767 Artists For ModVal=59] Has Run For 3.5 Seconds.  ETA is 22.8 Seconds
# 7500/18767 : Process [Creating DB Data From 18767 Artists For ModVal=59] Has Run For 9.1 Seconds.  ETA is 13.7 Seconds
# 15000/18767 : Process [Creating DB Data From 18767 Artists For ModVal=59] Has Run For 16.9 Seconds.  ETA is 4.2 Seconds
# Process [Creating DB Data From 18767 Artists For ModVal=59] Took 20.7 Seconds
# 59/100     : Process [Creating DB Data] Has Run For 28.0 Minutes.  ETA is 19.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:41 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:41 for Creating DB Data From 19006 Artists For ModVal=60
# 2500/19006 : Process [Creating DB Data From 19006 Artists For ModVal=60] Has Run For 4.3 Seconds.  ETA is 28.4 Seconds
# 7500/19006 : Process [Creating DB Data From 19006 Artists For ModVal=60] Has Run For 10.1 Seconds.  ETA is 15.5 Seconds
# 15000/19006 : Process [Creating DB Data From 19006 Artists For ModVal=60] Has Run For 19.3 Seconds.  ETA is 5.2 Seconds
# Process [Creating DB Data From 19006 Artists For ModVal=60] Took 23.5 Seconds
# 60/100     : Process [Creating DB Data] Has Run For 28.4 Minutes.  ETA is 18.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:42 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:42 for Creating DB Data From 18821 Artists For ModVal=61
# 2500/18821 : Process [Creating DB Data From 18821 Artists For ModVal=61] Has Run For 3.7 Seconds.  ETA is 24.2 Seconds
# 7500/18821 : Process [Creating DB Data From 18821 Artists For ModVal=61] Has Run For 9.9 Seconds.  ETA is 14.9 Seconds
# 15000/18821 : Process [Creating DB Data From 18821 Artists For ModVal=61] Has Run For 17.6 Seconds.  ETA is 4.5 Seconds
# Process [Creating DB Data From 18821 Artists For ModVal=61] Took 22.0 Seconds
# 61/100     : Process [Creating DB Data] Has Run For 28.9 Minutes.  ETA is 18.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:42 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:42 for Creating DB Data From 18694 Artists For ModVal=62
# 2500/18694 : Process [Creating DB Data From 18694 Artists For ModVal=62] Has Run For 3.8 Seconds.  ETA is 24.6 Seconds
# 7500/18694 : Process [Creating DB Data From 18694 Artists For ModVal=62] Has Run For 9.8 Seconds.  ETA is 14.6 Seconds
# 15000/18694 : Process [Creating DB Data From 18694 Artists For ModVal=62] Has Run For 17.1 Seconds.  ETA is 4.2 Seconds
# Process [Creating DB Data From 18694 Artists For ModVal=62] Took 20.6 Seconds
# 62/100     : Process [Creating DB Data] Has Run For 29.3 Minutes.  ETA is 18.0 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:42 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:42 for Creating DB Data From 19024 Artists For ModVal=63
# 2500/19024 : Process [Creating DB Data From 19024 Artists For ModVal=63] Has Run For 3.4 Seconds.  ETA is 22.5 Seconds
# 7500/19024 : Process [Creating DB Data From 19024 Artists For ModVal=63] Has Run For 8.4 Seconds.  ETA is 12.9 Seconds
# 15000/19024 : Process [Creating DB Data From 19024 Artists For ModVal=63] Has Run For 16.5 Seconds.  ETA is 4.4 Seconds
# Process [Creating DB Data From 19024 Artists For ModVal=63] Took 20.3 Seconds
# 63/100     : Process [Creating DB Data] Has Run For 29.7 Minutes.  ETA is 17.4 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:43 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:43 for Creating DB Data From 18676 Artists For ModVal=64
# 2500/18676 : Process [Creating DB Data From 18676 Artists For ModVal=64] Has Run For 3.3 Seconds.  ETA is 21.4 Seconds
# 7500/18676 : Process [Creating DB Data From 18676 Artists For ModVal=64] Has Run For 8.4 Seconds.  ETA is 12.5 Seconds
# 15000/18676 : Process [Creating DB Data From 18676 Artists For ModVal=64] Has Run For 16.5 Seconds.  ETA is 4.0 Seconds
# Process [Creating DB Data From 18676 Artists For ModVal=64] Took 20.0 Seconds
# 64/100     : Process [Creating DB Data] Has Run For 30.1 Minutes.  ETA is 16.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:43 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# ...
# 7500/18812 : Process [Creating DB Data From 18812 Artists For ModVal=78] Has Run For 9.3 Seconds.  ETA is 14.0 Seconds
# 15000/18812 : Process [Creating DB Data From 18812 Artists For ModVal=78] Has Run For 16.5 Seconds.  ETA is 4.2 Seconds
# Process [Creating DB Data From 18812 Artists For ModVal=78] Took 20.0 Seconds
# 78/100     : Process [Creating DB Data] Has Run For 35.8 Minutes.  ETA is 10.1 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:49 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:49 for Creating DB Data From 18940 Artists For ModVal=79
# 2500/18940 : Process [Creating DB Data From 18940 Artists For ModVal=79] Has Run For 4.0 Seconds.  ETA is 26.3 Seconds
# 7500/18940 : Process [Creating DB Data From 18940 Artists For ModVal=79] Has Run For 9.1 Seconds.  ETA is 13.9 Seconds
# 15000/18940 : Process [Creating DB Data From 18940 Artists For ModVal=79] Has Run For 16.3 Seconds.  ETA is 4.3 Seconds
# Process [Creating DB Data From 18940 Artists For ModVal=79] Took 20.0 Seconds
# 79/100     : Process [Creating DB Data] Has Run For 36.2 Minutes.  ETA is 9.6 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:49 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:49 for Creating DB Data From 18905 Artists For ModVal=80
# 2500/18905 : Process [Creating DB Data From 18905 Artists For ModVal=80] Has Run For 4.0 Seconds.  ETA is 26.2 Seconds
# 7500/18905 : Process [Creating DB Data From 18905 Artists For ModVal=80] Has Run For 9.0 Seconds.  ETA is 13.7 Seconds
# 15000/18905 : Process [Creating DB Data From 18905 Artists For ModVal=80] Has Run For 16.2 Seconds.  ETA is 4.2 Seconds
# Process [Creating DB Data From 18905 Artists For ModVal=80] Took 19.9 Seconds
# 80/100     : Process [Creating DB Data] Has Run For 36.6 Minutes.  ETA is 9.2 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:50 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:50 for Creating DB Data From 19006 Artists For ModVal=81
# 2500/19006 : Process [Creating DB Data From 19006 Artists For ModVal=81] Has Run For 4.0 Seconds.  ETA is 26.4 Seconds
# 7500/19006 : Process [Creating DB Data From 19006 Artists For ModVal=81] Has Run For 9.0 Seconds.  ETA is 13.8 Seconds
# 15000/19006 : Process [Creating DB Data From 19006 Artists For ModVal=81] Has Run For 16.2 Seconds.  ETA is 4.3 Seconds
# Process [Creating DB Data From 19006 Artists For ModVal=81] Took 20.0 Seconds
# 81/100     : Process [Creating DB Data] Has Run For 37.0 Minutes.  ETA is 8.7 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:50 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:50 for Creating DB Data From 18847 Artists For ModVal=82
# 2500/18847 : Process [Creating DB Data From 18847 Artists For ModVal=82] Has Run For 3.3 Seconds.  ETA is 21.6 Seconds
# 7500/18847 : Process [Creating DB Data From 18847 Artists For ModVal=82] Has Run For 9.0 Seconds.  ETA is 13.6 Seconds
# 15000/18847 : Process [Creating DB Data From 18847 Artists For ModVal=82] Has Run For 16.2 Seconds.  ETA is 4.2 Seconds
# Process [Creating DB Data From 18847 Artists For ModVal=82] Took 19.8 Seconds
# 82/100     : Process [Creating DB Data] Has Run For 37.4 Minutes.  ETA is 8.2 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:51 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:51 for Creating DB Data From 18771 Artists For ModVal=83
# 2500/18771 : Process [Creating DB Data From 18771 Artists For ModVal=83] Has Run For 3.4 Seconds.  ETA is 22.1 Seconds
# 7500/18771 : Process [Creating DB Data From 18771 Artists For ModVal=83] Has Run For 9.2 Seconds.  ETA is 13.8 Seconds
# 15000/18771 : Process [Creating DB Data From 18771 Artists For ModVal=83] Has Run For 16.4 Seconds.  ETA is 4.1 Seconds
# Process [Creating DB Data From 18771 Artists For ModVal=83] Took 20.0 Seconds
# 83/100     : Process [Creating DB Data] Has Run For 37.8 Minutes.  ETA is 7.7 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:51 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:51 for Creating DB Data From 18709 Artists For ModVal=84
# 2500/18709 : Process [Creating DB Data From 18709 Artists For ModVal=84] Has Run For 3.5 Seconds.  ETA is 22.7 Seconds
# 7500/18709 : Process [Creating DB Data From 18709 Artists For ModVal=84] Has Run For 8.6 Seconds.  ETA is 12.9 Seconds
# 15000/18709 : Process [Creating DB Data From 18709 Artists For ModVal=84] Has Run For 16.6 Seconds.  ETA is 4.1 Seconds
# Process [Creating DB Data From 18709 Artists For ModVal=84] Took 20.1 Seconds
# 84/100     : Process [Creating DB Data] Has Run For 38.2 Minutes.  ETA is 7.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:51 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:51 for Creating DB Data From 18772 Artists For ModVal=85
# 2500/18772 : Process [Creating DB Data From 18772 Artists For ModVal=85] Has Run For 3.4 Seconds.  ETA is 22.1 Seconds
# 7500/18772 : Process [Creating DB Data From 18772 Artists For ModVal=85] Has Run For 8.4 Seconds.  ETA is 12.6 Seconds
# 15000/18772 : Process [Creating DB Data From 18772 Artists For ModVal=85] Has Run For 16.4 Seconds.  ETA is 4.1 Seconds
# Process [Creating DB Data From 18772 Artists For ModVal=85] Took 19.9 Seconds
# 85/100     : Process [Creating DB Data] Has Run For 38.6 Minutes.  ETA is 6.8 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:52 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.0 Seconds
# Current Time is Wed Dec 15, 2021 12:52 for Creating DB Data From 18659 Artists For ModVal=86
# 2500/18659 : Process [Creating DB Data From 18659 Artists For ModVal=86] Has Run For 3.3 Seconds.  ETA is 21.3 Seconds
# 7500/18659 : Process [Creating DB Data From 18659 Artists For ModVal=86] Has Run For 8.3 Seconds.  ETA is 12.3 Seconds
# 15000/18659 : Process [Creating DB Data From 18659 Artists For ModVal=86] Has Run For 15.5 Seconds.  ETA is 3.8 Seconds
# Process [Creating DB Data From 18659 Artists For ModVal=86] Took 18.9 Seconds
# 86/100     : Process [Creating DB Data] Has Run For 38.9 Minutes.  ETA is 6.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:52 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:52 for Creating DB Data From 18811 Artists For ModVal=87
# 2500/18811 : Process [Creating DB Data From 18811 Artists For ModVal=87] Has Run For 4.0 Seconds.  ETA is 26.1 Seconds
# 7500/18811 : Process [Creating DB Data From 18811 Artists For ModVal=87] Has Run For 9.0 Seconds.  ETA is 13.6 Seconds
# 15000/18811 : Process [Creating DB Data From 18811 Artists For ModVal=87] Has Run For 16.3 Seconds.  ETA is 4.1 Seconds
# Process [Creating DB Data From 18811 Artists For ModVal=87] Took 19.8 Seconds
# 87/100     : Process [Creating DB Data] Has Run For 39.3 Minutes.  ETA is 5.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:52 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:52 for Creating DB Data From 18937 Artists For ModVal=88
# 2500/18937 : Process [Creating DB Data From 18937 Artists For ModVal=88] Has Run For 4.0 Seconds.  ETA is 26.3 Seconds
# 7500/18937 : Process [Creating DB Data From 18937 Artists For ModVal=88] Has Run For 9.0 Seconds.  ETA is 13.7 Seconds
# 15000/18937 : Process [Creating DB Data From 18937 Artists For ModVal=88] Has Run For 16.1 Seconds.  ETA is 4.2 Seconds
# Process [Creating DB Data From 18937 Artists For ModVal=88] Took 19.8 Seconds
# 88/100     : Process [Creating DB Data] Has Run For 39.7 Minutes.  ETA is 5.4 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:53 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:53 for Creating DB Data From 18844 Artists For ModVal=89
# 2500/18844 : Process [Creating DB Data From 18844 Artists For ModVal=89] Has Run For 3.3 Seconds.  ETA is 21.6 Seconds
# 7500/18844 : Process [Creating DB Data From 18844 Artists For ModVal=89] Has Run For 9.0 Seconds.  ETA is 13.6 Seconds
# 15000/18844 : Process [Creating DB Data From 18844 Artists For ModVal=89] Has Run For 16.2 Seconds.  ETA is 4.2 Seconds
# Process [Creating DB Data From 18844 Artists For ModVal=89] Took 19.8 Seconds
# 89/100     : Process [Creating DB Data] Has Run For 40.1 Minutes.  ETA is 5.0 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:53 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.0 Seconds
# Current Time is Wed Dec 15, 2021 12:53 for Creating DB Data From 18944 Artists For ModVal=90
# 2500/18944 : Process [Creating DB Data From 18944 Artists For ModVal=90] Has Run For 3.2 Seconds.  ETA is 21.0 Seconds
# 7500/18944 : Process [Creating DB Data From 18944 Artists For ModVal=90] Has Run For 9.0 Seconds.  ETA is 13.7 Seconds
# 15000/18944 : Process [Creating DB Data From 18944 Artists For ModVal=90] Has Run For 16.2 Seconds.  ETA is 4.3 Seconds
# Process [Creating DB Data From 18944 Artists For ModVal=90] Took 19.9 Seconds
# 90/100     : Process [Creating DB Data] Has Run For 40.5 Minutes.  ETA is 4.5 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:54 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.3 Seconds
# Current Time is Wed Dec 15, 2021 12:54 for Creating DB Data From 18844 Artists For ModVal=91
# 2500/18844 : Process [Creating DB Data From 18844 Artists For ModVal=91] Has Run For 4.2 Seconds.  ETA is 27.5 Seconds
# 7500/18844 : Process [Creating DB Data From 18844 Artists For ModVal=91] Has Run For 10.6 Seconds.  ETA is 16.0 Seconds
# 15000/18844 : Process [Creating DB Data From 18844 Artists For ModVal=91] Has Run For 20.8 Seconds.  ETA is 5.3 Seconds
# Process [Creating DB Data From 18844 Artists For ModVal=91] Took 25.3 Seconds
# 91/100     : Process [Creating DB Data] Has Run For 41.0 Minutes.  ETA is 4.1 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:54 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:54 for Creating DB Data From 18943 Artists For ModVal=92
# 2500/18943 : Process [Creating DB Data From 18943 Artists For ModVal=92] Has Run For 4.1 Seconds.  ETA is 27.0 Seconds
# 7500/18943 : Process [Creating DB Data From 18943 Artists For ModVal=92] Has Run For 10.6 Seconds.  ETA is 16.2 Seconds
# 15000/18943 : Process [Creating DB Data From 18943 Artists For ModVal=92] Has Run For 20.7 Seconds.  ETA is 5.4 Seconds
# Process [Creating DB Data From 18943 Artists For ModVal=92] Took 25.8 Seconds
# 92/100     : Process [Creating DB Data] Has Run For 41.5 Minutes.  ETA is 3.6 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:55 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:55 for Creating DB Data From 18751 Artists For ModVal=93
# 2500/18751 : Process [Creating DB Data From 18751 Artists For ModVal=93] Has Run For 4.6 Seconds.  ETA is 29.9 Seconds
# 7500/18751 : Process [Creating DB Data From 18751 Artists For ModVal=93] Has Run For 11.5 Seconds.  ETA is 17.3 Seconds
# 15000/18751 : Process [Creating DB Data From 18751 Artists For ModVal=93] Has Run For 20.8 Seconds.  ETA is 5.2 Seconds
# Process [Creating DB Data From 18751 Artists For ModVal=93] Took 26.3 Seconds
# 93/100     : Process [Creating DB Data] Has Run For 42.0 Minutes.  ETA is 3.2 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:55 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:55 for Creating DB Data From 18798 Artists For ModVal=94
# 2500/18798 : Process [Creating DB Data From 18798 Artists For ModVal=94] Has Run For 4.0 Seconds.  ETA is 26.1 Seconds
# 7500/18798 : Process [Creating DB Data From 18798 Artists For ModVal=94] Has Run For 10.5 Seconds.  ETA is 15.8 Seconds
# 15000/18798 : Process [Creating DB Data From 18798 Artists For ModVal=94] Has Run For 20.3 Seconds.  ETA is 5.1 Seconds
# Process [Creating DB Data From 18798 Artists For ModVal=94] Took 25.3 Seconds
# 94/100     : Process [Creating DB Data] Has Run For 42.5 Minutes.  ETA is 2.7 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:56 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:56 for Creating DB Data From 19086 Artists For ModVal=95
# 2500/19086 : Process [Creating DB Data From 19086 Artists For ModVal=95] Has Run For 5.5 Seconds.  ETA is 36.5 Seconds
# 7500/19086 : Process [Creating DB Data From 19086 Artists For ModVal=95] Has Run For 12.0 Seconds.  ETA is 18.5 Seconds
# 15000/19086 : Process [Creating DB Data From 19086 Artists For ModVal=95] Has Run For 21.3 Seconds.  ETA is 5.8 Seconds
# Process [Creating DB Data From 19086 Artists For ModVal=95] Took 26.1 Seconds
# 95/100     : Process [Creating DB Data] Has Run For 43.0 Minutes.  ETA is 2.3 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:56 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:56 for Creating DB Data From 18603 Artists For ModVal=96
# 2500/18603 : Process [Creating DB Data From 18603 Artists For ModVal=96] Has Run For 4.1 Seconds.  ETA is 26.4 Seconds
# 7500/18603 : Process [Creating DB Data From 18603 Artists For ModVal=96] Has Run For 11.3 Seconds.  ETA is 16.7 Seconds
# 15000/18603 : Process [Creating DB Data From 18603 Artists For ModVal=96] Has Run For 20.5 Seconds.  ETA is 4.9 Seconds
# Process [Creating DB Data From 18603 Artists For ModVal=96] Took 24.9 Seconds
# 96/100     : Process [Creating DB Data] Has Run For 43.5 Minutes.  ETA is 1.8 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:57 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:57 for Creating DB Data From 18816 Artists For ModVal=97
# 2500/18816 : Process [Creating DB Data From 18816 Artists For ModVal=97] Has Run For 4.3 Seconds.  ETA is 28.1 Seconds
# 7500/18816 : Process [Creating DB Data From 18816 Artists For ModVal=97] Has Run For 11.6 Seconds.  ETA is 17.5 Seconds
# 15000/18816 : Process [Creating DB Data From 18816 Artists For ModVal=97] Has Run For 20.8 Seconds.  ETA is 5.3 Seconds
# Process [Creating DB Data From 18816 Artists For ModVal=97] Took 25.4 Seconds
# 97/100     : Process [Creating DB Data] Has Run For 44.0 Minutes.  ETA is 1.4 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:57 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:57 for Creating DB Data From 18720 Artists For ModVal=98
# 2500/18720 : Process [Creating DB Data From 18720 Artists For ModVal=98] Has Run For 4.2 Seconds.  ETA is 27.2 Seconds
# 7500/18720 : Process [Creating DB Data From 18720 Artists For ModVal=98] Has Run For 10.6 Seconds.  ETA is 15.9 Seconds
# 15000/18720 : Process [Creating DB Data From 18720 Artists For ModVal=98] Has Run For 20.6 Seconds.  ETA is 5.1 Seconds
# Process [Creating DB Data From 18720 Artists For ModVal=98] Took 25.1 Seconds
# 98/100     : Process [Creating DB Data] Has Run For 44.5 Minutes.  ETA is 0.9 Minutes
#
#
# Current Time is Wed Dec 15, 2021 12:58 for Creating ModData Subset
# Process [Creating ModData Subset] Took 1.1 Seconds
# Current Time is Wed Dec 15, 2021 12:58 for Creating DB Data From 18948 Artists For ModVal=99
# 2500/18948 : Process [Creating DB Data From 18948 Artists For ModVal=99] Has Run For 4.2 Seconds.  ETA is 27.6 Seconds
# 7500/18948 : Process [Creating DB Data From 18948 Artists For ModVal=99] Has Run For 10.7 Seconds.  ETA is 16.3 Seconds
# 15000/18948 : Process [Creating DB Data From 18948 Artists For ModVal=99] Has Run For 20.9 Seconds.  ETA is 5.5 Seconds
# Process [Creating DB Data From 18948 Artists For ModVal=99] Took 25.6 Seconds
# 99/100     : Process [Creating DB Data] Has Run For 44.9 Minutes.  ETA is 0.5 Minutes
#
#
# Process [Creating DB Data] Took 44.9 Minutes

# %%
modValData['108541848016828757278131944962756872900'].show()
# Out:
# Artist Data Class
# -------------------------
# Artist:  Prince
# Meta:    None
#          https://musicbrainz.org/artist/070d193a-845c-479f-980e-bef15710653e
# Info:    None
#          None
#          2021-12-15 12:06:52.455003
# URL:     https://musicbrainz.org/artist/070d193a-845c-479f-980e-bef15710653e
# ID:      108541848016828757278131944962756872900
# Profile: {'general': {'SortName': 'Prince', 'Aliases': ['O(+>)', 'Formerly Prince', 'Prince', '(us 1) PRINCE', 'Joey Coco', '♀♂', 'The Artist Formerly Known as Prince', 'The Love Symbol', 'Symbol', 'O(+>', 'Prince Rogers Nelson', 'T.A.F.K.A.P.', 'Ƭ̵̬̊', 'Alexander Nevermind', 'Paisley Park'], 'Gender': 'Male', 'County': 'United States', 'Formed': Timestamp('1958-06-07 00:00:00'), 'Disbanded': Timestamp('2016-04-21 00:00:00'), 'ArtistType': 'Person', 'ISNI': '0000000120964892'}, 'genres': None, 'tags': None, 'external': {'BBC': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91970>], 'RateYourMusic': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b916a0>], 'Musicmoz': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b913d0>], 'LastFM': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91eb0>], 'YouTube': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b913a0>], 'MusikSammler': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91340>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b91280>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95580>], 'Spotify': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91910>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b955e0>], 'Misc': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91e50>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b91250>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b918e0>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b91ac0>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b91640>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b91df0>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95e80>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b956a0>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95100>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95d90>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95a30>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95a60>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95a00>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95280>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95130>], 'Twitter': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91040>], 'Songkick': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91580>], 'Tidal': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91220>], 'GooglePlay': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91430>], 'Discogs': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91100>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b954f0>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95af0>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b950d0>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b957c0>], 'IMDB': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91370>], 'AllMusic': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91b20>], 'SecondhandSongs': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91760>], 'Wikidata': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b91190>], 'Muzikum': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b951c0>], 'Facebook': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b95f40>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95490>], 'Soundcloud': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b958b0>], 'VIAF': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b955b0>], 'Apple': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b952b0>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95b20>, <artistDBBase.artistDBLinkClass object at 0x7fa3c1b95ca0>], 'Genius': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b95640>], 'IMVBD': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b95be0>], 'WhoSampled': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b95ee0>], 'SetListFM': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b95820>], 'Instagram': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b95910>], 'Deezer': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1b95b50>, <artistDBBase.artistDBLinkCl ...
# Pages:   {'ppp': 1, 'tot': 1, 'pages': 1, 'err': None, 'more': False, 'redo': False}
# Media:   {'counts': {'Releases': {'Album': 56, 'Album + Compilation': 58, 'Album + Demo': 2, 'Album + Live': 86, 'Album + Mixtape/Street': 1, 'Album + Remix': 5, 'Album + Soundtrack': 3, 'Compilation': 5, 'EP': 10, 'EP + Compilation': 1, 'Other': 3, 'Other + Compilation': 2, 'Other + Interview': 2, 'Other + Live': 1, 'Single': 81, 'Single + Demo': 1, 'Single + Live': 2, 'Single + Remix': 3, 'Unknown': 29, 'Song': 656, 'OtherWork': 57, 'Prose': 6, 'Recordings': 445}}, 'err': None}
#    Album
#       Prince
#       For You
#       Emancipation
#       Come
#       Sign “☮︎” the Times
#       The Vault... Old Friends 4 Sale
#       1999
#       Crystal Ball
#       Black Album
#       Dirty Mind
#       Lovesexy
#       The Gold Experience
#       One Nite Alone... Solo Piano and Voice by Prince
#       Chaos and Disorder
#       Controversy
#       N.E.W.S.
#       Xpectation
#       Rave Un2 the Joy Fantastic
#       The Rainbow Children
#       Musicology
#       Trax From the NPG Music Club, Volume One: The Chocolate Invasion
#       DePosition
#       3121
#       Planet Earth
#       Blue
#       The Undertaker
#       20Ten
#       Camille
#       3rdeyegirl
#       Lotusflow3r
#       Art Official Age
#       Chicken Grease
#       HITnRUN Phase One
#       Mplsound
#       HITnRUN Phase Two
#       Open Sessions Vol. 1
#       Charade
#       Yellow
#       Crystal Ball
#       The Truth
#       Nudity
#       Sacrifice
#       Girl Thang
#       Oakland 2001
#       Sound & Vision 5 - TV Appearances 1998-2000
#       12 Inch: 1976–1988, Volume 1
#       Welcome 2 The Beautiful Experience
#       Sign “☮︎” the Times Rehearsal Sessions 1.0
#       Sign O' The Times Rehearsal Sessions 2.0
#       12 Inch & B Sides
#       30 Years Of Unreleased Funk Vol.1
#       30 Years Of Unreleased Funk Vol.2
#       30 Years Of Unreleased Funk Vol.3
#       Musicology Release Party
#       The Purple Era
#       Welcome 2 America
#    Album + Compilation
#       The Hits 1
#       The Hits 2
#       Dreams
#       The Very Best of Prince
#       Dance De Luxe
#       The Undertaker
#       Black Album / Crystal Ball
#       Bootleg Collection, Volume 1
#       12" Singles Collection, Volume 3
#       The Work, Volume 1: Demos and Outtakes 1976-1984
#       The Work, Volume 2: Demos and Outtakes 1984-1988
#       The Work, Volume 3: Demos and Outtakes 1988-1991
#       The Work, Volume 4: Demos and Outtakes 1991-1994
#       The Work, Volume 5: Demos and Outtakes 1995-2001
#       The Hits/The B-Sides
#       Ultra Rare Trax, Volume 2
#       Ultimate
#       Studio Nights: The Rebels
#       Extended Member of the Royal Household
#       Xpectation: New Directions in Music from Prince
#       The 1994 Radio Promo DAT
#       12″ Archive 2.0
#       The Dawn (4.1)
#       Best Ballads
#       Original Album Series
#       City Lights Remastered And Extended Volume 5: The 1986 U.S. Hit & Run Tour And The Parade World Tour 1986
#       Quintessential 12 Inch Collection
#       City Lights Remastered and Extended Volume 2: The Controversy Tour (1981-1982)
#       City Lights Remastered and Extended Volume 3: 1999 Tour (1982-1983)
#       12″ Single Archive
#       The Evolution: Singles, Downloads, Broadcasts and Streams (2007-2014)
#       City Lights Remastered And Extended Volume 6: The Sign O' The Times Tour 1987
#       City Lights Remastered And Extended Volume 7: The Lovesexy World Tour 1988/1989
#       City Lights Remastered And Extended Volume 4: The Purple Rain Tour 1984/1985, Featuring Sheila E. & Band
#       Xpectation: New Directions in Music From Prince
#       4Ever
#       The Crown Jewels
#       Studio Nights (Demos And Outtakes 1976-1987)
#       Blast From the Past 1.0
#       Ultra Rare Trax Vol. 1
#       Live USA
#       Driving To Midnight Mess
#       Anthology: 1995-2010
#       Columbus High
#       Live USA
#       Ultimate Rave
#       TV Appearances 1991-1993
#       Can I Play With U ? "The Flesh" Sessions 1985/86 Studio Outtakes
#       Brave New Wold
#       Into The Vault
#       Sun, Moon & Stars
#       Beautiful Strange: Cafe De Paris
#       Vavoom!
#       Up All Nite With Prince (The One Nite Alone Collection)
#       All My Dreams
#       Transmission Impossible
#       Blast From the Past 2.0
#       Blast From the Past 3.0
#    Album + Demo
#       Piano & a Microphone 1983
#       Originals
#    Album + Live
#       The Park, Volume 2
#       Funky Party 2Nite
#       Miles 2 Nowhere
#       Nightclubbing
#       One Nite Alone in Chicago
#       Secret Gig
#       Return of the Bump Squad
#       Small Club
#       Small Club
#       Miles From the Park
#       1988-09-09: Lovesexy: Dortmund, Germany
#       City Lights: Stockholm
#       Nude Tour - 1990 Live in Tokio
#       1993-04-12: What's Hip: DNA Lounge, San Francisco, CA, USA
#       City Lights: Detroit/Providence
#       R U Gonna Go My Way?
#       Now's the Time
#       R U Xperienced
#       C-Note
#       City Lights: Paris (1981-06-03)
#       The Homecoming
#       One Nite Not So Alone
#       2KTV
#       Parade Around the World 1-3
#       2004-02-15: The Fillmore, San Francisco, CA, USA
#       1989-02-07: Nagoya, Japan
#       Tokyo 1990
#       Wonderboy
#       Birthday Parade
#       Left Eye
#       Live USA
#       Neon Rendezvous
#       Oh Oh Ohhh
#       One Nite Alone Live in Japan
#       Outrageously Live!
#       Trojan Horse Aftershow '88
#       Villanova Park
#       Indigo Nights
#       1985-01-04: City Lights: Atlanta '85: The Omni, Atlanta, GA, USA
#       1999 Revisited
#       Estandard
#       This Is My Night
#       Abu Dhabi 20ten
#       1987-03-21: 4 Those of U on Valium
#       Paris Affair
#       Columbia '81
#       Saginaw '82
#       Detroit '82
#       Providence '83
#       Le New Morning '87
#       City Lights Remastered And Extended Volume 5: The 1986 U.S. Hit & Run Tour And The Parade World Tour 1986
#       Live USA 81
#       Sexy M.F. Tour '92
#       The Story 1
#       The Story 2
#       Prince Live (Unapproved)
#       Montreux Musicology
#       City Lights Remastered and Extended Volume 2: The Controversy Tour (1981-1982)
#       City Lights Remastered and Extended Volume 3: 1999 Tour (1982-1983)
#       One Nite... Not So Alone
#       City Lights Remastered And Extended Volume 6: The Sign O' The Times Tour 1987
#       City Lights Remastered And Extended Volume 7: The Lovesexy World Tour 1988/1989
#       City Lights Remastered And Extended Volume 1: The Prince And Dirty Mind Tours 1979-1981
#       City Lights Remastered And Extended Volume 4: The Purple Rain Tour 1984/1985, Featuring Sheila E. & Band
#       Live in Rotterdam 28.5.1992
#       Live at the Aladdin Las Vegas
#       After Concert Show
#       Prince In Rehersal
#       Purple Morning
#       Live USA
#       Live & Alive Vol. 1
#       Live & Alive Vol. 2
#       Live & Alive - Live in Holland
#       Live & Alive
#       Live & Alive
#       At the Club: Miami Broadcast 1994
#       Live USA
#       3 Nites in Miami Glam Slam, '94
#       Purple Waves: Broadcasting Live 1985-1990
#       TV Appearances 1991-1993
#       Osaka '89
#       Flesh For Fantasy
#       The Pod
#       Rock in Rio, 1991
#       One Nite Alone In L.A.
#       Take Me With U (Live)
#    Album + Mixtape/Street
#       The VERSACE Experience: Prelude 2 Gold
#    Album + Remix
#       1999: The New Master
#       The Comin' King: Brain Attack Remixes 1995
#       The Unreleased Mixes
#       Rave In2 the Joy Fantastic
#       The Greatest Romance Ever Sold
#    Album + Soundtrack
#       Batman
#       Girl 6
#       Graffiti Bridge
#    Compilation
#       Blast From the Past 4.0
#       Blast From the Past 5.0
#       Cosmos
#       H2O
#       Broadcast Four
#    EP
#       The Beautiful Experience
#       94 East
#       The Scandalous Sex Suite
#       My Name Is Prince
#       The Breakfast Experience
#       I’ll Do Anything
#       Cinnamon Girl
#       Deliverance
#       His Majesty’s Pop Life / The Purple Mix Club
#       Live From Paisley Park EP
#    EP + Compilation
#       New Power Generation (Funky Weapon remix)
#    Other
#       The Jewel Box II
#       Husney’s: A Work In Progress
#       The Hits Collection
#    Other + Compilation
#       Work It, Volume 1
#       Work It, Volume 2
#    Other + Interview
#       Prince Interview Picture Disc
#       Interview '85
#    Other + Live
#       Sign “☮︎” the Times
#    Single
#       CyberSingle
#       Betcha by Golly Wow! / Right Back Here in My Arms
#       Thieves in the Temple
#       Controversy
#       The Future
#       U Make My Sun Shine
#       Purple Medley
#       The Scandalous Sex Suite
#       Batdance
#       Partyman
#       The Arms of Orion
#       Letitgo
#       Little Red Corvette
#       Let’s Work / Gotta Stop (Messin’ About)
#       Delirious
#       Let's Pretend We're Married / Irresistable Bitch
#       The Most Beautiful Girl in the World
#       Erotic City / I Would Die 4 U
#       Space
#       The Greatest Romance Ever Sold
#       Te Amo Corazón
#       Dinner With Delores
#       S.S.T.
#       Come On
#       U Got the Look
#       Peach
#       If I Was Your Girlfriend
#       1999
#       When Doves Cry
#       I Hate U
#       Gold
#       The Truth
#       The Holy River
#       Fury
#       The War
#       Extraloveable
#       Sign “☮︎” the Times
#       I Could Never Take the Place of Your Man
#       I Wanna Be Your Lover
#       Uptown
#       Black Sweat
#       Screwdriver
#       Ain't Gonna Miss U When U're Gone
#       Extraloveable Reloaded
#       Royal Mix
#       Breakfast Can Wait
#       Fallinlove2nite
#       The Breakdown
#       Da Bourgeoisie
#       CLOUDS
#       U KNOW
#       FUNKNROLL
#       Alphabet St.
#       Stare
#       Hardrocklover
#       Glam Slam
#       I Wish U Heaven
#       Pink Cashmere
#       The Song of the Heart
#       Free Urself
#       If Eye Could Get Ur Attention
#       Kiss
#       Little Red Corvette / 1999
#       Nothing Compares 2 U
#       Dance 4 Me
#       Partyman (Remixes)
#       Mary Don't You Weep
#       17 Days
#       My Computer / Shhh
#       I Feel for You (Acoustic Demo)
#       Rock ’n’ Roll Is Alive! (And It Lives in Minneapolis)
#       Don’t Let Him Fool Ya
#       Cinnamon Girl
#       Call My Name
#       Musicology
#       Witness 4 the Prosecution (version 1)
#       Dance Music Sex Romance
#       Cosmic Day
#       Batdance
#       Controversy
#       Soft and Wet
#    Single + Demo
#       Batdance
#    Single + Live
#       2004 Grammys (live)
#       Joy in Repetition (SOH live)
#    Single + Remix
#       Rock and Roll Love Affair
#       The Greatest Romance Ever Sold (Neptunes remix)
#       Venus de Milo (A Trackademicks Vibe)
#    Unknown
#       Beautiful Strange: Cafe de Paris
#       Licence to Funk
#       London Calling - London Week # 3
#       Vienna Ball
#       C3L.A.bration 2009
#       Swiss Castle Magic
#       All Day, All Night, All Week!
#       Riviera Affairs
#       La Coruna
#       New York City 2002: It Ain't Over!
#       Welcome 2 America - Volume 1 Izod
#       Welcome 2 America Reel 1 IZOD
#       Welcome 2 America Reel 2 - The Garden
#       Welcome 2 America Reel 3 - The Garden 2011
#       Piano & A Microphone Gala Event
#       Peach And Black
#       Intimate Moments
#       Small Club
#       Acoustic Love Affair
#       Midnight Blues
#       Denver 12th May 13
#       Ultimate Vol. 3
#       Mohegan Sun Volume One
#       Mohegan Sun Volume Two
#       Mohegan Sun Volume Three
#       Funkin' Copenhagen
#       Atlanta 2016
#       Live 4 Love
#       One Nite Alone In Washington
#    Song
#       Automatic
#       Automatic
#       Free
#       Free
#       Lady Cab Driver
#       Lady Cab Driver
#       All the Critics Love U in New York
#       All the Critics Love U in New York
#       Hot Thing
#       Hot Thing
#       P Control
#       P Control
#       Play in the Sunshine
#       Play in the Sunshine
#       Housequake
#       Housequake
#       Bliss
#       Slow Love
#       Slow Love
#       It’s Gonna Be a Beautiful Night
#       It’s Gonna Be a Beautiful Night
#       Mind Bells
#       Strange Relationship
#       Strange Relationship
#       MIND BELLS
#       Adore
#       Adore
#       I Wanna Be Your Lover
#       I Wanna Be Your Lover
#       BLISS
#       My Love Is Forever
#       My Love Is Forever
#       Computer Blue
#       Computer Blue
#       I Would Die 4 U
#       I Would Die 4 U
#       Baby I’m a Star
#       Baby I’m a Star
#       Crazy You
#       Crazy You
#       17 Days
#       17 Days
#       International Lover
#       International Lover
#       The Beautiful Ones
#       The Beautiful Ones
#       Let’s Go Crazy
#       Let’s Go Crazy
#       Take Me With U
#       Take Me With U
#       Darling Nikki
#       Darling Nikki
#       The Cross
#       The Cross
#       Anotherloverholenyohead
#       Gotta Broken Heart Again
#       Gotta Broken Heart Again
#       Partyup
#       Partyup
#       Uptown
#       Uptown
#       Dirty Mind
#       Dirty Mind
#       Head
#       Head
#       Do It All Night
#       Do It All Night
#       Sister
#       Sister
#       When You Were Mine
#       When You Were Mine
#       Dance On
#       Dance On
#       Controversy
#       Controversy
#       Do Me, Baby
#       Sexy MF
#       How Come U Don’t Call Me Anymore?
#       How Come U Don’t Call Me Anymore?
#       Kiss
#       Kiss
#       I Feel for You
#       I Feel for You
#       Manic Monday
#       Manic Monday
#       Stand Back
#       Just Another Sucker
#       Just Another Sucker
#       Girls & Boys
#       Girls & Boys
#       Mountains
#       Delirious
#       Delirious
#       Peach
#       Peach
#       Pope
#       Pope
#       Raspberry Beret
#       Raspberry Beret
#       Cream
#       Cream
#       Little Red Corvette
#       Little Red Corvette
#       I ha di gärn gha
#       I ha di gärn gha
#       D.M.S.R.
#       D.M.S.R.
#       Thieves in the Temple
#       Thieves in the Temple
#       Sugar Walls
#       Joy in Repetition
#       Joy in Repetition
#       The Glamorous Life
#       The Glamorous Life
#       Elephants and Flowers
#       Elephants and Flowers
#       Waiting Room
#       Love Song
#       Money Don’t Matter 2 Night
#       Money Don’t Matter 2 Night
#       Breakdown
#       Breakdown
#       Marz
#       Tictactoe
#       Affirmation I & II
#       Affirmation I & II
#       Way Back Home
#       Way Back Home
#       Time
#       Time
#       Art Official Cage
#       Art Official Cage
#       Clouds
#       Clouds
#       Wow
#       The Gold Standard
#       The Gold Standard
#       U Know
#       U Know
#       Breakfast Can Wait
#       Breakfast Can Wait
#       This Could Be Us
#       This Could Be Us
#       What It Feels Like
#       What It Feels Like
#       Affirmation III
#       Affirmation III
#       Pretzelbodylogic
#       Aintturninround
#       Plectumelectrum
#       Whitecaps
#       Fixurlifeup
#       Boytrouble
#       Stopthistrain
#       Anotherlove
#       We Can Funk
#       Love Machine
#       Tick, Tick, Bang
#       Tick, Tick, Bang
#       Shake
#       The Latest Fashion
#       Still Would Stand All Time
#       Still Would Stand All Time
#       Graffiti Bridge
#       Graffiti Bridge
#       Electric Chair
#       Electric Chair
#       Electric Chair
#       The Arms of Orion
#       The Arms of Orion
#       Partyman
#       Partyman
#       Partyman
#       Vicki Waiting
#       Vicki Waiting
#       Vicki Waiting
#       Trust
#       Trust
#       Trust
#       Lemon Crush
#       Lemon Crush
#       Lemon Crush
#       Scandalous
#       Scandalous
#       Scandalous
#       Batdance
#       Batdance
#       Batdance
#       Diamonds and Pearls
#       Diamonds and Pearls
#       Daddy Pop
#       Daddy Pop
#       Eye No
#       Eye No
#       Glam Slam
#       Glam Slam
#       Anna Stesia
#       Anna Stesia
#       Lovesexy
#       Lovesexy
#       When 2 R in Love
#       When 2 R in Love
#       I Wish U Heaven
#       I Wish U Heaven
#       Positivity
#       Positivity
#       Le Grind
#       Le Grind
#       Cindy C.
#       Cindy C.
#       Dead on It
#       Dead on It
#       Bob George
#       Bob George
#       Superfunkycalifragisexy
#       Superfunkycalifragisexy
#       2 Nigs United 4 West Compton
#       2 Nigs United 4 West Compton
#       New Power Generation
#       New Power Generation
#       Release It
#       Thunder
#       Thunder
#       Strollin’
#       Strollin’
#       Willing and Able
#       Walk Don’t Walk
#       Walk Don’t Walk
#       Push
#       Insatiable
#       Insatiable
#       Live 4 Love
#       My Name Is Prince
#       I Wanna Melt With U
#       I Wanna Melt With U
#       And God Created Woman
#       And God Created Woman
#       Jughead
#       The Morning Papers
#       The Morning Papers
#       Alphabet Street
#       Alphabet Street
#       Rockhard in a Funky Place
#       Rockhard in a Funky Place
#       1999
#       1999
#       Born 2 B.R.E.E.D.
#       Love 2 The 9’s
#       Love 2 The 9’s
#       She’s Always in My Hair
#       She’s Always in My Hair
#       Let’s Pretend We’re Married
#       Let’s Pretend We’re Married
#       101
#       101
#       Cool Love
#       Cool Love
#       Neon Telephone
#       Heartz of Men
#       What’z Ya Phone #
#       When Doves Cry
#       When Doves Cry
#       Gett Off
#       Gett Off
#       Purple Rain
#       Purple Rain
#       Nothing Compares 2 U
#       Nothing Compares 2 U
#       Possessed
#       Possessed
#       God
#       God
#       100 MPH
#       100 MPH
#       The Work Part 1
#       The Work Part 1
#       A Love Bizarre
#       A Love Bizarre
#       A Love Bizarre
#       U Got the Look
#       U Got the Look
#       The Ballad of Dorothy Parker
#       The Ballad of Dorothy Parker
#       Starfish and Coffee
#       Starfish and Coffee
#       Forever in My Life
#       Forever in My Life
#       If I Was Your Girlfriend
#       If I Was Your Girlfriend
#       I Could Never Take the Place of Your Man
#       I Could Never Take the Place of Your Man
#       Mutiny
#       4 the Tears in Your Eyes
#       4 the Tears in Your Eyes
#       Drive Me Wild
#       Drive Me Wild
#       Drive Me Wild
#       Drive Me Wild
#       Electric Intercourse
#       Electric Intercourse
#       Electric Intercourse
#       Erotic City
#       Erotic City
#       Erotic City
#       Eternity
#       Eternity
#       Sticky Wicked
#       Sticky Wicked
#       Come 2 My House
#       This Crazy Life of Mine
#       Pop My Clutch
#       Journey 2 the Center of Your Heart
#       Journey 2 the Center of Your Heart
#       Democrazy
#       I Remember U
#       Reconsider (U Betta)
#       Don't Talk 2 Strangers
#       Don't Talk 2 Strangers
#       Why You Wanna Treat Me So Bad?
#       Why You Wanna Treat Me So Bad?
#       Sexy Dancer
#       Sexy Dancer
#       With You
#       With You
#       Bambi
#       Bambi
#       Still Waiting
#       Still Waiting
#       It’s Gonna Be Lonely
#       It’s Gonna Be Lonely
#       The Max
#       The Max
#       Blue Light
#       Blue Light
#       1+1+1 is 3
#       1+1+1 is 3
#       1+1+1 is 3
#       U Want Me
#       U Want Me
#       Family Name
#       Family Name
#       Family Name
#       The Continental
#       The Continental
#       Arrogance
#       Arrogance
#       The Everlasting Now
#       The Everlasting Now
#       The Everlasting Now
#       The Everlasting Now
#       The Flow
#       The Ride
#       The Ride
#       The Ride
#       The Ride
#       3 Chains o' Gold
#       3 Chains o' Gold
#       The Sacrifice of Victor
#       The Sacrifice of Victor
#       Something in the Water (Does Not Compute)
#       Something in the Water (Does Not Compute)
#       The Most Beautiful Girl in the World
#       The Most Beautiful Girl in the World
#       Irresistible Bitch
#       Irresistible Bitch
#       3121
#       3121
#       3121
#       The One
#       The One
#       The Question of U
#       The Question of U
#       The Question of U
#       For You
#       Soft and Wet
#       In Love
#       In Love
#       Just as Long as We’re Together
#       Just as Long as We’re Together
#       Baby
#       Baby
#       So Blue
#       So Blue
#       I’m Yours
#       I’m Yours
#       I Am
#       On the Way Up
#       Playgirl
#       Love’s No Fun
#       Oooh This I Need
#       Hello
#       200 Balloons
#       200 Balloons
#       Escape
#       Escape
#       Gotta Stop (Messin’ About)
#       Gotta Stop (Messin’ About)
#       Horny Toad
#       Horny Toad
#       Feel U Up
#       Feel U Up
#       Girl
#       I Love U in Me
#       I Love U in Me
#       Shockadelica
#       Shockadelica
#       La, La, La, He, He, Hee
#       La, La, La, He, He, Hee
#       Another Lonely Christmas
#       Power Fantastic
#       Power Fantastic
#       Scarlet Pussy
#       Scarlet Pussy
#       Johnny
#       Melody Cool
#       Melody Cool
#       Melody Cool
#       Melody Cool
#       I Hate U
#       I Hate U
#       Rock and Roll Is Alive! (and It Lives in Minneapolis)
#       Get Wild
#       Endorphinmachine
#       Endorphinmachine
#       Shhh
#       Shhh
#       We March
#       We March
#       Dolphin
#       Dolphin
#       Now
#       Now
#       319
#       319
#       Shy
#       Shy
#       Billy Jack Bitch
#       Billy Jack Bitch
#       Wednesday
#       Wednesday
#       Cold Coffee & Cocaine
#       Cold Coffee & Cocaine
#       Why the Butterflies
#       Why the Butterflies
#       Christopher Tracy’s Parade
#       I Wonder U
#       Martika’s Kitchen
#       Spirit
#       Love… Thy Will Be Done
#       Don’t Say U Love Me
#       Sex Shooter
#       Sex Shooter
#       Jungle Love
#       Noon Rendezvous
#       Make-Up
#       Make-Up
#       You’re My Love
#       You’re My Love
#       Holly Rock
#       Gigolos Get Lonely Too
#       Gigolos Get Lonely Too
#       Baby, You’re a Trip
#       Baby, You’re a Trip
#       Dear Michaelangelo
#       Wouldn’t You Love to Love Me?
#       I Hear Your Voice
#       Yo Mister
#       Love 89
#       Five Women
#       Five Women
#       Sunday Afternoon
#       Black Sweat
#       Black Sweat
#       Extraloveable
#       Extraloveable
#       Planet Earth
#       Planet Earth
#       Guitar
#       Guitar
#       Somewhere Here on Earth
#       Somewhere Here on Earth
#       The One U Wanna C
#       The One U Wanna C
#       Future Baby Mama
#       Future Baby Mama
#       Mr. Goodnight
#       Mr. Goodnight
#       All the Midnights in the World
#       All the Midnights in the World
#       Chelsea Rodgers
#       Chelsea Rodgers
#       Lion of Judah
#       Lion of Judah
#       Resolution
#       Resolution
#       When We’re Dancing Close and Slow
#       When We’re Dancing Close and Slow
#       Million $ Show
#       Gold
#       Gold
#       Funknroll
#       Funknroll
#       Funknroll
#       I’ll Never B Another Fool
#       America
#       America
#       Sign “☮︎” the Times
#       Sign “☮︎” the Times
#       Musicology
#       Musicology
#       Illusion, Coma, Pimp & Circumstance
#       Illusion, Coma, Pimp & Circumstance
#       A Million Days
#       A Million Days
#       Life ’o’ the Party
#       Life ’o’ the Party
#       Cinnamon Girl
#       Cinnamon Girl
#       What Do U Want Me 2 Do?
#       What Do U Want Me 2 Do?
#       The Marrying Kind
#       The Marrying Kind
#       If Eye Was the Man in Ur Life
#       If Eye Was the Man in Ur Life
#       On the Couch
#       On the Couch
#       Dear Mr. Man
#       Dear Mr. Man
#       Reflection
#       Reflection
#       Call My Name
#       Call My Name
#       Compassion
#       Compassion
#       Beginning Endlessly
#       Beginning Endlessly
#       Future Soul Song
#       Future Soul Song
#       Sticky Like Glue
#       Sticky Like Glue
#       Act of God
#       Act of God
#       Lavaux
#       Lavaux
#       Walk in Sand
#       Walk in Sand
#       Sea of Everything
#       Sea of Everything
#       Everybody Loves Me
#       Everybody Loves Me
#       Laydown
#       Laydown
#       The Rest of My Life
#       The Rest of My Life
#       It's About That Walk
#       It's About That Walk
#       She Spoke 2 Me
#       She Spoke 2 Me
#       When the Lights Go Down
#       When the Lights Go Down
#       My Little Pill
#       My Little Pill
#       There Is Lonely
#       There Is Lonely
#       Old Friends 4 Sale
#       Old Friends 4 Sale
#       Sarah
#       Sarah
#       Extraordinary
#       Extraordinary
#       Ice Cream Castles
#       My Drawers
#       My Drawers
#       Chili Sauce
#       Chili Sauce
#       If the Kid Can't Make You Come
#       If the Kid Can't Make You Come
#       The Bird
#       Pray
#       Ich bin nicht Dein Mann
#       Under the Cherry Moon
#       Someone 2 Call
#       Pop Life
#       Pop Life
#       Pink Cashmere
#       Would You Die for Me
#       All My Dreams
#       All My Dreams
#       Teacher, Teacher
#       Teacher, Teacher
#       Wonderful Day
#       Wonderful Day
#       Love and Sex
#       Love and Sex
#       A Place in Heaven
#       A Place in Heaven
#       Big Tall Wall
#       Big Tall Wall
#       In a Large Room With No Light
#       In a Large Room With No Light
#       Train
#       Train
#       Eggplant
#       Eggplant
#       Everybody Want What They Don’t Got
#       Everybody Want What They Don’t Got
#       Blanche
#       Blanche
#       Soul Psychodelicide
#       Soul Psychodelicide
#       The Ball
#       The Ball
#       Adonis and Bathsheba
#       Adonis and Bathsheba
#       Crucial
#       Crucial
#       Crucial
#       Crucial
#       The Cocoa Boys
#       The Cocoa Boys
#       When the Dawn of the Morning Comes
#       When the Dawn of the Morning Comes
#       It Be’s Like That Sometimes
#       It Be’s Like That Sometimes
#       Emotional Pump
#       Emotional Pump
#       Rebirth of the Flesh
#       Rebirth of the Flesh
#       Cosmic Day
#       Cosmic Day
#       Walkin’ in Glory
#       Walkin’ in Glory
#       Wally
#       Wally
#       I Need a Man
#       I Need a Man
#       Promise to Be True
#       Promise to Be True
#       Jealous Girl
#       Jealous Girl
#       There’s Something I Like About Being Your Fool
#       There’s Something I Like About Being Your Fool
#       It
#       It
#       In a Word or 2
#       Beautiful, Loved & Blessed
#       Can’t Stop This Feeling I Got
#       Can’t Stop This Feeling I Got
#       Round and Round
#       Round and Round
#       Damn U
#       Damn U
#       Sweet Baby
#       Sweet Baby
#       7
#       14,400 Minutes
#    OtherWork
#       America Number One
#       Sexuality
#       Sexuality
#       Private Joy
#       Private Joy
#       The Future
#       The Future
#       The Future
#       Around the World in a Day
#       Paisley Park
#       Condition of the Heart
#       Tamborine
#       The Ladder
#       Temptation
#       Ronnie, Talk to Russia
#       Ronnie, Talk to Russia
#       Annie Christian
#       Annie Christian
#       Jack U Off
#       Jack U Off
#       Sometimes It Snows in April
#       One
#       Two
#       Three
#       Four
#       Five
#       Six
#       Seven
#       Eight
#       Nine
#       Ten
#       Eleven
#       Twelve
#       Solo
#       The Song of the Heart
#       The Song of the Heart
#       Zeester met koffie
#       Zeester met koffie
#       ’03 Bonnie & Clyde
#       ’03 Bonnie & Clyde
#       Let’s Work
#       Let’s Work
#       Segue
#       U
#       U
#       Thirteen
#       Fourteen
#       Fifteen
#       Sixteen
#       Can I Play With U?
#       Witness 4 the Prosecution
#       Witness 4 the Prosecution
#       And That Says What?
#       Crystal Ball
#       Crystal Ball
#       It Ain’t Over ’til the Fat Lady Sings
#       Soul Psychodelicide
#    Prose
#       NPG Operator
#       NPG Operator
#       NPG Operator
#       NPG Operator
#       NPG Operator
#       NPG Operator
#    Recordings
#       0
#       3
#       6
#       9
#       15
#       21
#       26
#       30
#       32
#       34
#       36
#       39
#       45
#       51
#       55
#       59
#       62
#       64
#       67
#       69
#       70
#       72
#       74
#       76
#       78
#       80
#       82
#       85
#       86
#       87
#       88
#       90
#       93
#       96
#       99
#       102
#       105
#       111
#       116
#       118
#       120
#       124
#       126
#       128
#       130
#       132
#       135
#       138
#       144
#       148
#       152
#       157
#       158
#       162
#       163
#       164
#       165
#       167
#       169
#       171
#       173
#       175
#       177
#       178
#       180
#       182
#       184
#       189
#       194
#       199
#       204
#       209
#       211
#       212
#       213
#       214
#       215
#       218
#       224
#       229
#       231
#       233
#       235
#       241
#       247
#       251
#       255
#       259
#       263
#       264
#       266
#       273
#       274
#       276
#       278
#       280
#       282
#       284
#       286
#       288
#       290
#       292
#       297
#       299
#       305
#       306
#       307
#       308
#       309
#       310
#       311
#       312
#       313
#       314
#       315
#       317
#       318
#       319
#       320
#       321
#       322
#       324
#       326
#       329
#       330
#       331
#       332
#       333
#       336
#       339
#       342
#       349
#       354
#       355
#       357
#       359
#       361
#       363
#       365
#       367
#       369
#       371
#       375
#       379
#       381
#       382
#       383
#       384
#       386
#       388
#       389
#       390
#       392
#       394
#       396
#       401
#       402
#       404
#       406
#       408
#       413
#       418
#       423
#       428
#       433
#       438
#       443
#       448
#       453
#       454
#       458
#       462
#       464
#       467
#       468
#       469
#       470
#       471
#       472
#       473
#       474
#       475
#       476
#       477
#       478
#       479
#       480
#       481
#       482
#       483
#       484
#       485
#       489
#       492
#       493
#       494
#       495
#       496
#       497
#       499
#       501
#       503
#       507
#       513
#       514
#       515
#       516
#       518
#       520
#       523
#       526
#       529
#       534
#       538
#       542
#       546
#       549
#       554
#       557
#       558
#       559
#       561
#       565
#       569
#       575
#       578
#       579
#       581
#       586
#       587
#       591
#       593
#       598
#       601
#       605
#       609
#       612
#       615
#       618
#       621
#       622
#       627
#       628
#       629
#       630
#       631
#       632
#       633
#       634
#       635
#       636
#       638
#       639
#       640
#       644
#       649
#       652
#       655
#       661
#       664
#       665
#       667
#       669
#       672
#       673
#       676
#       677
#       678
#       679
#       680
#       682
#       685
#       686
#       691
#       696
#       701
#       705
#       708
#       709
#       711
#       712
#       713
#       714
#       719
#       720
#       721
#       722
#       723
#       724
#       725
#       726
#       727
#       728
#       729
#       730
#       731
#       732
#       733
#       734
#       735
#       738
#       741
#       744
#       747
#       751
#       755
#       761
#       764
#       768
#       771
#       774
#       778
#       781
#       784
#       788
#       792
#       796
#       800
#       804
#       805
#       812
#       815
#       816
#       817
#       820
#       821
#       826
#       829
#       832
#       835
#       838
#       841
#       844
#       847
#       849
#       852
#       858
#       861
#       864
#       867
#       872
#       874
#       876
#       878
#       880
#       882
#       887
#       891
#       894
#       897
#       902
#       906
#       907
#       908
#       910
#       911
#       915
#       917
#       918
#       919
#       920
#       921
#       923
#       925
#       927
#       932
#       937
#       938
#       939
#       940
#       941
#       942
#       943
#       944
#       945
#       946
#       947
#       948
#       949
#       950
#       951
#       952
#       953
#       954
#       955
#       956
#       957
#       958
#       959
#       960
#       961
#       962
#       963
#       964
#       965
#       966
#       967
#       968
#       969
#       970
#       971
#       972
#       973
#       974
#       975
#       976
#       977
#       978
#       979
#       980
#       981
#       984
#       987
#       988
#       990
#       992
#       996
#       999
#       1002
#       1006
#       1010
#       1016
#       1019
#       1021
#       1024
#       1027
#       1029
#       1031
#       1033
#       1038
#       1043
#       1045
#       1046
#       1047
#       1051
#       1055
#       1059
#       1063
#       1064
#       1068
#       1072
#       1076
#       1079
#       1084
#       1085

# %%
modValData['251108434349887660386335524263902329399'].show()
# Out:
# Artist Data Class
# -------------------------
# Artist:  米巍
# Meta:    None
#          https://musicbrainz.org/artist/c4596d2d-de50-4388-aca3-f9abb313918d
# Info:    None
#          None
#          2021-12-15 12:03:26.427993
# URL:     https://musicbrainz.org/artist/c4596d2d-de50-4388-aca3-f9abb313918d
# ID:      251108434349887660386335524263902329399
# Profile: {'general': {'SortName': 'Mi, Wei', 'Aliases': nan, 'County': 'China', 'Formed': NaT, 'Disbanded': NaT, 'ArtistType': 'Person', 'ISNI': nan}, 'genres': None, 'tags': None, 'external': {'Discogs': [<artistDBBase.artistDBLinkClass object at 0x7fa3c1294d30>]}, 'extra': None, 'err': None}
# Pages:   {'ppp': 1, 'tot': 1, 'pages': 1, 'err': None, 'more': False, 'redo': False}
# Media:   {'counts': {'Releases': {'Recordings': 4}}, 'err': None}
#    Recordings
#       0
#       1
#       2
#       3

# %% [markdown]
# # Merge With Known DB

# %%
ts = timestat("Merging DBs")
for n,modVal in enumerate(range(100)):
    newDB = Series(io.get("/Volumes/Seagate/DB/MusicBrainzDBData/{0}-DB.p".format(modVal)))
    known = io.get("/Users/tgadfort/dbdiscogs/artists-musicbrainz-db/{0}-DB.p".format(modVal))
    
    toMerge = newDB[~newDB.index.isin(known.index)]
    fullDB = concat([known,toMerge]).sort_index()
    io.save(idata=fullDB, ifile="/Users/tgadfort/dbdiscogs/artists-musicbrainz-db/full/{0}-DB.p".format(modVal))
    ts.update(n=n+1,N=100)
ts.stop()

# %%
known.shape

# %%
tmp['172552485256597266680385033568580864600'].show()

# %%
masterArtistData = artistData['artist'][["ArtistGID", "ArtistName", "ArtistSortName", "Formed", "Disbanded"]].copy(deep=True)
masterArtistNumAlbums = artistIDNumReleaseGroups.join(artistIDNumRelease, how='outer')
masterArtistData = masterArtistData.join(masterArtistNumAlbums)
masterArtistData["NumReleaseGroups"] = masterArtistData["NumReleaseGroups"].fillna(0).apply(int)
masterArtistData["NumReleases"] = masterArtistData["NumReleases"].fillna(0).apply(int)

# %%
masterArtistData

# %%
masterartistNumAlbums

# %%
artistIDNumReleaseGroups.shape

# %%
artistIDNumRelease.shape

# %%
artistData['artist'][artistData['artist']['ArtistID'] == aIDs["ArianaGrande"]]

# %%
artistData['artist'][artistData['artist']['ArtistID'] == aIDs["BuddyHolly"]]

# %%
artistData['artist'][artistData['artist']['ArtistID'] == aIDs["Bono"]]

# %%
artistData['artist'][artistData['artist']['ArtistID'] == aIDs["Rupaul"]]

# %%
artistData['artist'][artistData['artist']['ArtistID'] == aIDs["U2"]]

# %%
artistData['artist'][artistData['artist']['ArtistID'] == aIDs["DMB"]]

# %%
artistData['artist']["NA18"].value_counts()

# %%
artistData['artist']["NA9"].value_counts()

# %%
artistData['artist']['NA12'].unique()

# %%
artistData['artist']['NA5'].unique()

# %%
artistData['artist'][artistData['artist']['ArtistGID'] == '7f347782-eb14-40c3-98e2-17b6e1bfe56c']

# %%
artistData["artist"][artistData["artist"]["ArtistID"] == 502]

# %%
artistData["artist"]['NA10'].unique()

# %%
artistData["artist"][artistData["artist"]["ArtistID"] == 197]

# %% [markdown]
# # Artist Lookup

# %%
colnames["l_artist_url"]={0: "ArtistURLLID", 1: "URLGroupID", 2: "ArtistID", 3: "URLID"}
colnames["l_artist_release_group"]={0: "ArtistReleaseGroupLID", 1: "ReleaseGroupGroupID", 2: "ArtistID", 3: "ReleaseGroupID"}
colnames["l_artist_release"]={0: "ArtistReleaseLID", 1: "ReleaseGroupID", 2: "ArtistID", 3: "ReleaseID"}

ts = timestat("Loading Artist Data")
files = glob("mbdump/l_artist_*")
lookupData = {fileInfo(ifile).basename: loadData(ifile) for ifile in files}
lookupData = {key: val[list(colnames[key].keys())].rename(columns=colnames[key]) for key,val in lookupData.items() if key in colnames} if lookupData is not None else lookupData
print("Keys: {0}".format(lookupData.keys()))
ts.stop()

# %%
files = glob("mbdump/l_artist_release")
lookupData = {fileInfo(ifile).basename: loadData(ifile) for ifile in files}

# %%
lookupData['l_artist_release']["ReleaseGroupID"].nunique()

# %%
lookupData['l_artist_release'][lookupData['l_artist_release']['ArtistID'] == 502]

# %%
key='l_artist_url'
lookupData['l_artist_url'] = lookupData['l_artist_url'][list(colnames[key].keys())].rename(columns=colnames[key])

# %%
print(urlData['url'][urlData['url']["URLName"].eq("https://www.discogs.com/artist/6520")])
print(urlData['url'][urlData['url']["URLName"].eq("https://www.allmusic.com/artist/mn0000219203")])

# %%
lookupData["l_artist_url"][lookupData["l_artist_url"]["URLID"].isin([3017,993955])]

# %%
from pandas import merge
dmbAU = lookupData["l_artist_url"][lookupData["l_artist_url"]['ArtistID'] == 502].copy(deep=True)
u2AU  = lookupData["l_artist_url"][lookupData["l_artist_url"]['ArtistID'] == 197].copy(deep=True)

# %%
dmbURLs = merge(dmbAU, urlData['url'], how='left', on=["URLID"]).copy(deep=True)
u2URLs  = merge(u2AU, urlData['url'], how='left', on=["URLID"]).copy(deep=True)

# %%
dmbURLs["URLDomain"] = dmbURLs["URLName"].apply(lambda x: x.replace("https://", "").replace("http://", "").split('/')[0])

# %%
u2URLs["URLDomain"] = u2URLs["URLName"].apply(lambda x: x.replace("https://", "").replace("http://", "").split('/')[0])

# %%
u2URLs[["NA1", "URLDomain"]].sort_values(by="NA1").T

# %%
dmbURLs[["NA1", "URLDomain"]].sort_values(by="NA1").T

# %%
artistData["artist"][artistData["artist"].eq(8723).any(1)]

# %%
urlData['url'].shape

# %%
lookupData["l_artist_url"][lookupData["l_artist_url"].eq(1025971).any(1)]

# %%
lookupData["l_artist_url"][lookupData["l_artist_url"].eq(2625).any(1)]

# %%
lookupData["l_artist_url"][lookupData["l_artist_url"][2].eq(502).any(1)]

# %%
DMB={AllMusic = 1025971 (c94225e3-2f0c-4c6d-9115-9f268fb7c31b), Discogs = 2625 (7a157b6e-d01d-4248-9995-edb05652c5b2)}

# %%
artistData['artist']

# %%
colnames = {0: "ArtistID", 1: "NA1", 2: "NA2": 3: "NA3"}
lookupData["l_artist_artist"][lookupData["l_artist_artist"].eq(502).any(1)]

# %%
urlData['url'][urlData['url']["URLName"].eq("https://www.discogs.com/artist/6520")]
urlData['url'][urlData['url']["URLName"].eq("https://www.allmusic.com/artist/mn0000219203")]

# %%
502
07e748f1-075e-428d-85dc-ce3be434e906
