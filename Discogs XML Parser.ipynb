# %%
## Basic stuff
# %load_ext autoreload
# %autoreload

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
#IPython.Cell.options_default.cm_config.lineNumbers = true;
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>

# %%
from fileIO import fileIO
from fileInfo import fileInfo
from pandas import read_csv, DataFrame, Series, concat, to_datetime, isna, Timestamp


from timeUtils import timestat
from webUtils import getHTML
from fsUtils import setFile, setDir, mkDir

from timeUtils import timestat
from xml.etree import ElementTree
from glob import glob

io = fileIO()

Nmod = 100
#basedir = "."
basedir = "/Volumes/Seagate/DB"
#savedir = "DiscogsArtistAlbumData"
# Out:
# /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
def roundTo(increment, value):
    return int(round(value / float(increment)) * increment)


def getElement(element,nC):
    if element is None or nC > 5:
        return None
    if element.text is not None:
        items  = element.items()
        return element.text if len(items) == 0 else [element.text, items]
    else:
        lElements = list(element)
        if len(lElements) > 0:
            retval = []
            for el in lElements:
                key  = el.tag
                val  = getElement(el,nC+1)
                if val is not None:
                    retval.append({key: val})
            return retval
            return [{el.tag: getElement(el,nC+1)} for el in lElements]
        else:
            items  = element.items()
            return items if len(items) > 0 else None

# %%
def getTree(ifile):
    tsFile  = timestat("Getting/Parsing XML Data For {0}".format(ifile))
    tree    = ElementTree.parse(ifile)
    root    = tree.getroot()
    tsFile.stop()
    return tree,root


def getTreeData(tree, key, keepKeys=None, N=None):
    treeData = {}
    elements = tree.findall(key)
    elements = elements[:N] if N is not None else elements
    N        = len(elements)
    modval   = roundTo(10000,N/5)
    
    tsParse  = timestat("Parsing {0} Elements".format(N))
    for i,element in enumerate(elements):
        _ = tsParse.update(n=i, N=N) if (modval > 0 and i % modval == 0 and i > 0) else None
        elementID,elementData = getElementData(element, keepKeys)
        treeData[elementID] = Series(elementData)
    tsParse.stop()
    return treeData


def getElementData(element, keepKeys):
    lelement    = list(element)
    subElements = [el for el in lelement if el.tag in keepKeys] if keepKeys is not None else lelement
    elementData = {el.tag: getElement(el,0) for el in subElements}
    elementID   = element.get("id")
    elementID   = elementData.get("id") if elementID is None else elementID
    elementID   = elementID if isinstance(elementID,str) else None
    return elementID,elementData


def getTreeDataFrame(treeData):
    ts = timestat("Creating DataFrame For {0} Elements".format(len(treeData)))
    df = DataFrame(treeData).T
    ts.update()
    return df

# %%
from numpy import isnan


def checkTypeAndLength(x, typeval, length=None):
    if x is None:
        return False
    if isinstance(x, float) and isnan(x):
        return False
    if length is not None:
        if isinstance(x, typeval) and len(x) == length:
            return True
    else:
        if isinstance(x, typeval):
            return True
        
    #print("Not sure how to process --> {0}. Expected {1}".format(x, typeval))
    return False


def fixListOfDict(x, key):
    masterListData = []
    if checkTypeAndLength(x, list):
        for dictval in x:
            if checkTypeAndLength(dictval, dict):
                masterListData.append(dictval[key])
    return masterListData


def fixGenresList(x):
    return fixListOfDict(x, 'genre')

def fixStylesList(x):
    return fixListOfDict(x, 'style')

def fixVariationsList(x):
    return fixListOfDict(x, 'name')

def fixArtistsList(x):
    if not checkTypeAndLength(x,list):
        return None
    
    masterArtistData = []
    for artistDict in x:
        if checkTypeAndLength(artistDict, dict):
            artistData = {key: val for item in artistDict['artist'] for key, val in item.items()}
            masterArtistData.append(artistData)
    return masterArtistData


def fixGroupItem(item):
    if checkTypeAndLength(item,list,2):
        if checkTypeAndLength(item[0],str) and checkTypeAndLength(item[1],list,1):
            if item[1][0][0] == 'id':
                return {item[1][0][1]: item[0]}
            else:
                print("Unsure how to parse alias data: {0}".format(item))
    return None


def fixGroupsList(x):
    if not checkTypeAndLength(x,list):
        return None

    masterGroupData = []
    for groupData in x:
        if checkTypeAndLength(groupData,dict,1):
            if groupData.get('name') is not None:
                groupItem = fixGroupItem(groupData['name'])
                masterGroupData.append(groupItem) if groupItem is not None else None
    return masterGroupData


def fixMembersList(x):
    if not checkTypeAndLength(x,list):
        return None

    masterMemberData = []
    for memberData in x:
        if checkTypeAndLength(memberData,dict):
            if memberData.get('name') is not None:
                memberItem = fixGroupItem(memberData['name'])
                masterMemberData.append(memberItem) if memberItem is not None else None
    return masterMemberData


def fixReleaseDate(x):
    if isinstance(x,float) and isnan(x):
        return None
    if x is None:
        return None
    if isinstance(x,str):
        retval = None
        x = x.strip()
        
        #### Just Year
        if x.isdigit() is True: 
            retval = to_datetime(x, format='%Y', errors='ignore')
            return retval
            
            
        splitX = x.split("-")
        #### Just Year/Month
        if len(splitX) == 2:
            retval = to_datetime(x, format='%Y-%m', errors='ignore')
            return retval
        
        #### Just Year/Month/Day
        if len(splitX) == 3:
            if splitX[1].isdigit() and splitX[2].isdigit():
                if int(splitX[1]) == 0:
                    retval = to_datetime(splitX[0], format='%Y', errors='ignore')
                    return retval
                elif int(splitX[2]) == 0:
                    retval = to_datetime("-".join(splitX[:2]), format='%Y-%m', errors='ignore')
                    return retval
                else:
                    retval = to_datetime(x, format='%Y-%m-%d', errors='ignore')
                    return retval

        if x == "?":
            return None
        print("Unknown Format: {0}".format(x))
              
    print("Unknown Type: [{0}] / [{1}]".format(x,type(x)))
    return x



def fixMasterArtists(x):
    if checkTypeAndLength(x, list):
        artists = [artistData['id'] for artistData in x]
        return artists
    return x

def fixMasterGenre(x):
    return x["MasterGenres"] if isna(x["MasterID"]) else None

def fixMasterStyle(x):
    return x["MasterStyles"] if isna(x["MasterID"]) else None


def fixFormat(x):
    if not checkTypeAndLength(x, list):
        return None
    
    for fmatData in x:
        if checkTypeAndLength(fmatData,dict,1):
            if checkTypeAndLength(fmatData.get('format'),list):
                    for fmatDescr in fmatData['format']:
                        if checkTypeAndLength(fmatDescr,dict):
                            if checkTypeAndLength(fmatDescr.get('descriptions'),list):
                                return fixListOfDict(fmatDescr['descriptions'], 'description')
                        elif checkTypeAndLength(fmatDescr,tuple):
                            if len(fmatDescr) == 2:
                                if fmatDescr[0] == "name":
                                    return [fmatDescr[1]]
                                
    print("Could not parse format: {0}".format(x))
    return x
                        

def mergeListOfDicts(x):
    retval = {}
    if checkTypeAndLength(x,list):
        for item in x:
            if checkTypeAndLength(item,dict):
                retval.update(item)
    return retval

def fixTrackList(x):
    if not checkTypeAndLength(x, list):
        return None
    
    trackArtists = {}
    
    tracks = []
    for trackData in x:
        trackInfo = {}
        if checkTypeAndLength(trackData,dict,1):
            if checkTypeAndLength(trackData.get('track'),list):
                trackValue = mergeListOfDicts(trackData['track'])
                if trackValue.get('extraartists') is not None:
                    trackValue['extraartists'] = fixArtistsList(trackValue['extraartists'])
                    for artist in trackValue['extraartists']:
                        trackArtists[artist['id']] = True
                tracks.append(trackValue)

    trackArtists = list(trackArtists.keys())
    return {"Artists": trackArtists, "Tracks": tracks}


def fixMasterID(x):
    if x is None:
        return
    if checkTypeAndLength(x, list, 2):
        return [x[0],x[1][0][1] == 'true']
    return None

# %%
def fixDataFrame(df):
    ts = timestat("Fixing Artists/Genres/Styles Data For {0} Elements".format(df.shape[0]))
    coldrops = []
    if "artists" in df.columns:
        df["MasterArtists"] = df["artists"].apply(fixArtistsList)
        coldrops.append("artists")
        #ts.update()
    if "genres" in df.columns:
        df["MasterGenres"] = df["genres"].apply(fixGenresList)
        coldrops.append("genres")
        #ts.update()
    if "styles" in df.columns:
        df["MasterStyles"] = df["styles"].apply(fixStylesList)
        coldrops.append("styles")
        #ts.update()
    if "aliases" in df.columns:
        df["MasterAliases"] = df["aliases"].apply(fixGroupsList)
        coldrops.append("aliases")   
        #ts.update()
    if "groups" in df.columns:
        df["MasterGroups"] = df["groups"].apply(fixGroupsList)
        coldrops.append("groups")   
        #ts.update()
    if "members" in df.columns:
        df["MasterMembers"] = df["members"].apply(fixMembersList)
        coldrops.append("members")   
        #ts.update()
    if "namevariations" in df.columns:
        df["MasterNameVariations"] = df["namevariations"].apply(fixVariationsList)
        coldrops.append("namevariations")
        #ts.update()
    if "released" in df.columns:
        df["MasterReleaseDate"] = df["released"].apply(fixReleaseDate)
        coldrops.append("released")   
        #ts.update()
    if "master_id" in df.columns:
        mIDData = df["master_id"].apply(lambda x: x[0] if isinstance(x,list) else None)
        mIDData.name = "MasterID"
        #ts.update()
        isMData = df["master_id"].apply(lambda x: x[1][0][1] == 'true' if isinstance(x,list) else None)
        isMData.name = "IsMaster"
        df = df.join(mIDData).join(isMData)
        coldrops.append("master_id")
        #ts.update()
    if "id" in df.columns:
        coldrops.append("id")
    ts.stop()
    
    if len(coldrops) > 0:
        df.drop(coldrops, axis=1, inplace=True)
    return df



def saveModData(df):
    io = fileIO()
    Nmod = 10
    releaseMap = {x: [] for x in range(Nmod)}
    ts = timestat("Saving Mod Data")
    for releaseID,releaseData in df.iterrows():
        artistIDs = [artistData['id'] for artistData in releaseData["MasterArtists"]] if isinstance(releaseData["MasterArtists"],list) else []
        for artistID in artistIDs:
            releaseMap[int(artistID)%Nmod].append(releaseID)

    ts.update()
    for modVal,modValData in releaseMap.items():
        savename  = "{0}-ArtistMod{1}.p".format(ifile.split("-")[0], modVal)
        dfModData = df.loc[modValData]
        if fileInfo(savename).exists is True:
            previousData = io.get(savename)
            print("Found Previous {0} Releases".format(previousData.shape[0]))
            dfModData = concat([dfModData, previousData])
            dfModData = dfModData[~dfModData.index.duplicated()]
            print("Saving {0} Releases To {1}".format(dfModData.shape[0], savename))
            io.save(idata=dfModData, ifile=savename)
        elif fileInfo(savename).exists is False:
            print("Saving {0} Releases To {1}".format(dfModData.shape[0], savename))
            io.save(idata=dfModData, ifile=savename)
        ts.update()
    ts.stop()

# %%
def splitList(ilist, N):
    retval = {k: [] for k in range(N)}
    for i,lval in enumerate(ilist):
        retval[i%N].append(lval)
    return retval

# %% [markdown]
# # Artists

# %% [markdown]
# ## Split Code

# %%
discKey = "Artists"

# %%
# !xml_split -s 200MB /Volumes/Seagate/DB/discogs_20211001_artists.xml
#  xml_split -s 1000MB discogs_20211001_artists.xml

# %% [markdown]
# ## Parse Code

# %%
files      = [x for x in glob("/Volumes/Seagate/DB/discogs_20211001_{0}-*.xml".format(discKey.lower())) if fileInfo(x).basefilename.endswith("00") is False]
print("Found {0} Files".format(len(files)))
#splitFiles = splitList(files, N=3)

# %%
#keys = ["groups", "members", "namevariations", "aliases"]
#keys = ["profile", "urls"]
keepKeys    = ["id", "name", "realname"] + ["groups", "members", "namevariations", "aliases"]

# %%
ts          = timestat("Parsing {0} Data".format(discKey))
sfiles      = files
N           = len(sfiles)
for i,ifile in enumerate(sfiles):
    savename = ifile.replace(".xml", ".p")
    if fileInfo(savename).exists is True:
        continue

    tree,root = getTree(ifile)
    treeData  = getTreeData(tree, key='artist', keepKeys=keepKeys)
    
    df = getTreeDataFrame(treeData)
    df = fixDataFrame(df)
    io.save(idata=df, ifile=savename)
    
    del df
    del treeData
    del tree
    del root
    
    ts.update(n=i+1,N=N)
    print("\n\n")
ts.stop()

# Process [Parsing Artists Data] Took 69.9 Minutes

# %% [markdown]
# ## Merge Code

# %%
files      = [x for x in glob("/Volumes/Seagate/DB/discogs_20211001_{0}-*.p".format(discKey.lower())) if fileInfo(x).basefilename.endswith("00") is False]
print("Found {0} Files".format(len(files)))

ts = timestat("Loading {0} DataFrames".format(len(files)))
pdata = [io.get(ifile) for ifile in files]
ts.update()
pdf = concat(pdata)
ts.update()
io.save(idata=pdf, ifile="/Volumes/Seagate/DB/discogs_20211001_{0}.p".format(discKey.lower()))
ts.stop()
# Process [Loading 10 DataFrames] Took 1.8 Minutes

# %% [markdown]
# # Master

# %%
discKey = "masters"

# %% [markdown]
# ## Split Code

# %%
# !xml_split -s 250MB /Volumes/Seagate/DB/discogs_20211001_masters.xml
#  xml_split -s 1000MB discogs_20211001_releases.xml

# %% [markdown]
# ## Parse Code

# %%
files      = [x for x in glob("/Volumes/Seagate/DB/discogs_20211001_{0}-*.xml".format(discKey.lower())) if fileInfo(x).basefilename.endswith("00") is False]
print("Found {0} Files".format(len(files)))
#splitFiles = splitList(files, N=3)

# %%
ts          = timestat("Parsing {0} Data".format(discKey))
#sfiles      = splitFiles[0]
sfiles      = files
N           = len(sfiles)
keepKeys    = ["main_release", "artists", "year", "title", 'styles', 'genres']


for i,ifile in enumerate(sfiles):
    savename = ifile.replace(".xml", ".p")
    if fileInfo(savename).exists is True:
        continue

    tree,root = getTree(ifile)
    treeData  = getTreeData(tree, key='master', keepKeys=keepKeys)
    
    df = getTreeDataFrame(treeData)
    df = fixDataFrame(df)
    io.save(idata=df, ifile=savename)
    
    del df
    del treeData
    del tree
    del root
    
    ts.update(n=i+1,N=N)
    print("\n\n")
ts.stop()

# Process [Parsing masters Data] Took 18.2 Minutes

# %% [markdown]
# ## Merge Code

# %%
files      = [x for x in glob("/Volumes/Seagate/DB/discogs_20211001_{0}-*.p".format(discKey.lower())) if fileInfo(x).basefilename.endswith("00") is False]
print("Found {0} Files".format(len(files)))

ts = timestat("Loading {0} DataFrames".format(len(files)))
pdata = [io.get(ifile) for ifile in files]
ts.update()
pdf = concat(pdata)
ts.update()
io.save(idata=pdf, ifile="/Volumes/Seagate/DB/discogs_20211001_{0}.p".format(discKey.lower()))
ts.stop()
# Process [Loading 10 DataFrames] Took 1.8 Minutes

# %%
masterData = io.get("/Volumes/Seagate/DB/discogs_20211001_masters.p")

# %%
masterData.loc['45284']

# %% [markdown]
# # Release

# %%
discKey = "Releases"

# %% [markdown]
# ## Split Code

# %%
# !xml_split -s 3GB /Volumes/Seagate/DB/discogs_20211001_releases.xml
#  xml_split -s 1000MB discogs_20211001_releases.xml

# %% [markdown]
# ## Parse Code

# %%
files      = [x for x in glob("/Volumes/Seagate/DB/discogs_20211001_releases-*.xml") if fileInfo(x).basefilename.endswith("00") is False]
releaseFiles = {fileInfo(ifile).basefilename.split("-")[1]: ifile for ifile in files[1:]}
print("Found {0} Files".format(len(releaseFiles)))

# %%
tsAll       = timestat("Parsing {0} Data".format(discKey))
N           = len(releaseFiles)
keepKeys    = ["artists", "title", "genres", "styles", "country", "released", "master_id", 'formats', 'tracklist', 'extraartists']

for i,ifile in releaseFiles.items():
    ts = timestat("Getting Data From {0}".format(ifile))
    tree,root = getTree(ifile)
    treeData  = getTreeData(tree, key='release', keepKeys=keepKeys)
    ts.update()
    
    extraData = {releaseID: {"Genres": fixGenresList(releaseData.get('genres')),
                             "Styles": fixStylesList(releaseData.get("styles")),
                             "Country": releaseData.get('country'),
                             "Master": fixMasterID(releaseData.get("master_id"))} for releaseID,releaseData in treeData.items()}
    trackData = {releaseID: fixTrackList(releaseData['tracklist']) for releaseID,releaseData in treeData.items()}
    artistData = {releaseID: {"Artists": fixArtistsList(releaseData.get('artists')),
                              "ExtraArtists": fixArtistsList(releaseData.get('extraartists'))} for releaseID,releaseData in treeData.items()}
    generalData = {releaseID: {"Title": releaseData.get('title'),
                               "Format": fixFormat(releaseData.get('formats')),
                               "Released": fixReleaseDate(releaseData.get('released'))} for releaseID,releaseData in treeData.items()}
    
    extraData   = Series(extraData)
    trackData   = Series(trackData)
    artistData  = Series(artistData)
    generalData = Series(generalData)
    ts.update()
    
    savedir = setDir(basedir, "DiscogsReleaseData")
    io.save(idata=extraData, ifile=setFile(savedir, "{0}-{1}.p".format("ExtraReleaseData", i)))
    io.save(idata=trackData, ifile=setFile(savedir, "{0}-{1}.p".format("TrackReleaseData", i)))
    io.save(idata=artistData, ifile=setFile(savedir, "{0}-{1}.p".format("ArtistReleaseData", i)))
    io.save(idata=generalData, ifile=setFile(savedir, "{0}-{1}.p".format("GeneralReleaseData", i)))

    del extraData
    del trackData
    del generalData
    del treeData
    del tree
    del root
    
    ts.stop()
    tsAll.update(n=i,N=N)
tsAll.stop()

# %% [markdown]
# ## Create Slimmed Release Data

# %%
sFiles = splitList([x for x in glob("/Volumes/Seagate/DB/discogs_20211001_releases-*.p") if fileInfo(x).basefilename.endswith("00") is False], 10)

tsMods = timestat("Creating ReleaseModData")
for modVal,files in sFiles.items():
    tsAll = timestat("Creating ReleaseData For ModVal={0}".format(modVal))
    releaseData = None
    for i,ifile in enumerate(files):
        ts = timestat("Fixing {0}".format(ifile))
        xData = io.get(ifile)
        ts.update()
        xData = fixDataFrame(xData)
        xData["MasterArtists"] = xData["MasterArtists"].apply(fixMasterArtists)
        xData["MasterGenres"]  = xData.apply(fixMasterGenre, axis=1)
        xData["MasterStyles"]  = xData.apply(fixMasterStyle, axis=1)
        xData.drop(['IsMaster'], axis=1, inplace=True)
        releaseData = xData if releaseData is None else concat([releaseData,xData])
        ts.stop()
        print(i,'\t',len(files),'\t',releaseData.shape,'\n')
        
    tsAll.stop()
    
    io.save(idata=releaseData, ifile="/Volumes/Seagate/DB/DiscogsArtistAlbumData/ReleaseData-{0}.p".format(modVal))
    tsMods.update()
    print("\n",'='*150,'\n')
tsMods.stop()

# %% [markdown]
# # Create Artist-Keyed Mod Data

# %% [markdown]
# ## Artist Mod Data

# %%
tsFile = timestat("Loading Artist Data")
ifile = setFile(basedir, "discogs_20211001_artists.p")
artistsData = io.get(ifile)
savedir = setDir(basedir, "DiscogsMetadata")
sIndex = Series(artistsData.index)
tsFile.stop()

ts = timestat("Creating Artist Data")
for modVal in range(Nmod):
    modDir = mkDir(setDir(savedir, str(modVal)))
    savename  = setFile(modDir, "{0}-{1}.p".format("Artist", modVal))
    if fileInfo(savename).exists:
        continue
        
    idxVals = sIndex[sIndex.apply(lambda x: int(x)%Nmod == modVal)]
    modValData = artistsData[artistsData.index.isin(idxVals)]
    
    if fileInfo(savename).exists is True:
        previousData = io.get(savename)
        dfModData = concat([modValData, previousData])
        io.save(idata=modValData, ifile=savename)
    elif fileInfo(savename).exists is False:
        io.save(idata=modValData, ifile=savename)
    if (modVal+1) % 10 == 0 or (modVal+1) == 5:
        ts.update(n=modVal+1,N=Nmod)
ts.stop()

#Current Time is Thu Oct 21, 2021 09:24 for Loading Artist Data
#  Process [Loading Artist Data] Took 1.1 Minutes
#Current Time is Thu Oct 21, 2021 09:25 for Creating Artist Data
#  50/100     : Process [Creating Artist Data] Has Run For 3.9 Minutes
# 100/100     : Process [Creating Artist Data] Has Run For 7.9 Minutes
#  Process [Creating Artist Data] Took 7.9 Minutes

# %% [markdown]
# ## Master Mod Data

# %%
tsAll = timestat("Creating Master Mod Data")
tsFile = timestat("Loading Master Data")
ifile = setFile(basedir, "discogs_20211001_masters.p")
mastersData = io.get(ifile)
mastersData["ArtistIDs"] = mastersData["MasterArtists"].apply(fixMasterArtists)
savedir = setDir(basedir, "DiscogsMetadata")
tsFile.stop()


artistModData      = {x: {} for x in range(Nmod)}
artistModGenreData = {x: {} for x in range(Nmod)}
from collections import Counter
N = mastersData.shape[0]
ts = timestat("Getting Artist/Master Mod Data")
for i,(idx,row) in enumerate(mastersData.iterrows()):
    if (i+1) % 250000 == 0 or (i+1) == 100000:
        ts.update(n=i+1, N=N)
    for artistID in row["ArtistIDs"]:
        modVal = int(artistID) % Nmod
        if artistModData[modVal].get(artistID) is None:
            artistModData[modVal][artistID] = {}
        artistModData[modVal][artistID][idx] = {"Artists": row["ArtistIDs"], "Album": row["title"],
                                                "Year": row["year"], "MainRelease": row["main_release"]}
        if artistModGenreData[modVal].get(artistID) is None:
            artistModGenreData[modVal][artistID] = {"Genres": Counter(), "Styles": Counter()}
        for genre in row["MasterGenres"]:
            artistModGenreData[modVal][artistID]["Genres"][genre] += 1
        for style in row["MasterStyles"]:
            artistModGenreData[modVal][artistID]["Styles"][style] += 1
ts.stop()            
            
            
artistModData = {modVal: Series(modData) for modVal,modData in artistModData.items()}
artistModGenreData = {modVal: Series({artistID: {"Genres": [item[0] for item in artistData["Genres"].most_common(3)],
                                                 "Styles": [item[0] for item in artistData["Styles"].most_common(3)]} for artistID,artistData in modValData.items()}) for modVal,modValData in artistModGenreData.items()}            
            
ts = timestat("Saving Artist Master Mod Data")
for modVal,modValData in artistModData.items():
    modDir = mkDir(setDir(savedir, str(modVal)))
    savename  = setFile(modDir, "{0}-{1}.p".format("MasterAlbum", modVal))
    if fileInfo(savename).exists is True:
        previousData = io.get(savename)
        dfModData = concat([modValData, previousData])
        io.save(idata=modValData, ifile=savename)
    elif fileInfo(savename).exists is False:
        io.save(idata=modValData, ifile=savename)
    if (modVal+1) % 10 == 0 or (modVal+1) == 5:
        ts.update(n=modVal+1,N=Nmod)
ts.stop()

ts = timestat("Saving Artist Master Genre Mod Data")
for modVal,modValData in artistModGenreData.items():
    modDir = mkDir(setDir(savedir, str(modVal)))
    savename  = setFile(modDir, "{0}-{1}.p".format("MasterGenre", modVal))
    if fileInfo(savename).exists is True:
        previousData = io.get(savename)
        dfModData = concat([modValData, previousData])
        io.save(idata=modValData, ifile=savename)
    elif fileInfo(savename).exists is False:
        io.save(idata=modValData, ifile=savename)
    if (modVal+1) % 10 == 0 or (modVal+1) == 5:
        ts.update(n=modVal+1,N=Nmod)
ts.stop()
tsAll.stop()

# Current Time is Thu Oct 21, 2021 09:36 for Loading Master Data
#   Process [Loading Master Data] Took 25.4 Seconds
# Current Time is Thu Oct 21, 2021 09:36 for Getting Artist/Master Mod Data
#   Process [Getting Artist/Master Mod Data] Took 6.1 Minutes
# Current Time is Thu Oct 21, 2021 09:36 for Getting Artist/Master Mod Data
#   Process [Saving Artist Master Mod Data] Took 40.9 Seconds
# Current Time is Thu Oct 21, 2021 09:43 for Saving Artist Master Genre Mod Data
#   Process [Saving Artist Master Genre Mod Data] Took 3.8 Seconds
#   Process [Creating Master Mod Data] Took 7.4 Minutes

# %% [markdown]
# ## Release Mod Data

# %% [markdown]
# ### Create Master ReleaseID <-> ArtistID Map

# %%
masterReleaseArtistModMap = {}
ts = timestat("Creating Master Release ArtistID Map")
artistReleaseFiles = glob(setFile(setDir(basedir, "DiscogsReleaseData"), "ArtistReleaseData-*.p"))
for i,ifile in enumerate(artistReleaseFiles):
    releaseArtistData = io.get(ifile)
    for releaseID,releaseData in releaseArtistData.iteritems():
        ## Ignoring Extra Artists For Now
        artistIDs = fixMasterArtists(releaseData["Artists"])
        masterReleaseArtistModMap[releaseID] = {int(artistID)%Nmod: artistID for artistID in artistIDs} if isinstance(artistIDs,list) else {}
    if (i+1) % 10 == 0 or (i+1) == 5:
        ts.update(n=i+1,N=len(artistReleaseFiles))
ts.update()
io.save(idata=masterReleaseArtistModMap, ifile=setFile(setDir(basedir, "DiscogsReleaseData"), "ArtistReleaseMap.p"))
del masterReleaseArtistModMap
ts.stop()

# %%
useTracks = False
useExtras = True

# %%
tsAll = timestat("Creating Release Mod Data")

tsMap = timestat("Loading Release ID <-> ArtistID Map Map")
masterReleaseArtistModMap = io.get(ifile=setFile(setDir(basedir, "DiscogsReleaseData"), "ArtistReleaseMap.p"))
tsMap.stop()
fCheck = []
artistReleaseFiles  = glob(setFile(setDir(basedir, "DiscogsReleaseData"), "ArtistReleaseData-*.p"))
artistReleaseFiles  = {fileInfo(ifile).basefilename.split("-")[1]: ifile for ifile in artistReleaseFiles}
fCheck.append(artistReleaseFiles)
print("Found {0} Artist Release Files".format(len(artistReleaseFiles)))
generalReleaseFiles = glob(setFile(setDir(basedir, "DiscogsReleaseData"), "GeneralReleaseData-*.p"))
generalReleaseFiles = {fileInfo(ifile).basefilename.split("-")[1]: ifile for ifile in generalReleaseFiles}
fCheck.append(generalReleaseFiles)
print("Found {0} General Release Files".format(len(generalReleaseFiles)))
extraReleaseFiles   = glob(setFile(setDir(basedir, "DiscogsReleaseData"), "ExtraReleaseData-*.p")) if useExtras else []
extraReleaseFiles   = {fileInfo(ifile).basefilename.split("-")[1]: ifile for ifile in extraReleaseFiles}
if useExtras:
    fCheck.append(extraReleaseFiles)
    print("Found {0} Extra Release Files".format(len(generalReleaseFiles)))
trackReleaseFiles   = glob(setFile(setDir(basedir, "DiscogsReleaseData"), "TrackReleaseData-*.p")) if useTracks else []
trackReleaseFiles   = {fileInfo(ifile).basefilename.split("-")[1]: ifile for ifile in trackReleaseFiles}
if useTracks:
    fCheck.append(trackReleaseFiles)
    print("Found {0} Track Release Files".format(len(trackReleaseFiles)))


if len(set([len(x) for x in fCheck])) == 1:
    Nrelmods = list(generalReleaseFiles.keys())
else:
    raise ValueError("Didn't find an equal number of files")
    
#Current Time is Sat Oct 23, 2021 12:20 for Loading Release ID <-> ArtistID Map Map
#  Process [Loading Release ID <-> ArtistID Map Map] Took 3.1 Minutes

# %%
def saveArtistModData(artistModData, savedir):
    ts = timestat("Saving Artist Mod Data")
    for modVal,modValData in artistModData.items():
        modDir = mkDir(setDir(savedir, str(modVal)))
        savename  = setFile(modDir, "{0}-{1}.p".format("ReleaseAlbum", modVal))
        if fileInfo(savename).exists is True:
            previousData = io.get(savename)
            dfModData = concat([modValData, previousData])
            io.save(idata=dfModData, ifile=savename)
            del dfModData
        elif fileInfo(savename).exists is False:
            io.save(idata=modValData, ifile=savename)
        if (modVal+1) % 25 == 0:
            ts.update(n=modVal+1,N=Nmod)
    ts.stop()

# %%
savedir = setDir(basedir, "DiscogsMetadata")
tsTotal = timestat("Getting Artist/Release Mod Data")
artistModData = {x: {} for x in range(Nmod)}
for n,relmodVal in enumerate(Nrelmods):
    artistRelModData  = io.get(artistReleaseFiles[relmodVal])
    generalRelModData = io.get(generalReleaseFiles[relmodVal])
    extraRelModData   = io.get(extraReleaseFiles[relmodVal]) if useExtras else None
    trackRelModData   = io.get(trackReleaseFiles[relmodVal]) if useTracks else None

    
    N = generalRelModData.shape[0]
    ts = timestat("Splitting {0} Release Data For RelMod={1}".format(N,relmodVal))
    for i,(idx,row) in enumerate(generalRelModData.iteritems()):
        rowData = {"Album": row["Title"], "Format": row["Format"], "Year": row["Released"].year if isinstance(row["Released"], Timestamp) else None}
        rowData.update({"Artists": artistRelModData.get(idx)['Artists'], "ExtraArtists": artistRelModData.get(idx)['ExtraArtists']})
        if useExtras:
            rowData.update(extraRelModData[idx])
        if useTracks:
            rowData.update(trackRelModData[idx])
        
        modVals = masterReleaseArtistModMap.get(idx)
        for modVal,artistID in modVals.items():
            if artistModData[modVal].get(artistID) is None:
                artistModData[modVal][artistID] = {}
            artistModData[modVal][artistID][idx] = rowData

        if (i+1) % 500000 == 0 or (i+1) == 250000:
            ts.update(n=i+1,N=N)
    ts.stop()
    
    if (n+1) % 15 == 0 or (n+1) == len(Nrelmods):
        artistModData = {modVal: Series(modData) for modVal,modData in artistModData.items()}
        saveArtistModData(artistModData, savedir)
        del artistModData
        artistModData = {x: {} for x in range(Nmod)}
    
    tsTotal.update(n=n, N=len(Nrelmods))
#del masterReleaseArtistModMap
tsTotal.stop()
 
# Current Time is Sat Oct 23, 2021 12:23 for Getting Artist/Release Mod Data
#   14/66      : Process [Getting Artist/Release Mod Data] Has Run For 17.3 Minutes
#   29/66      : Process [Getting Artist/Release Mod Data] Has Run For 63.8 Minutes
#   44/66      : Process [Getting Artist/Release Mod Data] Has Run For 122.9 Minutes
#   65/66      : Process [Getting Artist/Release Mod Data] Has Run For 221.3 Minutes
#   Process [Getting Artist/Release Mod Data] Took 221.3 Minutes

# %% [markdown]
# ### Merge Multi Index

# %% [markdown]
# # DB Data

# %%
modVal = 0
artistModData       = io.get(setFile(modDir, "{0}-{1}.p".format("Artist", modVal)))
artistModData

# %%
from artistDBBase import artistDBBase, artistDBDataClass
from artistDBBase import artistDBNameClass, artistDBMetaClass, artistDBIDClass, artistDBURLClass, artistDBPageClass
from artistDBBase import artistDBProfileClass, artistDBMediaClass, artistDBMediaAlbumClass
from artistDBBase import artistDBMediaDataClass, artistDBMediaCountsClass, artistDBFileInfoClass
from artistDBBase import artistDBTextClass, artistDBLinkClass
from strUtils import fixName
from dbUtils import utilsDiscogs

def getMediaCounts(self, media):
    amcc = artistDBMediaCountsClass()

    credittype = "Releases"
    if amcc.counts.get(credittype) == None:
        amcc.counts[credittype] = {}
    for creditsubtype in media.media.keys():
        amcc.counts[credittype][creditsubtype] = int(len(media.media[creditsubtype]))

    return amcc

savedir = setDir(basedir, "DiscogsMetadata")
tsAll = timestat("Creating DB Data")
for modVal in range(Nmod):
    
    tsLoad = timestat("Loading ModValData")
    modDir = setDir(savedir, str(modVal))
    artistModData       = io.get(setFile(modDir, "{0}-{1}.p".format("Artist", modVal)))
    masterAlbumModData  = io.get(setFile(modDir, "{0}-{1}.p".format("MasterAlbum", modVal)))
    masterGenreModData  = io.get(setFile(modDir, "{0}-{1}.p".format("MasterGenre", modVal)))
    releaseAlbumModData = io.get(setFile(modDir, "{0}-{1}.p".format("ReleaseAlbum", modVal)))
    tsLoad.stop()
        

    modValData = {}
    N = artistModData.shape[0]
    tsMod = timestat("Creating DB Data From {0} Artists For ModVal={1}".format(N,modVal))
    for i,(artistID,artistData) in enumerate(artistModData.iterrows()):
        artistName  = artistData["name"]
        url         = "https://www.discogs.com/artist/{0}".format(artistID)

        generalData = {}
        generalData["RealName"]   = artistData["realname"]
        generalData["Aliases"]    = artistData["MasterAliases"]
        generalData["Groups"]     = artistData["MasterGroups"]
        generalData["Members"]    = artistData["MasterMembers"]
        generalData["Variations"] = artistData["MasterNameVariations"]
        generalData = {k: v for k,v in generalData.items() if v is not None}
        generalData = generalData if len(generalData) > 0 else None
        
        masterGenreData = masterGenreModData.get(artistID)
        masterAlbumData = masterAlbumModData.get(artistID)
        releaseAlbumData = releaseAlbumModData.get(artistID)
        
        genresData = masterGenreData.get("Genres") if isinstance(masterGenreData,dict) else None
        tagsData   = masterGenreData.get("Styles") if isinstance(masterGenreData,dict) else None
        
        if isinstance(releaseAlbumData,Series):
            artistReleaseData = {releaseID: releaseIDData for releaseData in releaseArtistAlbumData for releaseID, releaseIDData in releaseData.items()}
        elif isinstance(releaseAlbumData,dict):
            artistReleaseData = releaseAlbumData
        elif releaseAlbumData == None:
            artistReleaseData = {}
        else:
            print("Unsure how to parse [{0}] / [{1}]".format(artistID,releaseAlbumData))
            artistReleaseData = {}
            
                    
        ########################################################################
        # Get Releases
        ########################################################################
        mediaName = "Releases"
        mediaData = {mediaName: []}
        for code,releaseInfo in artistReleaseData.items():
            album        = releaseInfo["Album"]
            albumURL     = "https://www.discogs.com/release/{0}".format(code)
            
            albumArtists = releaseInfo["Artists"] + releaseInfo["ExtraArtists"] if isinstance(releaseInfo["ExtraArtists"],list) else releaseInfo["Artists"]
            albumFormat  = releaseInfo["Format"]
            albumYear    = releaseInfo["Year"]
            amdc = artistDBMediaDataClass(album=album, url=albumURL, artist=albumArtists, code=code, year=albumYear)
            mediaData[mediaName].append(amdc)
            
        credittype = "Releases"
        counts = {credittype: {mediaName: len(mediaData[mediaName])}}

            
            
        artist      = artistDBNameClass(name=artistName, err=None)
        meta        = artistDBMetaClass(title=None, url=url)
        url         = artistDBURLClass(url=url)
        ID          = artistDBIDClass(ID=artistID)
        pages       = artistDBPageClass(ppp=1, tot=1, redo=False, more=False)
        profile     = artistDBProfileClass(general=generalData, genres=genresData, tags=tagsData)
        media       = artistDBMediaClass()
        media.media = mediaData
        mediaCounts = artistDBMediaCountsClass()
        mediaCounts.counts = counts
        info        = artistDBFileInfoClass(info=None)
        
        adc = artistDBDataClass(artist=artist, meta=meta, url=url, ID=ID, pages=pages, profile=profile, mediaCounts=mediaCounts, media=media, info=info)
        modValData[artistID] = adc
        
        if (i+1) % 35000 == 0 or (i+1) == 10000:
            tsMod.update(n=i+1, N=N)
    tsMod.stop()
            
    outdir = setDir(basedir, "DiscogsDBData")
    io.save(idata=modValData, ifile=setFile(outdir, "{0}-{1}.p".format(modVal, "DB")))
    tsAll.update()
    print("\n")
# Out:
# Current Time is Sat Oct 23, 2021 20:41 for Creating DB Data
# Current Time is Sat Oct 23, 2021 20:41 for Loading ModValData
# Process [Loading ModValData] Took 5.1 Seconds
# Current Time is Sat Oct 23, 2021 20:41 for Creating DB Data From 77824 Artists For ModVal=0
# 10000/77824 : Process [Creating DB Data From 77824 Artists For ModVal=0] Has Run For 12.7 Seconds
# 35000/77824 : Process [Creating DB Data From 77824 Artists For ModVal=0] Has Run For 43.8 Seconds
# 70000/77824 : Process [Creating DB Data From 77824 Artists For ModVal=0] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77824 Artists For ModVal=0] Took 1.6 Minutes
# Process [Creating DB Data] Has Run For 2.7 Minutes
#
#
# Current Time is Sat Oct 23, 2021 20:44 for Loading ModValData
# Process [Loading ModValData] Took 7.1 Seconds
# Current Time is Sat Oct 23, 2021 20:44 for Creating DB Data From 77871 Artists For ModVal=1
# 10000/77871 : Process [Creating DB Data From 77871 Artists For ModVal=1] Has Run For 12.3 Seconds
# 35000/77871 : Process [Creating DB Data From 77871 Artists For ModVal=1] Has Run For 42.5 Seconds
# 70000/77871 : Process [Creating DB Data From 77871 Artists For ModVal=1] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77871 Artists For ModVal=1] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 5.4 Minutes
#
#
# Current Time is Sat Oct 23, 2021 20:46 for Loading ModValData
# Process [Loading ModValData] Took 5.5 Seconds
# Current Time is Sat Oct 23, 2021 20:46 for Creating DB Data From 77650 Artists For ModVal=2
# 10000/77650 : Process [Creating DB Data From 77650 Artists For ModVal=2] Has Run For 12.2 Seconds
# 35000/77650 : Process [Creating DB Data From 77650 Artists For ModVal=2] Has Run For 43.6 Seconds
# 70000/77650 : Process [Creating DB Data From 77650 Artists For ModVal=2] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77650 Artists For ModVal=2] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 8.1 Minutes
#
#
# Current Time is Sat Oct 23, 2021 20:49 for Loading ModValData
# Process [Loading ModValData] Took 6.4 Seconds
# Current Time is Sat Oct 23, 2021 20:49 for Creating DB Data From 77766 Artists For ModVal=3
# 10000/77766 : Process [Creating DB Data From 77766 Artists For ModVal=3] Has Run For 11.8 Seconds
# 35000/77766 : Process [Creating DB Data From 77766 Artists For ModVal=3] Has Run For 41.5 Seconds
# 70000/77766 : Process [Creating DB Data From 77766 Artists For ModVal=3] Has Run For 1.3 Minutes
# Process [Creating DB Data From 77766 Artists For ModVal=3] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 10.7 Minutes
#
#
# Current Time is Sat Oct 23, 2021 20:52 for Loading ModValData
# Process [Loading ModValData] Took 4.8 Seconds
# Current Time is Sat Oct 23, 2021 20:52 for Creating DB Data From 77907 Artists For ModVal=4
# 10000/77907 : Process [Creating DB Data From 77907 Artists For ModVal=4] Has Run For 11.7 Seconds
# 35000/77907 : Process [Creating DB Data From 77907 Artists For ModVal=4] Has Run For 43.4 Seconds
# 70000/77907 : Process [Creating DB Data From 77907 Artists For ModVal=4] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77907 Artists For ModVal=4] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 13.4 Minutes
#
#
# Current Time is Sat Oct 23, 2021 20:54 for Loading ModValData
# Process [Loading ModValData] Took 5.9 Seconds
# Current Time is Sat Oct 23, 2021 20:54 for Creating DB Data From 77711 Artists For ModVal=5
# 10000/77711 : Process [Creating DB Data From 77711 Artists For ModVal=5] Has Run For 11.9 Seconds
# 35000/77711 : Process [Creating DB Data From 77711 Artists For ModVal=5] Has Run For 42.7 Seconds
# 70000/77711 : Process [Creating DB Data From 77711 Artists For ModVal=5] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77711 Artists For ModVal=5] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 16.0 Minutes
#
#
# Current Time is Sat Oct 23, 2021 20:57 for Loading ModValData
# Process [Loading ModValData] Took 6.5 Seconds
# Current Time is Sat Oct 23, 2021 20:57 for Creating DB Data From 77877 Artists For ModVal=6
# 10000/77877 : Process [Creating DB Data From 77877 Artists For ModVal=6] Has Run For 12.0 Seconds
# 35000/77877 : Process [Creating DB Data From 77877 Artists For ModVal=6] Has Run For 42.6 Seconds
# 70000/77877 : Process [Creating DB Data From 77877 Artists For ModVal=6] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77877 Artists For ModVal=6] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 18.7 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:00 for Loading ModValData
# Process [Loading ModValData] Took 6.2 Seconds
# Current Time is Sat Oct 23, 2021 21:00 for Creating DB Data From 77760 Artists For ModVal=7
# 10000/77760 : Process [Creating DB Data From 77760 Artists For ModVal=7] Has Run For 11.9 Seconds
# 35000/77760 : Process [Creating DB Data From 77760 Artists For ModVal=7] Has Run For 42.3 Seconds
# 70000/77760 : Process [Creating DB Data From 77760 Artists For ModVal=7] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77760 Artists For ModVal=7] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 21.3 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:02 for Loading ModValData
# Process [Loading ModValData] Took 6.4 Seconds
# Current Time is Sat Oct 23, 2021 21:02 for Creating DB Data From 77883 Artists For ModVal=8
# 10000/77883 : Process [Creating DB Data From 77883 Artists For ModVal=8] Has Run For 11.9 Seconds
# 35000/77883 : Process [Creating DB Data From 77883 Artists For ModVal=8] Has Run For 42.5 Seconds
# 70000/77883 : Process [Creating DB Data From 77883 Artists For ModVal=8] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77883 Artists For ModVal=8] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 24.0 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:05 for Loading ModValData
# Process [Loading ModValData] Took 5.2 Seconds
# Current Time is Sat Oct 23, 2021 21:05 for Creating DB Data From 77742 Artists For ModVal=9
# 10000/77742 : Process [Creating DB Data From 77742 Artists For ModVal=9] Has Run For 11.8 Seconds
# 35000/77742 : Process [Creating DB Data From 77742 Artists For ModVal=9] Has Run For 42.7 Seconds
# 70000/77742 : Process [Creating DB Data From 77742 Artists For ModVal=9] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77742 Artists For ModVal=9] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 26.6 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:07 for Loading ModValData
# Process [Loading ModValData] Took 5.9 Seconds
# Current Time is Sat Oct 23, 2021 21:08 for Creating DB Data From 77799 Artists For ModVal=10
# 10000/77799 : Process [Creating DB Data From 77799 Artists For ModVal=10] Has Run For 13.7 Seconds
# 35000/77799 : Process [Creating DB Data From 77799 Artists For ModVal=10] Has Run For 45.6 Seconds
# 70000/77799 : Process [Creating DB Data From 77799 Artists For ModVal=10] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77799 Artists For ModVal=10] Took 1.6 Minutes
# Process [Creating DB Data] Has Run For 29.3 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:10 for Loading ModValData
# Process [Loading ModValData] Took 6.3 Seconds
# Current Time is Sat Oct 23, 2021 21:10 for Creating DB Data From 77757 Artists For ModVal=11
# 10000/77757 : Process [Creating DB Data From 77757 Artists For ModVal=11] Has Run For 12.4 Seconds
# 35000/77757 : Process [Creating DB Data From 77757 Artists For ModVal=11] Has Run For 42.8 Seconds
# 70000/77757 : Process [Creating DB Data From 77757 Artists For ModVal=11] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77757 Artists For ModVal=11] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 32.0 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:13 for Loading ModValData
# Process [Loading ModValData] Took 6.3 Seconds
# Current Time is Sat Oct 23, 2021 21:13 for Creating DB Data From 77938 Artists For ModVal=12
# 10000/77938 : Process [Creating DB Data From 77938 Artists For ModVal=12] Has Run For 12.7 Seconds
# 35000/77938 : Process [Creating DB Data From 77938 Artists For ModVal=12] Has Run For 44.5 Seconds
# 70000/77938 : Process [Creating DB Data From 77938 Artists For ModVal=12] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77938 Artists For ModVal=12] Took 1.6 Minutes
# Process [Creating DB Data] Has Run For 34.7 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:16 for Loading ModValData
# Process [Loading ModValData] Took 5.4 Seconds
# Current Time is Sat Oct 23, 2021 21:16 for Creating DB Data From 77857 Artists For ModVal=13
# 10000/77857 : Process [Creating DB Data From 77857 Artists For ModVal=13] Has Run For 12.6 Seconds
# 35000/77857 : Process [Creating DB Data From 77857 Artists For ModVal=13] Has Run For 43.8 Seconds
# 70000/77857 : Process [Creating DB Data From 77857 Artists For ModVal=13] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77857 Artists For ModVal=13] Took 1.6 Minutes
# Process [Creating DB Data] Has Run For 37.4 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:18 for Loading ModValData
# Process [Loading ModValData] Took 6.5 Seconds
# Current Time is Sat Oct 23, 2021 21:18 for Creating DB Data From 77760 Artists For ModVal=14
# 10000/77760 : Process [Creating DB Data From 77760 Artists For ModVal=14] Has Run For 12.5 Seconds
# 35000/77760 : Process [Creating DB Data From 77760 Artists For ModVal=14] Has Run For 42.7 Seconds
# 70000/77760 : Process [Creating DB Data From 77760 Artists For ModVal=14] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77760 Artists For ModVal=14] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 40.1 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:21 for Loading ModValData
# Process [Loading ModValData] Took 6.6 Seconds
# Current Time is Sat Oct 23, 2021 21:21 for Creating DB Data From 77851 Artists For ModVal=15
# 10000/77851 : Process [Creating DB Data From 77851 Artists For ModVal=15] Has Run For 11.9 Seconds
# 35000/77851 : Process [Creating DB Data From 77851 Artists For ModVal=15] Has Run For 42.2 Seconds
# 70000/77851 : Process [Creating DB Data From 77851 Artists For ModVal=15] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77851 Artists For ModVal=15] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 42.8 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:24 for Loading ModValData
# Process [Loading ModValData] Took 5.5 Seconds
# Current Time is Sat Oct 23, 2021 21:24 for Creating DB Data From 77749 Artists For ModVal=16
# 10000/77749 : Process [Creating DB Data From 77749 Artists For ModVal=16] Has Run For 12.0 Seconds
# 35000/77749 : Process [Creating DB Data From 77749 Artists For ModVal=16] Has Run For 42.8 Seconds
# 70000/77749 : Process [Creating DB Data From 77749 Artists For ModVal=16] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77749 Artists For ModVal=16] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 45.4 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:26 for Loading ModValData
# Process [Loading ModValData] Took 6.3 Seconds
# Current Time is Sat Oct 23, 2021 21:26 for Creating DB Data From 77781 Artists For ModVal=17
# 10000/77781 : Process [Creating DB Data From 77781 Artists For ModVal=17] Has Run For 12.5 Seconds
# 35000/77781 : Process [Creating DB Data From 77781 Artists For ModVal=17] Has Run For 44.1 Seconds
# 70000/77781 : Process [Creating DB Data From 77781 Artists For ModVal=17] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77781 Artists For ModVal=17] Took 1.6 Minutes
# Process [Creating DB Data] Has Run For 48.1 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:29 for Loading ModValData
# Process [Loading ModValData] Took 5.6 Seconds
# Current Time is Sat Oct 23, 2021 21:29 for Creating DB Data From 77871 Artists For ModVal=18
# 10000/77871 : Process [Creating DB Data From 77871 Artists For ModVal=18] Has Run For 12.4 Seconds
# 35000/77871 : Process [Creating DB Data From 77871 Artists For ModVal=18] Has Run For 43.6 Seconds
# 70000/77871 : Process [Creating DB Data From 77871 Artists For ModVal=18] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77871 Artists For ModVal=18] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 50.8 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:32 for Loading ModValData
# Process [Loading ModValData] Took 5.2 Seconds
# Current Time is Sat Oct 23, 2021 21:32 for Creating DB Data From 77769 Artists For ModVal=19
# 10000/77769 : Process [Creating DB Data From 77769 Artists For ModVal=19] Has Run For 12.5 Seconds
# 35000/77769 : Process [Creating DB Data From 77769 Artists For ModVal=19] Has Run For 43.8 Seconds
# 70000/77769 : Process [Creating DB Data From 77769 Artists For ModVal=19] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77769 Artists For ModVal=19] Took 1.6 Minutes
# Process [Creating DB Data] Has Run For 53.5 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:34 for Loading ModValData
# Process [Loading ModValData] Took 6.8 Seconds
# Current Time is Sat Oct 23, 2021 21:34 for Creating DB Data From 77758 Artists For ModVal=20
# 10000/77758 : Process [Creating DB Data From 77758 Artists For ModVal=20] Has Run For 12.2 Seconds
# 35000/77758 : Process [Creating DB Data From 77758 Artists For ModVal=20] Has Run For 43.0 Seconds
# 70000/77758 : Process [Creating DB Data From 77758 Artists For ModVal=20] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77758 Artists For ModVal=20] Took 1.6 Minutes
# Process [Creating DB Data] Has Run For 56.2 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:37 for Loading ModValData
# Process [Loading ModValData] Took 5.1 Seconds
# Current Time is Sat Oct 23, 2021 21:37 for Creating DB Data From 77827 Artists For ModVal=21
# 10000/77827 : Process [Creating DB Data From 77827 Artists For ModVal=21] Has Run For 12.5 Seconds
# 35000/77827 : Process [Creating DB Data From 77827 Artists For ModVal=21] Has Run For 43.6 Seconds
# 70000/77827 : Process [Creating DB Data From 77827 Artists For ModVal=21] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77827 Artists For ModVal=21] Took 1.6 Minutes
# Process [Creating DB Data] Has Run For 58.9 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:40 for Loading ModValData
# Process [Loading ModValData] Took 6.6 Seconds
# Current Time is Sat Oct 23, 2021 21:40 for Creating DB Data From 77771 Artists For ModVal=22
# 10000/77771 : Process [Creating DB Data From 77771 Artists For ModVal=22] Has Run For 12.2 Seconds
# 35000/77771 : Process [Creating DB Data From 77771 Artists For ModVal=22] Has Run For 43.8 Seconds
# 70000/77771 : Process [Creating DB Data From 77771 Artists For ModVal=22] Has Run For 1.4 Minutes
# Process [Creating DB Data From 77771 Artists For ModVal=22] Took 1.5 Minutes
# Process [Creating DB Data] Has Run For 61.6 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:42 for Loading ModValData
# Process [Loading ModValData] Took 6.2 Seconds
# Current Time is Sat Oct 23, 2021 21:43 for Creating DB Data From 77835 Artists For ModVal=23
# 10000/77835 : Process [Creating DB Data From 77835 Artists For ModVal=23] Has Run For 15.5 Seconds
# 35000/77835 : Process [Creating DB Data From 77835 Artists For ModVal=23] Has Run For 49.6 Seconds
# 70000/77835 : Process [Creating DB Data From 77835 Artists For ModVal=23] Has Run For 1.6 Minutes
# Process [Creating DB Data From 77835 Artists For ModVal=23] Took 1.7 Minutes
# Process [Creating DB Data] Has Run For 64.6 Minutes
#
#
# Current Time is Sat Oct 23, 2021 21:45 for Loading ModValData
# Process [Loading ModValData] Took 6.0 Seconds
# Current Time is Sat Oct 23, 2021 21:46 for Creating DB Data From 77680 Artists For ModVal=24
# 10000/77680 : Process [Creating DB Data From 77680 Artists For ModVal=24] Has Run For 12.6 Seconds
# 35000/77680 : Process [Creating DB Data From 77680 Artists For ModVal=24] Has Run For 44.7 Seconds

# %%
releaseAlbumModData = io.get(setFile(modDir, "{0}-{1}.p".format("ReleaseAlbum", modVal)))

# %%
masterGenreData
# Out:
# {'Genres': ['Electronic'], 'Styles': ['Drum n Bass']}

# %%
releaseAlbumModData.sort_index().head(40)
# Out:
# 0           {'3427135': {'Album': 'Brett Levy', 'Format': ...
# 0           {'3759568': {'Album': 'Who!??!', 'Format': ['1...
# 0           {'11827598': {'Album': 'Κρίθηκες', 'Format': [...
# 0           {'7654879': {'Album': 'Guitarist', 'Format': [...
# 0           {'18176035': {'Album': 'ι̠̊ϝ̻̽̀͋ ɪ͙͖͜ⱦ̫̥̯̭͘’ꜱ͋...
# 1000        {'7497529': {'Album': 'Techno', 'Format': ['Mi...
# 1000        {'1018': {'Album': 'Electro Boogie Vol 2 - The...
# 1000        {'11969194': {'Album': 'Way Of Life', 'Format'...
# 1000        {'16344807': {'Album': 'Devil's Advocate', 'Fo...
# 1000        {'3543520': {'Album': 'The Compass', 'Format':...
# 10000       {'9675': {'Album': 'Seatown / Possible Worlds'...
# 10000       {'10100771': {'Album': 'View Of Life / Streams...
# 10000300    {'20269645': {'Album': 'Snakers', 'Format': ['...
# 10003300    {'20277121': {'Album': 'Sum Ah Dis Sum Ah Dat'...
# 10003900    {'20278606': {'Album': 'Que Sera Sera / C'est ...
# 1000500     {'15047145': {'Album': 'Peak Controller', 'For...
# 1000500     {'1178875': {'Album': 'Peak Controller', 'Form...
# 10005100    {'20281624': {'Album': 'Ein Zigeunerkind', 'Fo...
# 10006600    {'20285653': {'Album': 'Hot', 'Format': ['Albu...
# 10006900    {'20286124': {'Album': 'β​-​methyl​-​4', 'Form...
# 10008400    {'20289418': {'Album': 'Argento', 'Format': ['...
# 10009000    {'20291149': {'Album': 'L'Ulcère Du Duodénum /...
# 10009600    {'20292949': {'Album': 'Roadtrip', 'Format': [...
# 100100      {'7579315': {'Album': 'Cornbread', 'Format': [...
# 100100      {'2439596': {'Album': 'Cornbread (XXX-Tra Corn...
# 100100      {'17937013': {'Album': 'Out Of My Mind / How D...
# 100100      {'12025130': {'Album': 'Cornbread', 'Format': ...
# 10011400    {'20297005': {'Album': 'Blood Vomit', 'Format'...
# 10012300    {'20298175': {'Album': '東京チョンキナ', 'Format': ['...
# 10013500    {'20302276': {'Album': 'The Second Chance / Go...
# 10014400    {'20304883': {'Album': 'BANDA DE GAITAS XARABA...
# 1001600     {'10850313': {'Album': 'Eyvallah Remix', 'Form...
# 1001600     {'12329676': {'Album': 'Nerde?', 'Format': ['A...
# 1001600     {'5702571': {'Album': 'Büyüyorum Seninle', 'Fo...
# 1001600     {'1179727': {'Album': 'Beyaz Vadi', 'Format': ...
# 1001600     {'16973583': {'Album': 'All The King's Horses'...
# 10016200    {'20309557': {'Album': 'Macaroni Birthday Time...
# 1001700     {'18809287': {'Album': 'Is Okay', 'Format': ['...
# 10018900    {'19805362': {'Album': 'Khmer Mohori Music CD ...
# 1001900     {'1180076': {'Album': 'OBX', 'Format': ['MP3']...
# dtype: object

# %%
releaseAlbumModData.get('400')
# Out:
# 400    {'16172714': {'Album': 'Beautiful Electronic M...
# 400    {'11826063': {'Album': 'Tone Flow', 'Format': ...
# 400    {'8122392': {'Album': 'Forms 5 - Shapes In Spa...
# 400    {'3470122': {'Album': 'Loop Series', 'Format':...
# 400    {'20389': {'Album': 'Baud / Unary', 'Format': ...
# dtype: object

# %%
#releaseAlbumModData.get('400').values
releaseArtistAlbumData = releaseAlbumModData.get('400')

# %%
# Out:
# {'16172714': {'Album': 'Beautiful Electronic Music',
#   'Format': ['FLAC', 'Album', 'Reissue', 'Remastered'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Recorded By, Remastered By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'Experimental'],
#   'Country': 'UK',
#   'Master': ['1835285', False]},
#  '16344999': {'Album': 'Forms 12 - Arpforms ',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Recorded By, Design, Photography By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '17522596': {'Album': 'Zerotheque Tome I ',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2021,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Recorded By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Berlin-School', 'IDM'],
#   'Country': 'UK',
#   'Master': None},
#  '18120472': {'Album': 'Syndrones & Syntones ',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2021,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Performer, Producer, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '11826063': {'Album': 'Tone Flow',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2018,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Design, Written-By, Recorded By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '13307931': {'Album': 'Forms 7 - Topological Landscapes ',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2019,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Music By, Artwork'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '14404548': {'Album': 'Forms 8 - Field Effect Studies ',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2019,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Recorded By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient', 'Drone', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '14720877': {'Album': 'Etherwaves',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Recorded By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient', 'Drone'],
#   'Country': 'UK',
#   'Master': None},
#  '14958442': {'Album': 'Forms 9 - Transformation Machine',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Recorded By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient', 'Drone', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '15225698': {'Album': 'Forms 10 - Quantised Tones',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Recorded By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient', 'Drone', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '15225872': {'Album': 'Twenty Systems',
#   'Format': ['FLAC', 'Album', 'Reissue'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '37958',
#     'name': 'Robin Rimbaud',
#     'role': 'Liner Notes [Foreword]'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': ['186185', False]},
#  '15427857': {'Album': 'Thirteen Systems',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Performer, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '15734625': {'Album': 'Mirror Systems',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Design, Music By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient', 'Berlin-School'],
#   'Country': 'UK',
#   'Master': None},
#  '15866158': {'Album': 'Electro-Orgoustic Music',
#   'Format': ['FLAC', 'Album', 'Reissue'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '2847684',
#     'name': 'Hugo Cariss',
#     'role': 'Photography By, Design'},
#    {'id': '400', 'name': 'Benge', 'role': 'Recorded By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'IDM', 'Ambient'],
#   'Country': 'UK',
#   'Master': ['1799721', False]},
#  '16000832': {'Album': 'Forms 11 - Devils Leap ',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2020,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Recorded By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '8122392': {'Album': 'Forms 5 - Shapes In Space',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2016,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '8381378': {'Album': 'Twenty Systems',
#   'Format': ['Album'],
#   'Year': 2008,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '982431',
#     'name': 'Daniel Edwards',
#     'role': 'Artwork By [Layout By]'},
#    {'id': '400', 'name': 'Benge', 'role': 'Mastered By'},
#    {'id': '471007',
#     'name': 'Alan Smith',
#     'role': 'Other [Studio And Synthetizer Maintenance]'},
#    {'id': '0',
#     'name': 'Kent Spong',
#     'role': 'Other [Studio And Synthetizer Maintenance]'},
#    {'id': '498208',
#     'name': 'Paul Merritt',
#     'role': 'Photography By, Artwork [Designed By]'},
#    {'id': '304493', 'name': 'Ben Edwards', 'role': 'Producer'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'role': 'Written-By, Recorded By, Other [Booklet Written By], Photography'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': ['186185', False]},
#  '9451517': {'Album': 'Loop Series Two: Films (Layers)',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2014,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient'],
#   'Country': 'UK',
#   'Master': ['1111795', True]},
#  '9451535': {'Album': 'Loop Series One: Buchla 100 ',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2014,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Minimal', 'Experimental'],
#   'Country': 'UK',
#   'Master': ['1111796', True]},
#  '10258241': {'Album': 'Forms 6 - Works On Paper',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2017,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Music By, Artwork'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '3470122': {'Album': 'Loop Series',
#   'Format': ['Limited Edition'],
#   'Year': 2012,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': None,
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '4402669': {'Album': 'Abstraxa',
#   'Format': ['MP3', 'Album'],
#   'Year': 2012,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental', 'Abstract'],
#   'Country': 'UK',
#   'Master': None},
#  '4402682': {'Album': 'Harmuna',
#   'Format': ['MP3', 'Album'],
#   'Year': 2012,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Minimal', 'Ambient'],
#   'Country': None,
#   'Master': None},
#  '4403065': {'Album': 'Minertua',
#   'Format': ['MP3', 'Album'],
#   'Year': 2012,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Abstract', 'Ambient', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '4403090': {'Album': 'Rebisus',
#   'Format': ['MP3', 'Album'],
#   'Year': 2012,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Abstract', 'Experimental', 'Minimal'],
#   'Country': None,
#   'Master': None},
#  '4660451': {'Album': 'Chimeror',
#   'Format': ['MP3', 'Mini-Album'],
#   'Year': 2013,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Performer, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental', 'Abstract'],
#   'Country': None,
#   'Master': None},
#  '6253018': {'Album': 'Loop Series 2: Films (Layers)',
#   'Format': ['MP3', 'Album'],
#   'Year': 2014,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient'],
#   'Country': 'UK',
#   'Master': ['1111795', False]},
#  '6253043': {'Album': 'Loop Series One: Buchla 100 ',
#   'Format': ['MP3', 'Album'],
#   'Year': 2014,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Minimal', 'Experimental'],
#   'Country': 'UK',
#   'Master': ['1111796', False]},
#  '6253877': {'Album': 'Forms 1',
#   'Format': ['MP3', 'Album'],
#   'Year': 2013,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental', 'Abstract'],
#   'Country': 'UK',
#   'Master': None},
#  '6253901': {'Album': 'Forms 2 - Earthmoves',
#   'Format': ['MP3', 'Album'],
#   'Year': 2013,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient'],
#   'Country': 'UK',
#   'Master': None},
#  '6253946': {'Album': 'Forms 3 - Controls, Sources & Treatments',
#   'Format': ['MP3', 'Album'],
#   'Year': 2013,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': None,
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental', 'Abstract', 'Ambient'],
#   'Country': 'UK',
#   'Master': None},
#  '6253967': {'Album': 'Sulieo',
#   'Format': ['MP3', 'Album'],
#   'Year': 2014,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Music By, Liner Notes, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Minimal', 'Abstract'],
#   'Country': 'UK',
#   'Master': None},
#  '6466941': {'Album': 'Minimalist Work (Sustained Tone Branch) ',
#   'Format': ['MP3', 'Album'],
#   'Year': 2014,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '7329195': {'Album': 'Forms 4 - Moor Music',
#   'Format': ['FLAC', 'Album'],
#   'Year': 2015,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Music By, Photography By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Ambient', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '20389': {'Album': 'Baud / Unary',
#   'Format': ['7"', '45 RPM', 'Limited Edition'],
#   'Year': 2001,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': None,
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'IDM', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '20743': {'Album': 'Electro-Orgoustic Music',
#   'Format': ['Album'],
#   'Year': 1995,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '2648335',
#     'name': 'Damon Elderfield',
#     'role': 'Design [Printwork]'},
#    {'id': '2847684', 'name': 'Hugo Cariss', 'role': 'Photography By, Design'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'BDEdwards',
#     'role': 'Written-By, Producer'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'IDM', 'Ambient'],
#   'Country': 'UK',
#   'Master': ['1799721', True]},
#  '20744': {'Album': 'Beautiful Electronic Music',
#   'Format': ['Album'],
#   'Year': 1996,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '2648335',
#     'name': 'Damon Elderfield',
#     'role': 'Design [Print]'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'role': 'Design, Photography By [Inside Cover]'},
#    {'id': '2847684',
#     'name': 'Hugo Cariss',
#     'role': 'Design, Photography By [Inside Cover]'},
#    {'id': '4533894', 'name': 'Martin Crook', 'role': 'Photography By [Cover]'},
#    {'id': '5343226', 'name': 'Joe Readman', 'role': 'Photography By [Disc]'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'B.D.Edwards',
#     'role': 'Written-By, Producer'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'Experimental'],
#   'Country': 'UK',
#   'Master': ['1835285', True]},
#  '20745': {'Album': 'Polyrhythmic Electronica',
#   'Format': ['EP'],
#   'Year': 1996,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': None,
#   'Genres': ['Electronic'],
#   'Styles': ['IDM', 'Experimental', 'Leftfield'],
#   'Country': 'UK',
#   'Master': ['186182', True]},
#  '20746': {'Album': 'Home Music',
#   'Format': ['Album'],
#   'Year': 1998,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'BD Edwards',
#     'role': 'Music By [Created By]'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'IDM', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '20747': {'Album': 'I, Computor',
#   'Format': ['Album'],
#   'Year': 1997,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '2648335',
#     'name': 'Damon Elderfield',
#     'anv': 'Damon',
#     'role': 'Design [Repro]'},
#    {'id': '400', 'name': 'Benge', 'role': 'Written-By, Producer, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'IDM', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '20748': {'Album': 'Experimental Non-Vocal Electronic Pop',
#   'Format': ['Album'],
#   'Year': 1999,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '2648633',
#     'name': 'Casper Meyer',
#     'role': 'Photography By'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'BDEdwards',
#     'role': 'Written-By, Recorded By, Design'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'IDM', 'Experimental'],
#   'Country': 'UK',
#   'Master': None},
#  '65176': {'Album': 'Meme Tunes',
#   'Format': ['Album'],
#   'Year': 2002,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '2847684',
#     'name': 'Hugo Cariss',
#     'role': 'Photography By'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'B.D.Edwards',
#     'role': 'Producer, Written-By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['IDM', 'Ambient'],
#   'Country': 'UK',
#   'Master': ['186181', True]},
#  '115505': {'Album': 'The Very Best Of',
#   'Format': ['Compilation'],
#   'Year': 1999,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'BD Edwards',
#     'role': 'Written-By, Performer [Performed By], Mixed By, Mastered By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'Abstract', 'IDM'],
#   'Country': 'Belgium',
#   'Master': None},
#  '117839': {'Album': 'Silicon Valleys',
#   'Format': ['CD'],
#   'Year': 2000,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': None,
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'IDM', 'Abstract'],
#   'Country': 'Belgium',
#   'Master': None},
#  '258331': {'Album': 'Meme Tunes',
#   'Format': ['LP', 'Album'],
#   'Year': 2002,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400590',
#     'name': 'Adam Nunn',
#     'anv': 'Adam',
#     'role': 'Mastered By'},
#    {'id': '2847684', 'name': 'Hugo Cariss', 'role': 'Photography By'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'B.D.Edwards',
#     'role': 'Producer, Written-By'}],
#   'Genres': ['Electronic'],
#   'Styles': ['IDM', 'Ambient'],
#   'Country': 'UK',
#   'Master': ['186181', False]},
#  '442976': {'Album': 'I Am 9',
#   'Format': ['Album'],
#   'Year': 2005,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '2648335',
#     'name': 'Damon Elderfield',
#     'role': 'Photography By'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'B.D.Edwards',
#     'role': 'Written-By, Producer'}],
#   'Genres': ['Electronic'],
#   'Styles': ['IDM', 'Ambient'],
#   'Country': 'UK',
#   'Master': ['186183', True]},
#  '504428': {'Album': 'I Am 9',
#   'Format': ['LP', 'Album'],
#   'Year': 2004,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '2648335',
#     'name': 'Damon Elderfield',
#     'role': 'Photography By'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'anv': 'B.D.Edwards',
#     'role': 'Written-By, Producer'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Abstract', 'Downtempo', 'Experimental', 'Ambient'],
#   'Country': 'UK',
#   'Master': ['186183', False]},
#  '1374010': {'Album': 'Polyrhythmic Electronica',
#   'Format': ['EP'],
#   'Year': 1997,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '400',
#     'name': 'Benge',
#     'role': 'Written-By, Producer'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Leftfield', 'IDM', 'Experimental'],
#   'Country': 'UK',
#   'Master': ['186182', False]},
#  '1403834': {'Album': 'Twenty Systems',
#   'Format': ['Album'],
#   'Year': 2007,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': None,
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': ['186185', False]},
#  '1491715': {'Album': 'Twenty Systems',
#   'Format': ['Album'],
#   'Year': 2008,
#   'Artists': [{'id': '400', 'name': 'Benge'}],
#   'ExtraArtists': [{'id': '982431',
#     'name': 'Daniel Edwards',
#     'role': 'Artwork By [Layout By]'},
#    {'id': '400', 'name': 'Benge', 'role': 'Mastered By'},
#    {'id': '471007',
#     'name': 'Alan Smith',
#     'role': 'Other [Studio And Synthetizer Maintenance]'},
#    {'id': '0',
#     'name': 'Kent Spong',
#     'role': 'Other [Studio And Synthetizer Maintenance]'},
#    {'id': '498208',
#     'name': 'Paul Merritt',
#     'role': 'Photography By, Artwork [Designed By]'},
#    {'id': '304493', 'name': 'Ben Edwards', 'role': 'Producer'},
#    {'id': '304493',
#     'name': 'Ben Edwards',
#     'role': 'Written-By, Recorded By, Other [Booklet Written By], Photography'}],
#   'Genres': ['Electronic'],
#   'Styles': ['Experimental'],
#   'Country': 'UK',
#   'Master': ['186185', True]}}

# %%
for item in releaseArtistAlbumData:
    print(item)
# Out:
# {'16172714': {'Album': 'Beautiful Electronic Music', 'Format': ['FLAC', 'Album', 'Reissue', 'Remastered'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Recorded By, Remastered By'}], 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'Experimental'], 'Country': 'UK', 'Master': ['1835285', False]}, '16344999': {'Album': 'Forms 12 - Arpforms ', 'Format': ['FLAC', 'Album'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Recorded By, Design, Photography By'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}, '17522596': {'Album': 'Zerotheque Tome I ', 'Format': ['FLAC', 'Album'], 'Year': 2021, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Recorded By'}], 'Genres': ['Electronic'], 'Styles': ['Berlin-School', 'IDM'], 'Country': 'UK', 'Master': None}, '18120472': {'Album': 'Syndrones & Syntones ', 'Format': ['FLAC', 'Album'], 'Year': 2021, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Performer, Producer, Design'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}}
# {'11826063': {'Album': 'Tone Flow', 'Format': ['FLAC', 'Album'], 'Year': 2018, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Design, Written-By, Recorded By'}], 'Genres': ['Electronic'], 'Styles': ['Ambient', 'Experimental'], 'Country': 'UK', 'Master': None}, '13307931': {'Album': 'Forms 7 - Topological Landscapes ', 'Format': ['FLAC', 'Album'], 'Year': 2019, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Artwork'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}, '14404548': {'Album': 'Forms 8 - Field Effect Studies ', 'Format': ['FLAC', 'Album'], 'Year': 2019, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Recorded By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Ambient', 'Drone', 'Experimental'], 'Country': 'UK', 'Master': None}, '14720877': {'Album': 'Etherwaves', 'Format': ['FLAC', 'Album'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Recorded By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Ambient', 'Drone'], 'Country': 'UK', 'Master': None}, '14958442': {'Album': 'Forms 9 - Transformation Machine', 'Format': ['FLAC', 'Album'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Recorded By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Ambient', 'Drone', 'Experimental'], 'Country': 'UK', 'Master': None}, '15225698': {'Album': 'Forms 10 - Quantised Tones', 'Format': ['FLAC', 'Album'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Recorded By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Ambient', 'Drone', 'Experimental'], 'Country': 'UK', 'Master': None}, '15225872': {'Album': 'Twenty Systems', 'Format': ['FLAC', 'Album', 'Reissue'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '37958', 'name': 'Robin Rimbaud', 'role': 'Liner Notes [Foreword]'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': ['186185', False]}, '15427857': {'Album': 'Thirteen Systems', 'Format': ['FLAC', 'Album'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Performer, Design'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}, '15734625': {'Album': 'Mirror Systems', 'Format': ['FLAC', 'Album'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Design, Music By'}], 'Genres': ['Electronic'], 'Styles': ['Ambient', 'Berlin-School'], 'Country': 'UK', 'Master': None}, '15866158': {'Album': 'Electro-Orgoustic Music', 'Format': ['FLAC', 'Album', 'Reissue'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '2847684', 'name': 'Hugo Cariss', 'role': 'Photography By, Design'}, {'id': '400', 'name': 'Benge', 'role': 'Recorded By'}], 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'IDM', 'Ambient'], 'Country': 'UK', 'Master': ['1799721', False]}, '16000832': {'Album': 'Forms 11 - Devils Leap ', 'Format': ['FLAC', 'Album'], 'Year': 2020, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Written-By, Recorded By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}}
# {'8122392': {'Album': 'Forms 5 - Shapes In Space', 'Format': ['FLAC', 'Album'], 'Year': 2016, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}, '8381378': {'Album': 'Twenty Systems', 'Format': ['Album'], 'Year': 2008, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '982431', 'name': 'Daniel Edwards', 'role': 'Artwork By [Layout By]'}, {'id': '400', 'name': 'Benge', 'role': 'Mastered By'}, {'id': '471007', 'name': 'Alan Smith', 'role': 'Other [Studio And Synthetizer Maintenance]'}, {'id': '0', 'name': 'Kent Spong', 'role': 'Other [Studio And Synthetizer Maintenance]'}, {'id': '498208', 'name': 'Paul Merritt', 'role': 'Photography By, Artwork [Designed By]'}, {'id': '304493', 'name': 'Ben Edwards', 'role': 'Producer'}, {'id': '304493', 'name': 'Ben Edwards', 'role': 'Written-By, Recorded By, Other [Booklet Written By], Photography'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': ['186185', False]}, '9451517': {'Album': 'Loop Series Two: Films (Layers)', 'Format': ['FLAC', 'Album'], 'Year': 2014, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Ambient'], 'Country': 'UK', 'Master': ['1111795', True]}, '9451535': {'Album': 'Loop Series One: Buchla 100 ', 'Format': ['FLAC', 'Album'], 'Year': 2014, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}], 'Genres': ['Electronic'], 'Styles': ['Minimal', 'Experimental'], 'Country': 'UK', 'Master': ['1111796', True]}, '10258241': {'Album': 'Forms 6 - Works On Paper', 'Format': ['FLAC', 'Album'], 'Year': 2017, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Artwork'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}}
# {'3470122': {'Album': 'Loop Series', 'Format': ['Limited Edition'], 'Year': 2012, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': None, 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}, '4402669': {'Album': 'Abstraxa', 'Format': ['MP3', 'Album'], 'Year': 2012, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Experimental', 'Abstract'], 'Country': 'UK', 'Master': None}, '4402682': {'Album': 'Harmuna', 'Format': ['MP3', 'Album'], 'Year': 2012, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Minimal', 'Ambient'], 'Country': None, 'Master': None}, '4403065': {'Album': 'Minertua', 'Format': ['MP3', 'Album'], 'Year': 2012, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Abstract', 'Ambient', 'Experimental'], 'Country': 'UK', 'Master': None}, '4403090': {'Album': 'Rebisus', 'Format': ['MP3', 'Album'], 'Year': 2012, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Abstract', 'Experimental', 'Minimal'], 'Country': None, 'Master': None}, '4660451': {'Album': 'Chimeror', 'Format': ['MP3', 'Mini-Album'], 'Year': 2013, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Performer, Design'}], 'Genres': ['Electronic'], 'Styles': ['Experimental', 'Abstract'], 'Country': None, 'Master': None}, '6253018': {'Album': 'Loop Series 2: Films (Layers)', 'Format': ['MP3', 'Album'], 'Year': 2014, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Ambient'], 'Country': 'UK', 'Master': ['1111795', False]}, '6253043': {'Album': 'Loop Series One: Buchla 100 ', 'Format': ['MP3', 'Album'], 'Year': 2014, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}], 'Genres': ['Electronic'], 'Styles': ['Minimal', 'Experimental'], 'Country': 'UK', 'Master': ['1111796', False]}, '6253877': {'Album': 'Forms 1', 'Format': ['MP3', 'Album'], 'Year': 2013, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}], 'Genres': ['Electronic'], 'Styles': ['Experimental', 'Abstract'], 'Country': 'UK', 'Master': None}, '6253901': {'Album': 'Forms 2 - Earthmoves', 'Format': ['MP3', 'Album'], 'Year': 2013, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}], 'Genres': ['Electronic'], 'Styles': ['Ambient'], 'Country': 'UK', 'Master': None}, '6253946': {'Album': 'Forms 3 - Controls, Sources & Treatments', 'Format': ['MP3', 'Album'], 'Year': 2013, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': None, 'Genres': ['Electronic'], 'Styles': ['Experimental', 'Abstract', 'Ambient'], 'Country': 'UK', 'Master': None}, '6253967': {'Album': 'Sulieo', 'Format': ['MP3', 'Album'], 'Year': 2014, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By, Liner Notes, Design'}], 'Genres': ['Electronic'], 'Styles': ['Minimal', 'Abstract'], 'Country': 'UK', 'Master': None}, '6466941': {'Album': 'Minimalist Work (Sustained Tone Branch) ', 'Format': ['MP3', 'Album'], 'Year': 2014, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '400', 'name': 'Benge', 'role': 'Music By'}], 'Genres': ['Electronic'], 'Styles': ['Experimental'], 'Country': 'UK', 'Master': None}, '7329195': {'Album': 'Forms 4 - Moor Music', 'Format': ['FLAC', 'Album'], 'Year': 2015, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraAr ...
# {'20389': {'Album': 'Baud / Unary', 'Format': ['7"', '45 RPM', 'Limited Edition'], 'Year': 2001, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': None, 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'IDM', 'Experimental'], 'Country': 'UK', 'Master': None}, '20743': {'Album': 'Electro-Orgoustic Music', 'Format': ['Album'], 'Year': 1995, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '2648335', 'name': 'Damon Elderfield', 'role': 'Design [Printwork]'}, {'id': '2847684', 'name': 'Hugo Cariss', 'role': 'Photography By, Design'}, {'id': '304493', 'name': 'Ben Edwards', 'anv': 'BDEdwards', 'role': 'Written-By, Producer'}], 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'IDM', 'Ambient'], 'Country': 'UK', 'Master': ['1799721', True]}, '20744': {'Album': 'Beautiful Electronic Music', 'Format': ['Album'], 'Year': 1996, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '2648335', 'name': 'Damon Elderfield', 'role': 'Design [Print]'}, {'id': '304493', 'name': 'Ben Edwards', 'role': 'Design, Photography By [Inside Cover]'}, {'id': '2847684', 'name': 'Hugo Cariss', 'role': 'Design, Photography By [Inside Cover]'}, {'id': '4533894', 'name': 'Martin Crook', 'role': 'Photography By [Cover]'}, {'id': '5343226', 'name': 'Joe Readman', 'role': 'Photography By [Disc]'}, {'id': '304493', 'name': 'Ben Edwards', 'anv': 'B.D.Edwards', 'role': 'Written-By, Producer'}], 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'Experimental'], 'Country': 'UK', 'Master': ['1835285', True]}, '20745': {'Album': 'Polyrhythmic Electronica', 'Format': ['EP'], 'Year': 1996, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': None, 'Genres': ['Electronic'], 'Styles': ['IDM', 'Experimental', 'Leftfield'], 'Country': 'UK', 'Master': ['186182', True]}, '20746': {'Album': 'Home Music', 'Format': ['Album'], 'Year': 1998, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '304493', 'name': 'Ben Edwards', 'anv': 'BD Edwards', 'role': 'Music By [Created By]'}], 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'IDM', 'Experimental'], 'Country': 'UK', 'Master': None}, '20747': {'Album': 'I, Computor', 'Format': ['Album'], 'Year': 1997, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '2648335', 'name': 'Damon Elderfield', 'anv': 'Damon', 'role': 'Design [Repro]'}, {'id': '400', 'name': 'Benge', 'role': 'Written-By, Producer, Design'}], 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'IDM', 'Experimental'], 'Country': 'UK', 'Master': None}, '20748': {'Album': 'Experimental Non-Vocal Electronic Pop', 'Format': ['Album'], 'Year': 1999, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '2648633', 'name': 'Casper Meyer', 'role': 'Photography By'}, {'id': '304493', 'name': 'Ben Edwards', 'anv': 'BDEdwards', 'role': 'Written-By, Recorded By, Design'}], 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'IDM', 'Experimental'], 'Country': 'UK', 'Master': None}, '65176': {'Album': 'Meme Tunes', 'Format': ['Album'], 'Year': 2002, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '2847684', 'name': 'Hugo Cariss', 'role': 'Photography By'}, {'id': '304493', 'name': 'Ben Edwards', 'anv': 'B.D.Edwards', 'role': 'Producer, Written-By'}], 'Genres': ['Electronic'], 'Styles': ['IDM', 'Ambient'], 'Country': 'UK', 'Master': ['186181', True]}, '115505': {'Album': 'The Very Best Of', 'Format': ['Compilation'], 'Year': 1999, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': [{'id': '304493', 'name': 'Ben Edwards', 'anv': 'BD Edwards', 'role': 'Written-By, Performer [Performed By], Mixed By, Mastered By'}], 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'Abstract', 'IDM'], 'Country': 'Belgium', 'Master': None}, '117839': {'Album': 'Silicon Valleys', 'Format': ['CD'], 'Year': 2000, 'Artists': [{'id': '400', 'name': 'Benge'}], 'ExtraArtists': None, 'Genres': ['Electronic'], 'Styles': ['Leftfield', 'IDM', 'Abstract'], 'Country': 'Belgium', 'Master' ...

# %%
for k,v in releaseAlbumData.iteritems():
    print(k,len(v))
# Out:
# 300 2
# 300 4
# 300 10

# %%
releaseAlbumModData.get('300')

# %%
for k,v in releaseAlbumData.iteritems():
    print(k,'\t',len(v))
    if isinstance(v, dict):
        for k2,v2 in v.items():
            print("\t",k2,'\t',len(v2))
            if isinstance(v2, dict):
                for k3,v3 in v2.items():
                    print("\t\t",k3,'\t',v3)

# %%
for modVal in range(Nmod):
    artistModData  = io.get("{0}/{1}-{2}.p".format(savedir, "ArtistModData", modVal))
    genreModData   = io.get("{0}/{1}-{2}.p".format(savedir, "ArtistModGenreData", modVal))
    masterModData  = io.get("{0}/{1}-{2}.p".format(savedir, "ArtistModMasterAlbumData", modVal))
    releaseModData = io.get("{0}/{1}-{2}.p".format(savedir, "ArtistModReleaseData", modVal))
    break

# %%
modValIdxs = sorted(list(set(artistModData.index).union(set(genreModData.index)).union(set(masterModData.index)).union(set(releaseModData.index))))
len(modValIdxs)
#len(artistModData.index)

# %%
if True:
    for artistID,artistDataFrame in artistModData.iterrows():
        dbData = {"ID": artistID, "Artist": artistDataFrame, "Genre": genreModData.get(artistID), "Master": masterModData.get(artistID), "Release": releaseModData.get(artistID)}
        art = artistDiscogsFull()
        art.getData(dbData)

# %%
from artistDBBase import artistDBBase, artistDBDataClass
from artistDBBase import artistDBNameClass, artistDBMetaClass, artistDBIDClass, artistDBURLClass, artistDBPageClass
from artistDBBase import artistDBProfileClass, artistDBMediaClass, artistDBMediaAlbumClass
from artistDBBase import artistDBMediaDataClass, artistDBMediaCountsClass, artistDBFileInfoClass
from artistDBBase import artistDBTextClass, artistDBLinkClass
from strUtils import fixName
from dbUtils import utilsDiscogs


class artistDiscogsFull(artistDBBase):
    def __init__(self, debug=False):
        super().__init__(debug)
        self.dutils = utilsDiscogs()
        
        
    ##############################################################################################################################
    ## Parse Data
    ##############################################################################################################################
    def getData(self, inputdata):
        if not isinstance(inputdata, dict):
            raise ValueError("Input must be a Discogs Dictionary")
            
        artistID    = inputdata["ID"]
        artistData  = inputdata["Artist"]
        genreData   = inputdata["Genre"]
        masterData  = inputdata["Master"]
        releaseData = inputdata["Release"]
        
        print(artistData)
        print(genreData)
        print(masterData)
        print(releaseData)
        artistName  = artistData["name"]
        url         = "https://www.discogs.com/artist/{0}".format(artistID)

        generalData = {}
        generalData["RealName"]   = artistData["realname"]
        generalData["Aliases"]    = artistData["MasterAliases"]
        generalData["Groups"]     = artistData["MasterGroups"]
        generalData["Members"]    = artistData["MasterMembers"]
        generalData["Variations"] = artistData["MasterNameVariations"]
        generalData = {k: v for k,v in generalData.items() if v is not None}
        generalData = generalData if len(generalData) > 0 else None
            
        artist      = artistDBNameClass(name=artistName, err=None)
        meta        = artistDBMetaClass(title=None, url=url)
        url         = artistDBURLClass(url=url)
        ID          = artistDBIDClass(ID=artistID)
        pages       = artistDBPageClass(ppp=1, tot=1, redo=False, more=False)
        profile     = artistDBProfileClass(general=generalData)
        
        amc  = artistDBMediaClass()
        for code,masterInfo in masterData.items():
            album        = masterInfo["Album"]
            albumURL     = "https://www.discogs.com/release/{0}".format(code)
            albumArtists = masterInfo["Artists"]
            albumYear    = masterInfo["Year"]
            amdc = artistDBMediaDataClass(album=album, url=albumURL, artist=albumArtists, code=code, year=year)
        amc.media[name].append(amdc)

        media       = self.getMedia()
        mediaCounts = self.getMediaCounts(media)
        info        = artistDBFileInfoClass(info=None)
        
        adc = artistDBDataClass(artist=artist, meta=meta, url=url, ID=ID, pages=pages, profile=profile, mediaCounts=mediaCounts, media=media, info=info)
        
        return adc
